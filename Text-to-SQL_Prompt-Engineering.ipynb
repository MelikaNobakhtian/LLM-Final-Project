# %% [markdown]
# # **Import & Install `openai`**

# %%
! pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 813.2 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.7.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Installing collected packages: openai
# Successfully installed openai-0.28.0

# %%
import openai

# Set up OpenAI API key
openai.api_key = '*****'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Few-Shot Promting - DIN-SQL paper**
#
# In this part we just show the codes of `DIN-Sql` paper.
#
# https://github.com/MohammadrezaPourreza/Few-shot-NL2SQL-with-prompting

# %%
import pandas as pd
import time
import openai
import os
import sys


#----------------------------------------------------prompts-----------------------------------------------
schema_linking_prompt = '''Table advisor, columns = [*,s_ID,i_ID]
Table classroom, columns = [*,building,room_number,capacity]
Table course, columns = [*,course_id,title,dept_name,credits]
Table department, columns = [*,dept_name,building,budget]
Table instructor, columns = [*,ID,name,dept_name,salary]
Table prereq, columns = [*,course_id,prereq_id]
Table section, columns = [*,course_id,sec_id,semester,year,building,room_number,time_slot_id]
Table student, columns = [*,ID,name,dept_name,tot_cred]
Table takes, columns = [*,ID,course_id,sec_id,semester,year,grade]
Table teaches, columns = [*,ID,course_id,sec_id,semester,year]
Table time_slot, columns = [*,time_slot_id,day,start_hr,start_min,end_hr,end_min]
Foreign_keys = [course.dept_name = department.dept_name,instructor.dept_name = department.dept_name,section.building = classroom.building,section.room_number = classroom.room_number,section.course_id = course.course_id,teaches.ID = instructor.ID,teaches.course_id = section.course_id,teaches.sec_id = section.sec_id,teaches.semester = section.semester,teaches.year = section.year,student.dept_name = department.dept_name,takes.ID = student.ID,takes.course_id = section.course_id,takes.sec_id = section.sec_id,takes.semester = section.semester,takes.year = section.year,advisor.s_ID = student.ID,advisor.i_ID = instructor.ID,prereq.prereq_id = course.course_id,prereq.course_id = course.course_id]
Q: "Find the buildings which have rooms with capacity more than 50."
A: Let’s think step by step. In the question "Find the buildings which have rooms with capacity more than 50.", we are asked:
"the buildings which have rooms" so we need column = [classroom.capacity]
"rooms with capacity" so we need column = [classroom.building]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [50]. So the Schema_links are:
Schema_links: [classroom.building,classroom.capacity,50]

Table department, columns = [*,Department_ID,Name,Creation,Ranking,Budget_in_Billions,Num_Employees]
Table head, columns = [*,head_ID,name,born_state,age]
Table management, columns = [*,department_ID,head_ID,temporary_acting]
Foreign_keys = [management.head_ID = head.head_ID,management.department_ID = department.Department_ID]
Q: "How many heads of the departments are older than 56 ?"
A: Let’s think step by step. In the question "How many heads of the departments are older than 56 ?", we are asked:
"How many heads of the departments" so we need column = [head.*]
"older" so we need column = [head.age]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [56]. So the Schema_links are:
Schema_links: [head.*,head.age,56]

Table department, columns = [*,Department_ID,Name,Creation,Ranking,Budget_in_Billions,Num_Employees]
Table head, columns = [*,head_ID,name,born_state,age]
Table management, columns = [*,department_ID,head_ID,temporary_acting]
Foreign_keys = [management.head_ID = head.head_ID,management.department_ID = department.Department_ID]
Q: "what are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?"
A: Let’s think step by step. In the question "what are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?", we are asked:
"distinct creation years of the departments" so we need column = [department.Creation]
"departments managed by" so we need column = [management.department_ID]
"born in" so we need column = [head.born_state]
Based on the columns and tables, we need these Foreign_keys = [department.Department_ID = management.department_ID,management.head_ID = head.head_ID].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = ['Alabama']. So the Schema_links are:
Schema_links: [department.Creation,department.Department_ID = management.department_ID,head.head_ID = management.head_ID,head.born_state,'Alabama']

Table Addresses, columns = [*,address_id,line_1,line_2,city,zip_postcode,state_province_county,country]
Table Candidate_Assessments, columns = [*,candidate_id,qualification,assessment_date,asessment_outcome_code]
Table Candidates, columns = [*,candidate_id,candidate_details]
Table Courses, columns = [*,course_id,course_name,course_description,other_details]
Table People, columns = [*,person_id,first_name,middle_name,last_name,cell_mobile_number,email_address,login_name,password]
Table People_Addresses, columns = [*,person_address_id,person_id,address_id,date_from,date_to]
Table Student_Course_Attendance, columns = [*,student_id,course_id,date_of_attendance]
Table Student_Course_Registrations, columns = [*,student_id,course_id,registration_date]
Table Students, columns = [*,student_id,student_details]
Foreign_keys = [Students.student_id = People.person_id,People_Addresses.address_id = Addresses.address_id,People_Addresses.person_id = People.person_id,Student_Course_Registrations.course_id = Courses.course_id,Student_Course_Registrations.student_id = Students.student_id,Student_Course_Attendance.student_id = Student_Course_Registrations.student_id,Student_Course_Attendance.course_id = Student_Course_Registrations.course_id,Candidates.candidate_id = People.person_id,Candidate_Assessments.candidate_id = Candidates.candidate_id]
Q: "List the id of students who never attends courses?"
A: Let’s think step by step. In the question "List the id of students who never attends courses?", we are asked:
"id of students" so we need column = [Students.student_id]
"never attends courses" so we need column = [Student_Course_Attendance.student_id]
Based on the columns and tables, we need these Foreign_keys = [Students.student_id = Student_Course_Attendance.student_id].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = []. So the Schema_links are:
Schema_links: [Students.student_id = Student_Course_Attendance.student_id]

Table Country, columns = [*,id,name]
Table League, columns = [*,id,country_id,name]
Table Player, columns = [*,id,player_api_id,player_name,player_fifa_api_id,birthday,height,weight]
Table Player_Attributes, columns = [*,id,player_fifa_api_id,player_api_id,date,overall_rating,potential,preferred_foot,attacking_work_rate,defensive_work_rate,crossing,finishing,heading_accuracy,short_passing,volleys,dribbling,curve,free_kick_accuracy,long_passing,ball_control,acceleration,sprint_speed,agility,reactions,balance,shot_power,jumping,stamina,strength,long_shots,aggression,interceptions,positioning,vision,penalties,marking,standing_tackle,sliding_tackle,gk_diving,gk_handling,gk_kicking,gk_positioning,gk_reflexes]
Table Team, columns = [*,id,team_api_id,team_fifa_api_id,team_long_name,team_short_name]
Table Team_Attributes, columns = [*,id,team_fifa_api_id,team_api_id,date,buildUpPlaySpeed,buildUpPlaySpeedClass,buildUpPlayDribbling,buildUpPlayDribblingClass,buildUpPlayPassing,buildUpPlayPassingClass,buildUpPlayPositioningClass,chanceCreationPassing,chanceCreationPassingClass,chanceCreationCrossing,chanceCreationCrossingClass,chanceCreationShooting,chanceCreationShootingClass,chanceCreationPositioningClass,defencePressure,defencePressureClass,defenceAggression,defenceAggressionClass,defenceTeamWidth,defenceTeamWidthClass,defenceDefenderLineClass]
Table sqlite_sequence, columns = [*,name,seq]
Foreign_keys = [Player_Attributes.player_api_id = Player.player_api_id,Player_Attributes.player_fifa_api_id = Player.player_fifa_api_id,League.country_id = Country.id,Team_Attributes.team_api_id = Team.team_api_id,Team_Attributes.team_fifa_api_id = Team.team_fifa_api_id]
Q: "List the names of all left-footed players who have overall rating between 85 and 90."
A: Let’s think step by step. In the question "List the names of all left-footed players who have overall rating between 85 and 90.", we are asked:
"names of all left-footed players" so we need column = [Player.player_name,Player_Attributes.preferred_foot]
"players who have overall rating" so we need column = [Player_Attributes.overall_rating]
Based on the columns and tables, we need these Foreign_keys = [Player_Attributes.player_api_id = Player.player_api_id].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [left,85,90]. So the Schema_links are:
Schema_links: [Player.player_name,Player_Attributes.preferred_foot,Player_Attributes.overall_rating,Player_Attributes.player_api_id = Player.player_api_id,left,85,90]

Table advisor, columns = [*,s_ID,i_ID]
Table classroom, columns = [*,building,room_number,capacity]
Table course, columns = [*,course_id,title,dept_name,credits]
Table department, columns = [*,dept_name,building,budget]
Table instructor, columns = [*,ID,name,dept_name,salary]
Table prereq, columns = [*,course_id,prereq_id]
Table section, columns = [*,course_id,sec_id,semester,year,building,room_number,time_slot_id]
Table student, columns = [*,ID,name,dept_name,tot_cred]
Table takes, columns = [*,ID,course_id,sec_id,semester,year,grade]
Table teaches, columns = [*,ID,course_id,sec_id,semester,year]
Table time_slot, columns = [*,time_slot_id,day,start_hr,start_min,end_hr,end_min]
Foreign_keys = [course.dept_name = department.dept_name,instructor.dept_name = department.dept_name,section.building = classroom.building,section.room_number = classroom.room_number,section.course_id = course.course_id,teaches.ID = instructor.ID,teaches.course_id = section.course_id,teaches.sec_id = section.sec_id,teaches.semester = section.semester,teaches.year = section.year,student.dept_name = department.dept_name,takes.ID = student.ID,takes.course_id = section.course_id,takes.sec_id = section.sec_id,takes.semester = section.semester,takes.year = section.year,advisor.s_ID = student.ID,advisor.i_ID = instructor.ID,prereq.prereq_id = course.course_id,prereq.course_id = course.course_id]
Q: "Give the title of the course offered in Chandler during the Fall of 2010."
A: Let’s think step by step. In the question "Give the title of the course offered in Chandler during the Fall of 2010.", we are asked:
"title of the course" so we need column = [course.title]
"course offered in Chandler" so we need column = [SECTION.building]
"during the Fall" so we need column = [SECTION.semester]
"of 2010" so we need column = [SECTION.year]
Based on the columns and tables, we need these Foreign_keys = [course.course_id = SECTION.course_id].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [Chandler,Fall,2010]. So the Schema_links are:
Schema_links: [course.title,course.course_id = SECTION.course_id,SECTION.building,SECTION.year,SECTION.semester,Chandler,Fall,2010]

Table city, columns = [*,City_ID,Official_Name,Status,Area_km_2,Population,Census_Ranking]
Table competition_record, columns = [*,Competition_ID,Farm_ID,Rank]
Table farm, columns = [*,Farm_ID,Year,Total_Horses,Working_Horses,Total_Cattle,Oxen,Bulls,Cows,Pigs,Sheep_and_Goats]
Table farm_competition, columns = [*,Competition_ID,Year,Theme,Host_city_ID,Hosts]
Foreign_keys = [farm_competition.Host_city_ID = city.City_ID,competition_record.Farm_ID = farm.Farm_ID,competition_record.Competition_ID = farm_competition.Competition_ID]
Q: "Show the status of the city that has hosted the greatest number of competitions."
A: Let’s think step by step. In the question "Show the status of the city that has hosted the greatest number of competitions.", we are asked:
"the status of the city" so we need column = [city.Status]
"greatest number of competitions" so we need column = [farm_competition.*]
Based on the columns and tables, we need these Foreign_keys = [farm_competition.Host_city_ID = city.City_ID].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = []. So the Schema_links are:
Schema_links: [city.Status,farm_competition.Host_city_ID = city.City_ID,farm_competition.*]

Table advisor, columns = [*,s_ID,i_ID]
Table classroom, columns = [*,building,room_number,capacity]
Table course, columns = [*,course_id,title,dept_name,credits]
Table department, columns = [*,dept_name,building,budget]
Table instructor, columns = [*,ID,name,dept_name,salary]
Table prereq, columns = [*,course_id,prereq_id]
Table section, columns = [*,course_id,sec_id,semester,year,building,room_number,time_slot_id]
Table student, columns = [*,ID,name,dept_name,tot_cred]
Table takes, columns = [*,ID,course_id,sec_id,semester,year,grade]
Table teaches, columns = [*,ID,course_id,sec_id,semester,year]
Table time_slot, columns = [*,time_slot_id,day,start_hr,start_min,end_hr,end_min]
Foreign_keys = [course.dept_name = department.dept_name,instructor.dept_name = department.dept_name,section.building = classroom.building,section.room_number = classroom.room_number,section.course_id = course.course_id,teaches.ID = instructor.ID,teaches.course_id = section.course_id,teaches.sec_id = section.sec_id,teaches.semester = section.semester,teaches.year = section.year,student.dept_name = department.dept_name,takes.ID = student.ID,takes.course_id = section.course_id,takes.sec_id = section.sec_id,takes.semester = section.semester,takes.year = section.year,advisor.s_ID = student.ID,advisor.i_ID = instructor.ID,prereq.prereq_id = course.course_id,prereq.course_id = course.course_id]
Q: "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010."
A: Let’s think step by step. In the question "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010.", we are asked:
"id of instructors who taught " so we need column = [teaches.id]
"taught a class in" so we need column = [teaches.semester,teaches.year]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [Fall,2009,Spring,2010]. So the Schema_links are:
schema_links: [teaches.id,teaches.semester,teaches.year,Fall,2009,Spring,2010]

Table Accounts, columns = [*,account_id,customer_id,date_account_opened,account_name,other_account_details]
Table Customers, columns = [*,customer_id,customer_first_name,customer_middle_initial,customer_last_name,gender,email_address,login_name,login_password,phone_number,town_city,state_county_province,country]
Table Financial_Transactions, columns = [*,transaction_id,account_id,invoice_number,transaction_type,transaction_date,transaction_amount,transaction_comment,other_transaction_details]
Table Invoice_Line_Items, columns = [*,order_item_id,invoice_number,product_id,product_title,product_quantity,product_price,derived_product_cost,derived_vat_payable,derived_total_cost]
Table Invoices, columns = [*,invoice_number,order_id,invoice_date]
Table Order_Items, columns = [*,order_item_id,order_id,product_id,product_quantity,other_order_item_details]
Table Orders, columns = [*,order_id,customer_id,date_order_placed,order_details]
Table Product_Categories, columns = [*,production_type_code,product_type_description,vat_rating]
Table Products, columns = [*,product_id,parent_product_id,production_type_code,unit_price,product_name,product_color,product_size]
Foreign_keys = [Orders.customer_id = Customers.customer_id,Invoices.order_id = Orders.order_id,Accounts.customer_id = Customers.customer_id,Products.production_type_code = Product_Categories.production_type_code,Financial_Transactions.account_id = Accounts.account_id,Financial_Transactions.invoice_number = Invoices.invoice_number,Order_Items.order_id = Orders.order_id,Order_Items.product_id = Products.product_id,Invoice_Line_Items.product_id = Products.product_id,Invoice_Line_Items.invoice_number = Invoices.invoice_number,Invoice_Line_Items.order_item_id = Order_Items.order_item_id]
Q: "Show the id, the date of account opened, the account name, and other account detail for all accounts."
A: Let’s think step by step. In the question "Show the id, the date of account opened, the account name, and other account detail for all accounts.", we are asked:
"the id, the date of account opened, the account name, and other account detail for all accounts." so we need column = [Accounts.account_id,Accounts.account_name,Accounts.other_account_details,Accounts.date_account_opened]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = []. So the Schema_links are:
Schema_links: [Accounts.account_id,Accounts.account_name,Accounts.other_account_details,Accounts.date_account_opened]

Table city, columns = [*,City_ID,Official_Name,Status,Area_km_2,Population,Census_Ranking]
Table competition_record, columns = [*,Competition_ID,Farm_ID,Rank]
Table farm, columns = [*,Farm_ID,Year,Total_Horses,Working_Horses,Total_Cattle,Oxen,Bulls,Cows,Pigs,Sheep_and_Goats]
Table farm_competition, columns = [*,Competition_ID,Year,Theme,Host_city_ID,Hosts]
Foreign_keys = [farm_competition.Host_city_ID = city.City_ID,competition_record.Farm_ID = farm.Farm_ID,competition_record.Competition_ID = farm_competition.Competition_ID]
Q: "Show the status shared by cities with population bigger than 1500 and smaller than 500."
A: Let’s think step by step. In the question "Show the status shared by cities with population bigger than 1500 and smaller than 500.", we are asked:
"the status shared by cities" so we need column = [city.Status]
"cities with population" so we need column = [city.Population]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [1500,500]. So the Schema_links are:
Schema_links: [city.Status,city.Population,1500,500]

'''
classification_prompt = '''Q: "Find the buildings which have rooms with capacity more than 50."
schema_links: [classroom.building,classroom.capacity,50]
A: Let’s think step by step. The SQL query for the question "Find the buildings which have rooms with capacity more than 50." needs these tables = [classroom], so we don't need JOIN.
Plus, it doesn't require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we don't need JOIN and don't need nested queries, then the the SQL query can be classified as "EASY".
Label: "EASY"

Q: "What are the names of all instructors who advise students in the math depart sorted by total credits of the student."
schema_links: [advisor.i_id = instructor.id,advisor.s_id = student.id,instructor.name,student.dept_name,student.tot_cred,math]
A: Let’s think step by step. The SQL query for the question "What are the names of all instructors who advise students in the math depart sorted by total credits of the student." needs these tables = [advisor,instructor,student], so we need JOIN.
Plus, it doesn't need nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we need JOIN and don't need nested queries, then the the SQL query can be classified as "NON-NESTED".
Label: "NON-NESTED"

Q: "Find the room number of the rooms which can sit 50 to 100 students and their buildings."
schema_links: [classroom.building,classroom.room_number,classroom.capacity,50,100]
A: Let’s think step by step. The SQL query for the question "Find the room number of the rooms which can sit 50 to 100 students and their buildings." needs these tables = [classroom], so we don't need JOIN.
Plus, it doesn't require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we don't need JOIN and don't need nested queries, then the the SQL query can be classified as "EASY".
Label: "EASY"

Q: "How many courses that do not have prerequisite?"
schema_links: [course.*,course.course_id = prereq.course_id]
A: Let’s think step by step. The SQL query for the question "How many courses that do not have prerequisite?" needs these tables = [course,prereq], so we need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["Which courses have prerequisite?"].
So, we need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

Q: "Find the title of course that is provided by both Statistics and Psychology departments."
schema_links: [course.title,course.dept_name,Statistics,Psychology]
A: Let’s think step by step. The SQL query for the question "Find the title of course that is provided by both Statistics and Psychology departments." needs these tables = [course], so we don't need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["Find the titles of courses that is provided by Psychology departments"].
So, we don't need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

Q: "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010."
schema_links: [teaches.id,teaches.semester,teaches.year,Fall,2009,Spring,2010]
A: Let’s think step by step. The SQL query for the question "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010." needs these tables = [teaches], so we don't need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["Find the id of instructors who taught a class in Spring 2010"].
So, we don't need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

Q: "Find the name of the department that offers the highest total credits?"
schema_links: [course.dept_name,course.credits]
A: Let’s think step by step. The SQL query for the question "Find the name of the department that offers the highest total credits?." needs these tables = [course], so we don't need JOIN.
Plus, it doesn't require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we don't need JOIN and don't need nested queries, then the the SQL query can be classified as "EASY".
Label: "EASY"

Q: "What is the name of the instructor who advises the student with the greatest number of total credits?"
schema_links: [advisor.i_id = instructor.id,advisor.s_id = student.id,instructor.name,student.tot_cred ]
A: Let’s think step by step. The SQL query for the question "What is the name of the instructor who advises the student with the greatest number of total credits?" needs these tables = [advisor,instructor,student], so we need JOIN.
Plus, it doesn't need nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we need JOIN and don't need nested queries, then the the SQL query can be classified as "NON-NESTED".
Label: "NON-NESTED"

Q: "Find the total number of students and total number of instructors for each department."
schema_links = [department.dept_name = instructor.dept_name,student.id,student.dept_name = department.dept_name,instructor.id]
A: Let’s think step by step. The SQL query for the question "Find the total number of students and total number of instructors for each department." needs these tables = [department,instructor,student], so we need JOIN.
Plus, it doesn't need nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we need JOIN and don't need nested queries, then the the SQL query can be classified as "NON-NESTED".
Label: "NON-NESTED"

Q: "Give the name and building of the departments with greater than average budget."
schema_links: [department.budget,department.dept_name,department.building]
A: Let’s think step by step. The SQL query for the question "Give the name and building of the departments with greater than average budget." needs these tables = [department], so we don't need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["What is the average budget of the departments"].
So, we don't need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

'''

easy_prompt = '''Q: "Find the buildings which have rooms with capacity more than 50."
Schema_links: [classroom.building,classroom.capacity,50]
SQL: SELECT DISTINCT building FROM classroom WHERE capacity  >  50

Q: "Find the room number of the rooms which can sit 50 to 100 students and their buildings."
Schema_links: [classroom.building,classroom.room_number,classroom.capacity,50,100]
SQL: SELECT building ,  room_number FROM classroom WHERE capacity BETWEEN 50 AND 100

Q: "Give the name of the student in the History department with the most credits."
Schema_links: [student.name,student.dept_name,student.tot_cred,History]
SQL: SELECT name FROM student WHERE dept_name  =  'History' ORDER BY tot_cred DESC LIMIT 1

Q: "Find the total budgets of the Marketing or Finance department."
Schema_links: [department.budget,department.dept_name,Marketing,Finance]
SQL: SELECT sum(budget) FROM department WHERE dept_name  =  'Marketing' OR dept_name  =  'Finance'

Q: "Find the department name of the instructor whose name contains 'Soisalon'."
Schema_links: [instructor.dept_name,instructor.name,Soisalon]
SQL: SELECT dept_name FROM instructor WHERE name LIKE '%Soisalon%'

Q: "What is the name of the department with the most credits?"
Schema_links: [course.dept_name,course.credits]
SQL: SELECT dept_name FROM course GROUP BY dept_name ORDER BY sum(credits) DESC LIMIT 1

Q: "How many instructors teach a course in the Spring of 2010?"
Schema_links: [teaches.ID,teaches.semester,teaches.YEAR,Spring,2010]
SQL: SELECT COUNT (DISTINCT ID) FROM teaches WHERE semester  =  'Spring' AND YEAR  =  2010

Q: "Find the name of the students and their department names sorted by their total credits in ascending order."
Schema_links: [student.name,student.dept_name,student.tot_cred]
SQL: SELECT name ,  dept_name FROM student ORDER BY tot_cred

Q: "Find the year which offers the largest number of courses."
Schema_links: [SECTION.YEAR,SECTION.*]
SQL: SELECT YEAR FROM SECTION GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1

Q: "What are the names and average salaries for departments with average salary higher than 42000?"
Schema_links: [instructor.dept_name,instructor.salary,42000]
SQL: SELECT dept_name ,  AVG (salary) FROM instructor GROUP BY dept_name HAVING AVG (salary)  >  42000

Q: "How many rooms in each building have a capacity of over 50?"
Schema_links: [classroom.*,classroom.building,classroom.capacity,50]
SQL: SELECT count(*) ,  building FROM classroom WHERE capacity  >  50 GROUP BY building

Q: "Find the names of the top 3 departments that provide the largest amount of courses?"
Schema_links: [course.dept_name,course.*]
SQL: SELECT dept_name FROM course GROUP BY dept_name ORDER BY count(*) DESC LIMIT 3

Q: "Find the maximum and average capacity among rooms in each building."
Schema_links: [classroom.building,classroom.capacity]
SQL: SELECT max(capacity) ,  avg(capacity) ,  building FROM classroom GROUP BY building

Q: "Find the title of the course that is offered by more than one department."
Schema_links: [course.title]
SQL: SELECT title FROM course GROUP BY title HAVING count(*)  >  1

'''
medium_prompt = '''Q: "Find the total budgets of the Marketing or Finance department."
Schema_links: [department.budget,department.dept_name,Marketing,Finance]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = []. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select sum(department.budget) from department  where  department.dept_name = \"Marketing\"  or  department.dept_name = \"Finance\"
SQL: SELECT sum(budget) FROM department WHERE dept_name  =  'Marketing' OR dept_name  =  'Finance'

Q: "Find the name and building of the department with the highest budget."
Schema_links: [department.budget,department.dept_name,department.building]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = []. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select department.dept_name , department.building from department  order by department.budget desc limit 1
SQL: SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1

Q: "What is the name and building of the departments whose budget is more than the average budget?"
Schema_links: [department.budget,department.dept_name,department.building]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = []. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation:  select department.dept_name , department.building from department  where  @.@ > avg ( department.budget )
SQL: SELECT dept_name ,  building FROM department WHERE budget  >  (SELECT avg(budget) FROM department)

Q: "Find the total number of students and total number of instructors for each department."
Schema_links: [department.dept_name = student.dept_name,student.id,department.dept_name = instructor.dept_name,instructor.id]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = [department,student,instructor]. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: "select count( distinct student.ID) , count( distinct instructor.ID) , department.dept_name from department  group by instructor.dept_name
SQL: SELECT count(DISTINCT T2.id) ,  count(DISTINCT T3.id) ,  T3.dept_name FROM department AS T1 JOIN student AS T2 ON T1.dept_name  =  T2.dept_name JOIN instructor AS T3 ON T1.dept_name  =  T3.dept_name GROUP BY T3.dept_name

Q: "Find the title of courses that have two prerequisites?"
Schema_links: [course.title,course.course_id = prereq.course_id]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = [course,prereq]. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select course.title from course  where  count ( prereq.* )  = 2  group by prereq.course_id
SQL: SELECT T1.title FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  =  2

Q: "Find the name of students who took any class in the years of 2009 and 2010."
Schema_links: [student.name,student.id = takes.id,takes.YEAR,2009,2010]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = [student,takes]. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select  distinct student.name from student  where  takes.year = 2009  or  takes.year = 2010
SQL: SELECT DISTINCT T1.name FROM student AS T1 JOIN takes AS T2 ON T1.id  =  T2.id WHERE T2.YEAR  =  2009 OR T2.YEAR  =  2010

Q: "list in alphabetic order all course names and their instructors' names in year 2008."
Schema_links: [course.title,course.course_id = teaches.course_id,teaches.id = instructor.id,instructor.name,teaches.year,2008]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = [course,teaches,instructor]. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select course.title , instructor.name from course  where  teaches.year = 2008  order by course.title asc
SQL: SELECT T1.title ,  T3.name FROM course AS T1 JOIN teaches AS T2 ON T1.course_id  =  T2.course_id JOIN instructor AS T3 ON T2.id  =  T3.id WHERE T2.YEAR  =  2008 ORDER BY T1.title

'''
hard_prompt = '''Q: "Find the title of courses that have two prerequisites?"
Schema_links: [course.title,course.course_id = prereq.course_id]
A: Let's think step by step. "Find the title of courses that have two prerequisites?" can be solved by knowing the answer to the following sub-question "What are the titles for courses with two prerequisites?".
The SQL query for the sub-question "What are the titles for courses with two prerequisites?" is SELECT T1.title FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  =  2
So, the answer to the question "Find the title of courses that have two prerequisites?" is =
Intermediate_representation: select course.title from course  where  count ( prereq.* )  = 2  group by prereq.course_id
SQL: SELECT T1.title FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  =  2

Q: "Find the name and building of the department with the highest budget."
Schema_links: [department.dept_name,department.building,department.budget]
A: Let's think step by step. "Find the name and building of the department with the highest budget." can be solved by knowing the answer to the following sub-question "What is the department name and corresponding building for the department with the greatest budget?".
The SQL query for the sub-question "What is the department name and corresponding building for the department with the greatest budget?" is SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1
So, the answer to the question "Find the name and building of the department with the highest budget." is =
Intermediate_representation: select department.dept_name , department.building from department  order by department.budget desc limit 1
SQL: SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1

Q: "Find the title, credit, and department name of courses that have more than one prerequisites?"
Schema_links: [course.title,course.credits,course.dept_name,course.course_id = prereq.course_id]
A: Let's think step by step. "Find the title, credit, and department name of courses that have more than one prerequisites?" can be solved by knowing the answer to the following sub-question "What is the title, credit value, and department name for courses with more than one prerequisite?".
The SQL query for the sub-question "What is the title, credit value, and department name for courses with more than one prerequisite?" is SELECT T1.title ,  T1.credits , T1.dept_name FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  >  1
So, the answer to the question "Find the name and building of the department with the highest budget." is =
Intermediate_representation: select course.title , course.credits , course.dept_name from course  where  count ( prereq.* )  > 1  group by prereq.course_id
SQL: SELECT T1.title ,  T1.credits , T1.dept_name FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  >  1

Q: "Give the name and building of the departments with greater than average budget."
Schema_links: [department.dept_name,department.building,department.budget]
A: Let's think step by step. "Give the name and building of the departments with greater than average budget." can be solved by knowing the answer to the following sub-question "What is the average budget of departments?".
The SQL query for the sub-question "What is the average budget of departments?" is SELECT avg(budget) FROM department
So, the answer to the question "Give the name and building of the departments with greater than average budget." is =
Intermediate_representation: select department.dept_name , department.building from department  where  @.@ > avg ( department.budget )
SQL: SELECT dept_name ,  building FROM department WHERE budget  >  (SELECT avg(budget) FROM department)

Q: "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010."
Schema_links: [teaches.id,teaches.semester,teaches.YEAR,Fall,2009,Spring,2010]
A: Let's think step by step. "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010." can be solved by knowing the answer to the following sub-question "Find the id of instructors who taught a class in Spring 2010".
The SQL query for the sub-question "Find the id of instructors who taught a class in Spring 2010" is SELECT id FROM teaches WHERE semester  =  'Spring' AND YEAR  =  2010
So, the answer to the question "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010." is =
Intermediate_representation: select teaches.ID from teaches  where  teaches.semester = \"Fall\"  and  teaches.year = 2009  and  teaches.semester != \"Spring\"  and  teaches.year = 2010
SQL: SELECT id FROM teaches WHERE semester  =  'Fall' AND YEAR  =  2009 EXCEPT SELECT id FROM teaches WHERE semester  =  'Spring' AND YEAR  =  2010

Q: "Find the name of the courses that do not have any prerequisite?"
Schema_links: [course.title,course.course_id]
A: Let's think step by step. "Find the name of the courses that do not have any prerequisite?" can be solved by knowing the answer to the following sub-question "What are the courses that have any prerequisite?".
The SQL query for the sub-question "What are the courses that have any prerequisite?" is SELECT course_id FROM prereq
So, the answer to the question "Find the name of the courses that do not have any prerequisite?" is =
Intermediate_representation: select course.title from course  where  @.@ not in prereq.course_id
SQL: SELECT title FROM course WHERE course_id NOT IN (SELECT course_id FROM prereq)

Q: "Find the salaries of all distinct instructors that are less than the largest salary."
Schema_links: [instructor.salary]
A: Let's think step by step. "Find the salaries of all distinct instructors that are less than the largest salary." can be solved by knowing the answer to the following sub-question "What is the largest salary of instructors".
The SQL query for the sub-question "What is the largest salary of instructors" is SELECT max(salary) FROM instructor
So, the answer to the question "Find the salaries of all distinct instructors that are less than the largest salary." is =
Intermediate_representation: select  distinct instructor.salary from instructor  where  @.@ < max ( instructor.salary )
SQL: SELECT DISTINCT salary FROM instructor WHERE salary  <  (SELECT max(salary) FROM instructor)

Q: "Find the names of students who have taken any course in the fall semester of year 2003."
Schema_links: [student.id,student.name,takes.id,takes.semester,fall,2003]
A: Let's think step by step. "Find the names of students who have taken any course in the fall semester of year 2003." can be solved by knowing the answer to the following sub-question "Find the students who have taken any course in the fall semester of year 2003.".
The SQL query for the sub-question "Find the students who have taken any course in the fall semester of year 2003." is SELECT id FROM takes WHERE semester  =  'Fall' AND YEAR  =  2003
So, the answer to the question "Find the names of students who have taken any course in the fall semester of year 2003." is =
Intermediate_representation: select student.name from student  where  takes.semester = \"Fall\"  and  takes.year = 2003
SQL: SELECT name FROM student WHERE id IN (SELECT id FROM takes WHERE semester  =  'Fall' AND YEAR  =  2003)

Q: "Find the minimum salary for the departments whose average salary is above the average payment of all instructors."
Schema_links: [instructor.salary,instructor.dept_name]
A: Let's think step by step. "Find the minimum salary for the departments whose average salary is above the average payment of all instructors." can be solved by knowing the answer to the following sub-question "What is the average payment of all instructors.".
The SQL query for the sub-question "What is the average payment of all instructors." is SELECT avg(salary) FROM instructor
So, the answer to the question "Find the minimum salary for the departments whose average salary is above the average payment of all instructors." is =
Intermediate_representation: select min(instructor.salary) , instructor.dept_name from instructor  where  avg ( instructor.salary )  > avg ( instructor.salary )   group by instructor.dept_name
SQL: SELECT min(salary) ,  dept_name FROM instructor GROUP BY dept_name HAVING avg(salary)  >  (SELECT avg(salary) FROM instructor)

Q: "What is the course title of the prerequisite of course Mobile Computing?"
Schema_links: [course.title,course.course_id = prereq.course_id,prereq.prereq_id,course.title,Mobile Computing]
A: Let's think step by step. "What is the course title of the prerequisite of course Mobile Computing?" can be solved by knowing the answer to the following sub-question "What are the ids of the prerequisite of course Mobile Computing?".
The SQL query for the sub-question "What are the ids of the prerequisite of course Mobile Computing?" is SSELECT T1.prereq_id FROM prereq AS T1 JOIN course AS T2 ON T1.course_id  =  T2.course_id WHERE T2.title  =  'Mobile Computing'
So, the answer to the question "What is the course title of the prerequisite of course Mobile Computing?" is =
Intermediate_representation: select course.title from course  where  @.@ in prereq.*  and  course.title = \"Mobile Computing\"
SQL: SELECT title FROM course WHERE course_id IN (SELECT T1.prereq_id FROM prereq AS T1 JOIN course AS T2 ON T1.course_id  =  T2.course_id WHERE T2.title  =  'Mobile Computing')

Q: "Give the title and credits for the course that is taught in the classroom with the greatest capacity."
Schema_links: [classroom.capacity,classroom.building = SECTION.building,classroom.room_number = SECTION.room_number,course.title,course.credits,course.course_id = SECTION.course_id]
A: Let's think step by step. "Give the title and credits for the course that is taught in the classroom with the greatest capacity." can be solved by knowing the answer to the following sub-question "What is the capacity of the largest room?".
The SQL query for the sub-question "What is the capacity of the largest room?" is (SELECT max(capacity) FROM classroom)
So, the answer to the question "Give the title and credits for the course that is taught in the classroom with the greatest capacity." is =
Intermediate_representation: select course.title , course.credits from classroom  order by classroom.capacity desc limit 1"
SQL: SELECT T3.title ,  T3.credits FROM classroom AS T1 JOIN SECTION AS T2 ON T1.building  =  T2.building AND T1.room_number  =  T2.room_number JOIN course AS T3 ON T2.course_id  =  T3.course_id WHERE T1.capacity  =  (SELECT max(capacity) FROM classroom)

'''
#----------------------------------------------------------------------------------------------------------

# Paths for input and output
DATASET_SCHEMA = "/content/drive/MyDrive/Colab Notebooks/spider/tables.json"
DATASET = "/content/drive/MyDrive/Colab Notebooks/spider/dev.json"
OUTPUT_FILE = "./predicted_sql.txt"

API_KEY = '*****'
os.environ["OPENAI_API_KEY"] = API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")


def load_data(DATASET):
    return pd.read_json(DATASET)

def hard_prompt_maker(test_sample_text,database,schema_links,sub_questions):
  instruction = "# Use the intermediate representation and the schema links to generate the SQL queries for each of the questions.\n"
  fields = find_fields_MYSQL_like("college_2")
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like("college_2") + '\n'
  fields += find_fields_MYSQL_like(database)
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
  stepping = f'''\nA: Let's think step by step. "{test_sample_text}" can be solved by knowing the answer to the following sub-question "{sub_questions}".'''
  fields += "\n"
  prompt = instruction +fields + hard_prompt + 'Q: "' + test_sample_text + '"' + '\nschema_links: ' + schema_links + stepping +'\nThe SQL query for the sub-question"'
  return promp

def medium_prompt_maker(test_sample_text,database,schema_links):
  instruction = "# Use the the schema links and Intermediate_representation to generate the SQL queries for each of the questions.\n"
  fields = find_fields_MYSQL_like("college_2")
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like("college_2") + '\n'
  fields += find_fields_MYSQL_like(database)
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
  fields += "\n"
  prompt = instruction +fields + medium_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nA: Let’s think step by step.'
  return prompt

def easy_prompt_maker(test_sample_text,database,schema_links):
  instruction = "# Use the the schema links to generate the SQL queries for each of the questions.\n"
  fields = find_fields_MYSQL_like("college_2")
  fields += find_fields_MYSQL_like(database)
  fields += "\n"
  prompt = instruction +fields + easy_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nSQL:'
  return prompt

def classification_prompt_maker(test_sample_text,database,schema_links):
  instruction = "# For the given question, classify it as EASY, NON-NESTED, or NESTED based on nested queries and JOIN.\n"
  instruction += "\nif need nested queries: predict NESTED\n"
  instruction += "elif need JOIN and don't need nested queries: predict NON-NESTED\n"
  instruction += "elif don't need JOIN and don't need nested queries: predict EASY\n\n"
  fields = find_fields_MYSQL_like("college_2")
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like("college_2") + '\n'
  fields += find_fields_MYSQL_like(database)
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
  fields += "\n"
  prompt = instruction + fields + classification_prompt + 'Q: "' + test_sample_text + '\nschema_links: ' + schema_links + '\nA: Let’s think step by step.'
  return prompt

def schema_linking_prompt_maker(test_sample_text,database):
  instruction = "# Find the schema_links for generating SQL queries for each question based on the database schema and Foreign keys.\n"
  fields = find_fields_MYSQL_like(database)
  foreign_keys = "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
  prompt = instruction + schema_linking_prompt + fields +foreign_keys+ 'Q: "' + test_sample_text + """"\nA: Let’s think step by step."""
  return prompt

def find_foreign_keys_MYSQL_like(db_name):
  df = spider_foreign[spider_foreign['Database name'] == db_name]
  output = "["
  for index, row in df.iterrows():
    output += row['First Table Name'] + '.' + row['First Table Foreign Key'] + " = " + row['Second Table Name'] + '.' + row['Second Table Foreign Key'] + ','
  output= output[:-1] + "]"
  return output

def find_fields_MYSQL_like(db_name):
  df = spider_schema[spider_schema['Database name'] == db_name]
  df = df.groupby(' Table Name')
  output = ""
  for name, group in df:
    output += "Table " +name+ ', columns = ['
    for index, row in group.iterrows():
      output += row[" Field Name"]+','
    output = output[:-1]
    output += "]\n"
  return output
def find_primary_keys_MYSQL_like(db_name):
  df = spider_primary[spider_primary['Database name'] == db_name]
  output = "["
  for index, row in df.iterrows():
    output += row['Table Name'] + '.' + row['Primary Key'] +','
  output = output[:-1]
  output += "]\n"
  return output

def creatiing_schema(DATASET_JSON):
    schema_df = pd.read_json(DATASET_JSON)
    schema_df = schema_df.drop(['column_names','table_names'], axis=1)
    schema = []
    f_keys = []
    p_keys = []
    for index, row in schema_df.iterrows():
        tables = row['table_names_original']
        col_names = row['column_names_original']
        col_types = row['column_types']
        foreign_keys = row['foreign_keys']
        primary_keys = row['primary_keys']
        for col, col_type in zip(col_names, col_types):
            index, col_name = col
            if index == -1:
                for table in tables:
                    schema.append([row['db_id'], table, '*', 'text'])
            else:
                schema.append([row['db_id'], tables[index], col_name, col_type])
        for primary_key in primary_keys:
            index, column = col_names[primary_key]
            p_keys.append([row['db_id'], tables[index], column])
        for foreign_key in foreign_keys:
            first, second = foreign_key
            first_index, first_column = col_names[first]
            second_index, second_column = col_names[second]
            f_keys.append([row['db_id'], tables[first_index], tables[second_index], first_column, second_column])
    spider_schema = pd.DataFrame(schema, columns=['Database name', ' Table Name', ' Field Name', ' Type'])
    spider_primary = pd.DataFrame(p_keys, columns=['Database name', 'Table Name', 'Primary Key'])
    spider_foreign = pd.DataFrame(f_keys,
                        columns=['Database name', 'First Table Name', 'Second Table Name', 'First Table Foreign Key',
                                 'Second Table Foreign Key'])
    return spider_schema,spider_primary,spider_foreign

def debuger(test_sample_text,database,sql):
  instruction = """#### For the given question, use the provided tables, columns, foreign keys, and primary keys to fix the given SQLite SQL QUERY for any issues. If there are any problems, fix them. If there are no issues, return the SQLite SQL QUERY as is.
#### Use the following instructions for fixing the SQL QUERY:
1) Use the database values that are explicitly mentioned in the question.
2) Pay attention to the columns that are used for the JOIN by using the Foreign_keys.
3) Use DESC and DISTINCT when needed.
4) Pay attention to the columns that are used for the GROUP BY statement.
5) Pay attention to the columns that are used for the SELECT statement.
6) Only change the GROUP BY clause when necessary (Avoid redundant columns in GROUP BY).
7) Use GROUP BY on one column only.

"""
  fields = find_fields_MYSQL_like(database)
  fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
  fields += "Primary_keys = " + find_primary_keys_MYSQL_like(database)
  prompt = instruction + fields+ '#### Question: ' + test_sample_text + '\n#### SQLite SQL QUERY\n' + sql +'\n#### SQLite FIXED SQL QUERY\nSELECT'
  return prompt
def GPT4_generation(prompt):
  response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[{"role": "user", "content": prompt}],
    n = 1,
    stream = False,
    temperature=0.0,
    max_tokens=600,
    top_p = 1.0,
    frequency_penalty=0.0,
    presence_penalty=0.0,
    stop = ["Q:"]
  )
  return response['choices'][0]['message']['content']

def GPT4_debug(prompt):
  response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[{"role": "user", "content": prompt}],
    n = 1,
    stream = False,
    temperature=0.0,
    max_tokens=350,
    top_p = 1.0,
    frequency_penalty=0.0,
    presence_penalty=0.0,
    stop = ["#", ";","\n\n"]
  )
  return response['choices'][0]['message']['content']

if __name__ == '__main__':
    spider_schema,spider_primary,spider_foreign = creatiing_schema(DATASET_SCHEMA)
    val_df = load_data(DATASET)
    print(f"Number of data samples {val_df.shape[0]}")
    CODEX = []
    for index, row in val_df.iterrows():
        #if index < 405: continue #for testing
        print(f"index is {index}")
        print(row['query'])
        print(row['question'])
        schema_links = None
        while schema_links is None:
            try:
                schema_links = GPT4_generation(
                    schema_linking_prompt_maker(row['question'], row['db_id']))
            except:
                time.sleep(3)
                pass
        try:
            schema_links = schema_links.split("Schema_links: ")[1]
        except:
            print("Slicing error for the schema_linking module")
            schema_links = "[]"
        #print(schema_links)
        classification = None
        while classification is None:
            try:
                classification = GPT4_generation(
                    classification_prompt_maker(row['question'], row['db_id'], schema_links[1:]))
            except:
                time.sleep(3)
                pass
        try:
            predicted_class = classification.split("Label: ")[1]
        except:
            print("Slicing error for the classification module")
            predicted_class = '"NESTED"'
        #print(classification)
        if '"EASY"' in predicted_class:
            print("EASY")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(easy_prompt_maker(row['question'], row['db_id'], schema_links))
                except:
                    time.sleep(3)
                    pass
        elif '"NON-NESTED"' in predicted_class:
            print("NON-NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(medium_prompt_maker(row['question'], row['db_id'], schema_links))
                except:
                    time.sleep(3)
                    pass
            try:
                SQL = SQL.split("SQL: ")[1]
            except:
                print("SQL slicing error")
                SQL = "SELECT"
        else:
            sub_questions = classification.split('questions = ["')[1].split('"]')[0]
            print("NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(
                        hard_prompt_maker(row['question'], row['db_id'], schema_links, sub_questions))
                except:
                    time.sleep(3)
                    pass
            try:
                SQL = SQL.split("SQL: ")[1]
            except:
                print("SQL slicing error")
                SQL = "SELECT"
        print(SQL)
        debugged_SQL = None
        while debugged_SQL is None:
            try:
                debugged_SQL = GPT4_debug(debuger(row['question'], row['db_id'], SQL)).replace("\n", " ")
            except:
                time.sleep(3)
                pass
        SQL = "SELECT " + debugged_SQL
        print(SQL)
        CODEX.append([row['question'], SQL, row['query'], row['db_id']])
        #break
    df = pd.DataFrame(CODEX, columns=['NLQ', 'PREDICTED SQL', 'GOLD SQL', 'DATABASE'])
    results = df['PREDICTED SQL'].tolist()
    with open(OUTPUT_FILE, 'w') as f:
        for line in results:
            f.write(f"{line}\n")
# Out:
# Number of data samples 1034
# index is 0
# SELECT count(*) FROM singer
# How many singers do we have?
# EASY
# SELECT COUNT(*) FROM singer
# SELECT COUNT(*) FROM singer
# index is 1
# SELECT count(*) FROM singer
# What is the total number of singers?
# EASY
# SELECT COUNT(*) FROM singer
# SELECT COUNT(*) FROM singer
# index is 2
# SELECT name ,  country ,  age FROM singer ORDER BY age DESC
# Show name, country, age for all singers ordered by age from the oldest to the youngest.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-5-2a41d1cd4afe> in <cell line: 608>()
#     620             try:
# --> 621                 schema_links = GPT4_generation(
#     622                     schema_linking_prompt_maker(row['question'], row['db_id']))
#
# <ipython-input-5-2a41d1cd4afe> in GPT4_generation(prompt)
#     578 def GPT4_generation(prompt):
# --> 579   response = openai.ChatCompletion.create(
#     580     model="gpt-4",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     764         if stream_error or not 200 <= rcode < 300:
# --> 765             raise self.handle_error_response(
#     766                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#
# RateLimitError: Rate limit reached for gpt-4 in organization org-0eJNxMV08WG3vx2VlS2KNZEg on tokens per min (TPM): Limit 10000, Used 6365, Requested 5196. Please try again in 9.366s. Visit https://platform.openai.com/account/rate-limits to learn more.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2a41d1cd4afe> in <cell line: 608>()
#     622                     schema_linking_prompt_maker(row['question'], row['db_id']))
#     623             except:
# --> 624                 time.sleep(3)
#     625                 pass
#     626         try:
#
# KeyboardInterrupt:

# %% [markdown]
# # **Zero-Shot Promting (GPT 3.5 Turbo)**
#
# In this part we just check Zero-shot prompting (We didn't give any resonable result, so we don't used this technique)

# %%
import pandas as pd
import time
import openai
import os
import json

# Set your OpenAI API key
API_KEY = '****'
os.environ["OPENAI_API_KEY"] = API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")

# Paths for input and output
DATASET_SCHEMA = "/content/drive/MyDrive/Colab Notebooks/data_usage/dev_tables.json"
DATASET = "/content/drive/MyDrive/Colab Notebooks/data_usage/sampled_dev.json"
OUTPUT_FILE = "./predicted_sql.txt"

# %%
def load_data(dataset_path):
    return pd.read_json(dataset_path)

def create_schema_prompts(schema_json_path, db_id):
    with open(schema_json_path, 'r') as f:
        schema_json = json.load(f)

    schema_prompts = ""
    for db in schema_json:
        if db['db_id'] == db_id:
            tables = []
            foreign_keys = []

            for table in db['table_names_original']:
                col_list = [col[1] for col in db['column_names_original'] if col[0] == db['table_names_original'].index(table)]
                tables.append(f"Table {table}, columns = [{', '.join(col_list)}]")

            for fk in db['foreign_keys']:
                print(f"Foreign key structure: {fk}")  # Debug statement
                if len(fk) == 4:
                    first_table_index = fk[0]
                    first_column_index = fk[1]
                    second_table_index = fk[2]
                    second_column_index = fk[3]
                    first_table = db['table_names_original'][first_table_index]
                    first_column = db['column_names_original'][first_column_index][1]
                    second_table = db['table_names_original'][second_table_index]
                    second_column = db['column_names_original'][second_column_index][1]
                    foreign_keys.append(f"{first_table}.{first_column} = {second_table}.{second_column}")
                else:
                    print(f"Unexpected foreign key structure: {fk}")

            schema_prompts += "\n".join(tables) + "\nForeign_keys = [" + ", ".join(foreign_keys) + "]\n"
            break

    print(f"Schema prompts for db_id {db_id}:\n{schema_prompts}\n")  # Debug statement
    return schema_prompts

def generate_sql(question, schema_prompts):
    prompt = f"""
    You are a helpful assistant that produces SQL Queries from the given question and related samples. You should output a SQL query that is syntactically correct and can be executed without error. In the input, you will receive the question and similar text-to-sql pairs. Please output in the following format so it would be easy to extract SQL query:
    ```sql
    SELECT T2.name,  count(*) FROM exhibition AS T1 JOIN artist AS T2 ON T1.artist_id  =  T2.artist_id GROUP BY T1.artist_id;
    ```

    Question: {question}
    {schema_prompts}
    SQL:
    """

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "system", "content": "You are a SQL expert."},
                  {"role": "user", "content": prompt}],
        max_tokens=150,
        n=1,
        stop=["```"],
        temperature=0.0
    )

    return response['choices'][0]['message']['content'].strip()

if __name__ == '__main__':
    # Load the dataset
    val_df = load_data(DATASET)
    print(f"Number of data samples: {val_df.shape[0]}")

    results = []
    for index, row in val_df.head(10).iterrows():  # Limiting to the first 10 samples for initial testing
        question = row['question']
        db_id = row['db_id']
        print(f"Processing index {index}: {question}")

        schema_prompts = create_schema_prompts(DATASET_SCHEMA, db_id)

        sql_query = None
        while sql_query is None or sql_query.strip() == "":
            try:
                sql_query = generate_sql(question, schema_prompts)
            except Exception as e:
                print(f"Error generating SQL query: {e}")
                time.sleep(3)
                pass

        results.append([question, sql_query, row['query'], row['db_id']])
        print(f"Generated SQL: {sql_query}\n")

    # Save the results to a file
    with open(OUTPUT_FILE, 'w') as f:
        for result in results:
            f.write(f"{result[1]}\n")

    # Save results in a DataFrame for further analysis if needed
    df = pd.DataFrame(results, columns=['NLQ', 'PREDICTED SQL', 'GOLD SQL', 'DATABASE'])
    df.to_csv('results.csv', index=False)
# Out:
# Number of data samples: 300
# Processing index 0: Find the name of the sailors who reserved boat with id 103.
# Foreign key structure: [9, 5]
# Unexpected foreign key structure: [9, 5]
# Foreign key structure: [8, 1]
# Unexpected foreign key structure: [8, 1]
# Schema prompts for db_id boat_1:
# Table Sailors, columns = [sid, name, rating, age]
# Table Boats, columns = [bid, name, color]
# Table Reserves, columns = [sid, bid, day]
# Foreign_keys = []

# %% [markdown]
# # **Few-Shot Promting - GPT-3.5 Turbo**
# The main result of our project here.
#
# after run the script ther result saved in a `.txt` file then test it using https://github.com/taoyds/test-suite-sql-eval script.

# %%
import pandas as pd
import time
import openai
import os
import json

# Set your OpenAI API key
API_KEY = '******'
os.environ["OPENAI_API_KEY"] = API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")

# Paths for input and output
DATASET_SCHEMA = "/content/drive/MyDrive/Colab Notebooks/data_usage/dev_tables.json"
DATASET = "/content/drive/MyDrive/Colab Notebooks/data_usage/sampled_dev.json"
OUTPUT_FILE = "./predicted_sql.txt"

def load_data(DATASET):
    return pd.read_json(DATASET)

def hard_prompt_maker(test_sample_text, database, schema_links, sub_questions):
    instruction = "# Use the intermediate representation and the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    stepping = f'''\nA: Let's think step by step. "{test_sample_text}" can be solved by knowing the answer to the following sub-question "{sub_questions}".'''
    fields += "\n"
    prompt = instruction + fields + hard_prompt + 'Q: "' + test_sample_text + '"' + '\nschema_links: ' + schema_links + stepping + '\nThe SQL query for the sub-question'
    return prompt

def medium_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links and Intermediate_representation to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + medium_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def easy_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "\n"
    prompt = instruction + fields + easy_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nSQL:'
    return prompt

def classification_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# For the given question, classify it as EASY, NON-NESTED, or NESTED based on nested queries and JOIN.\n"
    instruction += "\nif need nested queries: predict NESTED\n"
    instruction += "elif need JOIN and don't need nested queries: predict NON-NESTED\n"
    instruction += "elif don't need JOIN and don't need nested queries: predict EASY\n\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + classification_prompt + 'Q: "' + test_sample_text + '\nschema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def schema_linking_prompt_maker(test_sample_text, database):
    instruction = "# Find the schema_links for generating SQL queries for each question based on the database schema and Foreign keys.\n"
    fields = find_fields_MYSQL_like(database)
    foreign_keys = "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    prompt = instruction + schema_linking_prompt + fields + foreign_keys + 'Q: "' + test_sample_text + """"\nA: Let’s think step by step."""
    return prompt

def find_foreign_keys_MYSQL_like(db_name):
    df = spider_foreign[spider_foreign['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['First Table Name'] + '.' + row['First Table Foreign Key'] + " = " + row['Second Table Name'] + '.' + row['Second Table Foreign Key'] + ','
    output = output[:-1] + "]"
    return output

def find_fields_MYSQL_like(db_name):
    df = spider_schema[spider_schema['Database name'] == db_name]
    df = df.groupby(' Table Name')
    output = ""
    for name, group in df:
        output += "Table " + name + ', columns = ['
        for index, row in group.iterrows():
            output += row[" Field Name"] + ','
        output = output[:-1]
        output += "]\n"
    return output

def find_primary_keys_MYSQL_like(db_name):
    df = spider_primary[spider_primary['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['Table Name'] + '.' + row['Primary Key'] + ','
    output = output[:-1]
    output += "]\n"
    return output

def creating_schema(DATASET_JSON):
    schema_df = pd.read_json(DATASET_JSON)
    schema_df = schema_df.drop(['column_names', 'table_names'], axis=1)
    schema = []
    f_keys = []
    p_keys = []
    for index, row in schema_df.iterrows():
        tables = row['table_names_original']
        col_names = row['column_names_original']
        col_types = row['column_types']
        foreign_keys = row['foreign_keys']
        primary_keys = row['primary_keys']
        for col, col_type in zip(col_names, col_types):
            index, col_name = col
            if index == -1:
                for table in tables:
                    schema.append([row['db_id'], table, '*', 'text'])
            else:
                schema.append([row['db_id'], tables[index], col_name, col_type])
        for primary_key in primary_keys:
            index, column = col_names[primary_key]
            p_keys.append([row['db_id'], tables[index], column])
        for foreign_key in foreign_keys:
            first, second = foreign_key
            first_index, first_column = col_names[first]
            second_index, second_column = col_names[second]
            f_keys.append([row['db_id'], tables[first_index], tables[second_index], first_column, second_column])
    spider_schema = pd.DataFrame(schema, columns=['Database name', ' Table Name', ' Field Name', ' Type'])
    spider_primary = pd.DataFrame(p_keys, columns=['Database name', 'Table Name', 'Primary Key'])
    spider_foreign = pd.DataFrame(f_keys,
                                  columns=['Database name', 'First Table Name', 'Second Table Name', 'First Table Foreign Key',
                                           'Second Table Foreign Key'])
    return spider_schema, spider_primary, spider_foreign

def debuger(test_sample_text, database, sql):
    instruction = """#### For the given question, use the provided tables, columns, foreign keys, and primary keys to fix the given SQLite SQL QUERY for any issues. If there are any problems, fix them. If there are no issues, return the SQLite SQL QUERY as is.
#### Use the following instructions for fixing the SQL QUERY:
1) Use the database values that are explicitly mentioned in the question.
2) Pay attention to the columns that are used for the JOIN by using the Foreign_keys.
3) Use DESC and DISTINCT when needed.
4) Pay attention to the columns that are used for the GROUP BY statement.
5) Pay attention to the columns that are used for the SELECT statement.
6) Only change the GROUP BY clause when necessary (Avoid redundant columns in GROUP BY).
7) Use GROUP BY on one column only.

"""
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "Primary_keys = " + find_primary_keys_MYSQL_like(database)
    prompt = instruction + fields + '#### Question: ' + test_sample_text + '\n#### SQLite SQL QUERY\n' + sql + '\n#### SQLite FIXED SQL QUERY\nSELECT'
    return prompt

def GPT4_generation(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            n=1,
            stream=False,
            temperature=0.0,
            max_tokens=600,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0,
            stop=["Q:"]
        )
        return response['choices'][0]['message']['content']
    except Exception as e:
        print(f"Error during GPT-3.5-turbo call: {e}")
        return None

def GPT4_debug(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            n=1,
            stream=False,
            temperature=0.0,
            max_tokens=350,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0,
            stop=["#", ";", "\n\n"]
        )
        return response['choices'][0]['message']['content']
    except Exception as e:
        print(f"Error during GPT-3.5-turbo debug call: {e}")
        return None

if __name__ == '__main__':
    spider_schema, spider_primary, spider_foreign = creating_schema(DATASET_SCHEMA)
    val_df = load_data(DATASET)
    print(f"Number of data samples {val_df.shape[0]}")
    CODEX = []

    for index, row in val_df.iterrows():
        print(f"Processing index {index}")
        print(row['query'])
        print(row['question'])

        schema_links = None
        while schema_links is None:
            try:
                schema_links = GPT4_generation(schema_linking_prompt_maker(row['question'], row['db_id']))
            except Exception as e:
                print(f"Error getting schema links for index {index}: {e}")
                time.sleep(3)

        try:
            schema_links = schema_links.split("Schema_links: ")[1]
        except Exception as e:
            print(f"Slicing error for the schema_linking module at index {index}: {e}")
            schema_links = "[]"

        classification = None
        while classification is None:
            try:
                classification = GPT4_generation(classification_prompt_maker(row['question'], row['db_id'], schema_links[1:]))
            except Exception as e:
                print(f"Error during classification at index {index}: {e}")
                time.sleep(3)

        try:
            predicted_class = classification.split("Label: ")[1]
        except Exception as e:
            print(f"Slicing error for the classification module at index {index}: {e}")
            predicted_class = '"NESTED"'

        if '"EASY"' in predicted_class:
            print("EASY")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(easy_prompt_maker(row['question'], row['db_id'], schema_links))
                except Exception as e:
                    print(f"Error generating easy SQL at index {index}: {e}")
                    time.sleep(10)

        elif '"NON-NESTED"' in predicted_class:
            print("NON-NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(medium_prompt_maker(row['question'], row['db_id'], schema_links))
                except Exception as e:
                    print(f"Error generating medium SQL at index {index}: {e}")
                    time.sleep(10)

            try:
                SQL = SQL.split("SQL: ")[1]
            except Exception as e:
                print(f"SQL slicing error at index {index}: {e}")
                SQL = "SELECT"
        else:
            try:
                sub_questions = classification.split('questions = ["')[1].split('"]')[0]
            except Exception as e:
                print(f"Sub-questions slicing error at index {index}: {e}")
                sub_questions = ""

            print("NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = GPT4_generation(hard_prompt_maker(row['question'], row['db_id'], schema_links, sub_questions))
                except Exception as e:
                    print(f"Error generating hard SQL at index {index}: {e}")
                    time.sleep(10)

            try:
                SQL = SQL.split("SQL: ")[1]
            except Exception as e:
                print(f"SQL slicing error at index {index}: {e}")
                SQL = "SELECT"

        print(SQL)
        debugged_SQL = None
        while debugged_SQL is None:
            try:
                debugged_SQL = GPT4_debug(debuger(row['question'], row['db_id'], SQL)).replace("\n", " ")
            except Exception as e:
                print(f"Error during SQL debugging at index {index}: {e}")
                time.sleep(3)

        SQL = "SELECT " + debugged_SQL
        print(SQL)
        CODEX.append([row['question'], SQL, row['query'], row['db_id']])

    df = pd.DataFrame(CODEX, columns=['NLQ', 'PREDICTED SQL', 'GOLD SQL', 'DATABASE'])
    results = df['PREDICTED SQL'].tolist()
    with open(OUTPUT_FILE, 'w') as f:
        for line in results:
            f.write(f"{line}\n")
# Out:
# Number of data samples 300
# Processing index 0
# SELECT DISTINCT T1.name FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid  =  T2.sid WHERE  T2.bid  =  103
# Find the name of the sailors who reserved boat with id 103.
# NON-NESTED
# SELECT T1.name FROM Sailors AS T1 WHERE T1.sid IN (SELECT T2.sid FROM Reserves AS T2 WHERE T2.bid = 103)
# SELECT  T1.name  FROM Sailors AS T1  JOIN Reserves AS T2 ON T1.sid = T2.sid WHERE T2.bid = 103
# Processing index 1
# SELECT T1.name FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid  =  T2.sid JOIN Boats AS T3 ON T3.bid  =  T2.bid WHERE T3.name  =  'Melon'
# What are the names of sailors who reserved a boat with the name Melon?
# NON-NESTED
# SELECT T1.name FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid = T2.sid JOIN Boats AS T3 ON T2.bid = T3.bid WHERE T3.name = 'Melon'
# SELECT  T1.name  FROM Sailors AS T1  JOIN Reserves AS T2 ON T1.sid = T2.sid  JOIN Boats AS T3 ON T2.bid = T3.bid  WHERE T3.name = 'Melon'
# Processing index 2
# SELECT avg(Units_sold_Millions) FROM game AS T1 JOIN game_player AS T2 ON T1.Game_ID  =  T2.Game_ID JOIN player AS T3 ON T2.Player_ID  =  T3.Player_ID WHERE T3.Position  =  "Guard"
# What is the average number of units sold in millions of games played by players with position "Guard"?
# NON-NESTED
# SELECT AVG(T1.Units_sold_Millions) FROM game AS T1 JOIN game_player AS T2 ON T1.Game_ID = T2.Game_ID JOIN player AS T3 ON T2.Player_ID = T3.Player_ID WHERE T3.Position = 'Guard'
# SELECT  AVG(T1.Units_sold_Millions)  FROM game AS T1  JOIN game_player AS T2 ON T1.Game_ID = T2.Game_ID  JOIN player AS T3 ON T2.Player_ID = T3.Player_ID  WHERE T3.Position = 'Guard'
# Processing index 3
# SELECT DISTINCT T4.Collection_Name FROM Collection_Subset_Members AS T1 JOIN Collection_Subset_Members AS T2 ON T1.Related_Collection_ID = T2.Collection_ID JOIN Collections AS T3 ON T1.Collection_ID = T3.Collection_ID JOIN Collections AS T4 ON T2.Collection_ID = T4.Collection_ID WHERE T3.Collection_Name = "Best";
# What are the names of the collections that are related to the collection named Best?
# NON-NESTED
# SELECT T1.Collection_Name FROM Collections AS T1 JOIN Collection_Subsets AS T2 ON T1.Collection_ID = T2.Related_Collection_ID WHERE T2.Collection_Subset_Name = 'Best'
# SELECT  T1.Collection_Name  FROM Collections AS T1  JOIN Collection_Subsets AS T2 ON T1.Collection_ID = T2.Related_Collection_ID  WHERE T2.Collection_Subset_Name = 'Best'
# Processing index 4
# SELECT analytical_layer_type_code FROM analytical_layer GROUP BY analytical_layer_type_code ORDER BY count(*) DESC LIMIT 1
# Find the analytical layer type code that appears most often.
# EASY
# SELECT Analytical_Layer_Type_Code FROM Analytical_Layer GROUP BY Analytical_Layer_Type_Code ORDER BY COUNT(Analytical_Layer_Type_Code) DESC LIMIT 1
# SELECT Analytical_Layer_Type_Code FROM Analytical_Layer GROUP BY Analytical_Layer_Type_Code ORDER BY COUNT(*) DESC LIMIT 1
# Processing index 5
# SELECT Nationality ,  COUNT(*) FROM customer GROUP BY Nationality
# How many customers are associated with each nationality? List the nationality and the number of customers.
# EASY
# SELECT Nationality, COUNT(Customer_ID) FROM customer GROUP BY Nationality
# SELECT  Nationality, COUNT(Customer_ID) FROM customer GROUP BY Nationality
# Processing index 6
# SELECT T1.customer_id ,  T2.customer_name ,  T2.customer_phone ,  T2.customer_email FROM Customer_orders AS T1 JOIN Customers AS T2 ON T1.customer_id  =  T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# Give the id, name, phone, and email corresponding to the customer who made the most orders.
# NON-NESTED
# SELECT T1.customer_id ,  T1.customer_name ,  T1.customer_phone ,  T1.customer_email FROM Customers AS T1 WHERE T1.customer_id = (SELECT customer_id FROM Customer_Orders GROUP BY customer_id ORDER BY count(order_id) DESC LIMIT 1)
# SELECT T1.customer_id, T1.customer_name, T1.customer_phone, T1.customer_email  FROM Customers AS T1  WHERE T1.customer_id = (     SELECT customer_id      FROM Customer_Orders      GROUP BY customer_id      ORDER BY COUNT(order_id) DESC      LIMIT 1 )
# Processing index 7
# SELECT name FROM staff WHERE age  >  (SELECT avg(age) FROM staff)
# Show all staff name who are above the average age.
# EASY
# SELECT name FROM staff WHERE Age > (SELECT AVG(Age) FROM staff)
# SELECT  name  FROM staff  WHERE Age > (SELECT AVG(Age) FROM staff)
# Processing index 8
# SELECT T1.invoice_id ,  T2.invoice_status ,  T2.invoice_details FROM Payments AS T1 JOIN Invoices AS T2 ON T1.invoice_id  =  T2.invoice_id GROUP BY T1.invoice_id ORDER BY count(*) DESC LIMIT 1
# What is the invoice id, status code, and details for the invoice with most number of payments.
# NON-NESTED
# SELECT T1.invoice_id, T1.invoice_status, T1.invoice_details FROM Invoices AS T1 JOIN Payments AS T2 ON T1.invoice_id = T2.invoice_id GROUP BY T1.invoice_id, T1.invoice_status, T1.invoice_details ORDER BY COUNT(T2.invoice_id) DESC LIMIT 1
# SELECT  T1.invoice_id, T1.invoice_status, T1.invoice_details  FROM Invoices AS T1  JOIN Payments AS T2 ON T1.invoice_id = T2.invoice_id  GROUP BY T1.invoice_id, T1.invoice_status, T1.invoice_details  ORDER BY COUNT(T2.payment_id) DESC  LIMIT 1
# Processing index 9
# SELECT product_name FROM Products WHERE product_price  >  (SELECT avg(product_price) FROM Products)
# Show all product names with price higher than the average.
# EASY
# SELECT product_name FROM Products WHERE product_price > (SELECT AVG(product_price) FROM Products)
# SELECT  product_name  FROM Products  WHERE product_price > (SELECT AVG(product_price) FROM Products)
# Processing index 10
# SELECT sum(T1.Weight) FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Sender  =  T2.AccountNumber WHERE T2.Name  =  "Leo Wong";
# What is the total weight for all packages that Leo Wong sent?
# NON-NESTED
# SELECT SUM(T1.Weight) FROM Package AS T1 JOIN Client AS T2 ON T1.Sender = T2.AccountNumber WHERE T2.Name = 'Leo Wong'
# SELECT  SUM(T1.Weight)  FROM Package AS T1  JOIN Client AS T2 ON T1.Sender = T2.AccountNumber  WHERE T2.Name = 'Leo Wong'
# Processing index 11
# SELECT pilot_name ,  age FROM pilotskills WHERE plane_name  =  'Piper Cub' AND age  >  35 UNION SELECT pilot_name ,  age FROM pilotskills WHERE plane_name  =  'F-14 Fighter' AND age  <  30
# Return the names and ages of pilors who have flown Piper Cub and are older than 35, or have flown the F-14 Fighter and are younger than 30.
# NON-NESTED
#
# ```
# SELECT pilot_name, age
# FROM PilotSkills
# JOIN Hangar ON PilotSkills.plane_name = Hangar.plane_name
# WHERE (PilotSkills.plane_name = 'Piper Cub' AND age > 35)
# OR (PilotSkills.plane_name = 'F-14 Fighter' AND age < 30)
# ```
# SELECT  pilot_name, age  FROM PilotSkills  JOIN Hangar ON PilotSkills.plane_name = Hangar.plane_name  WHERE (PilotSkills.plane_name = 'Piper Cub' AND age > 35)  OR (PilotSkills.plane_name = 'F-14 Fighter' AND age < 30)
# Processing index 12
# SELECT client_id FROM Invoices GROUP BY client_id HAVING count(*)  >=  2
# What are client ids for clients with at least 2 invoices.
# NON-NESTED
# SELECT client_id FROM Invoices GROUP BY client_id HAVING COUNT(*) >= 2
# SELECT  client_id  FROM Invoices  GROUP BY client_id  HAVING COUNT(*) >= 2
# Processing index 13
# SELECT DISTINCT T1.Document_Subset_Name FROM Document_Subsets AS T1 JOIN Document_Subset_Members AS T2 ON T1.Document_Subset_ID =  T2.Document_Subset_ID JOIN Document_Objects AS T3 ON T2.Document_Object_ID  =  T3.Document_Object_ID WHERE T3.owner  =  'Braeden'
# Which unique subset does document owned by Braeden belong to? List the subset name.
# NON-NESTED
# SELECT DISTINCT T3.Collection_Subset_Name FROM Document_Objects AS T1 JOIN Document_Subset_Members AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID JOIN Document_Subsets AS T3 ON T2.Document_Subset_ID = T3.Document_Subset_ID WHERE T1.Owner = 'Braeden'
# SELECT  DISTINCT T3.Collection_Subset_Name  FROM Document_Objects AS T1  JOIN Document_Subset_Members AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID  JOIN Document_Subsets AS T3 ON T2.Document_Subset_ID = T3.Document_Subset_ID  WHERE T1.Owner = 'Braeden'
# Processing index 14
# SELECT avg(distance) FROM Direct_distance AS T1 JOIN City AS T2 ON T1.city1_code  =  T2.city_code WHERE T2.city_name  =  "Boston"
# What is the average distance between Boston and all other cities.
# NON-NESTED
# SELECT AVG(T1.distance) FROM Direct_distance AS T1 WHERE T1.city1_code = (SELECT T2.city_code FROM City AS T2 WHERE T2.city_name = 'Boston')
# SELECT  AVG(T1.distance)  FROM Direct_distance AS T1  JOIN City AS T2 ON T1.city2_code = T2.city_code JOIN City AS T3 ON T1.city1_code = T3.city_code WHERE T3.city_name = 'Boston'
# Processing index 15
# SELECT count(DISTINCT T1.code) FROM movies AS T1 JOIN movietheaters AS T2 ON T1.code  =  T2.movie
# How many distinct movies are on in theaters?
# NON-NESTED
# SELECT count(DISTINCT T1.Title) FROM Movies AS T1 JOIN MovieTheaters AS T2 ON T1.Code = T2.Movie
# SELECT  count(DISTINCT T1.Title) FROM Movies AS T1 JOIN MovieTheaters AS T2 ON T1.Code = T2.Movie
# Processing index 16
# SELECT T2.age_category_code FROM Ref_User_Categories AS T1 JOIN Users AS T2 ON T1.user_category_code  =  T2.user_category_code WHERE T1.User_category_description LIKE "%Mother";
# For users whose description contain the string 'Mother', which age categories are they in?
# NON-NESTED
# SELECT DISTINCT T1.user_id ,  T2.age_category_code FROM Users AS T1 JOIN Ref_Age_Categories AS T2 ON T1.other_user_details LIKE '%Mother%'
# SELECT  T2.age_category_code  FROM Users AS T1  JOIN Ref_Age_Categories AS T2 ON T1.age_category_code = T2.age_category_code WHERE T1.other_user_details LIKE '%Mother%'
# Processing index 17
# SELECT isbn ,  count(*) FROM Books_Order GROUP BY isbn
# What are all isbns for each book, and how many times has each been ordered?
# NON-NESTED
# SELECT T1.ISBN , SUM(T2.amount) FROM Book AS T1 JOIN Books_Order AS T2 ON T1.ISBN = T2.ISBN GROUP BY T1.ISBN
# SELECT  T1.ISBN, SUM(T2.amount)  FROM Book AS T1  JOIN Books_Order AS T2 ON T1.ISBN = T2.ISBN  GROUP BY T1.ISBN
# Processing index 18
# SELECT T1.pilot_name FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  "Austin" INTERSECT SELECT T1.pilot_name FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.LOCATION  =  "Boston"
# What are the names of pilots who have planes in both Austin and Boston?
# NESTED
# SELECT pilot_name FROM PilotSkills WHERE plane_name IN (SELECT plane_name FROM Hangar WHERE location = 'Austin') AND plane_name IN (SELECT plane_name FROM Hangar WHERE location = 'Boston')
# SELECT  pilot_name  FROM PilotSkills  WHERE plane_name IN (SELECT plane_name FROM Hangar WHERE location = 'Austin')  AND pilot_name IN (SELECT pilot_name FROM PilotSkills WHERE plane_name IN (SELECT plane_name FROM Hangar WHERE location = 'Boston'))
# Processing index 19
# SELECT t1.name ,  t1.gender FROM author AS t1 JOIN book AS t2 ON t1.author_id  =  t2.author_id GROUP BY t2.author_id ORDER BY count(*) DESC LIMIT 1
# Who wrote the largest number of books? Give me the author name and gender.
# NON-NESTED
# SELECT T1.Name ,  T1.Gender FROM author AS T1 JOIN book AS T2 ON T1.Author_ID  =  T2.Author_ID GROUP BY T1.Name, T1.Gender ORDER BY COUNT(T2.Book_ID) DESC LIMIT 1
# SELECT  T1.Name, T1.Gender  FROM author AS T1  JOIN book AS T2 ON T1.Author_ID = T2.Author_ID  GROUP BY T1.Name, T1.Gender  ORDER BY COUNT(T2.Book_ID) DESC  LIMIT 1
# Processing index 20
# SELECT 	count(DISTINCT T1.pilot_name) FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  'Chicago'
# Count the number of pilots who have planes in Chicago.
# NON-NESTED
# SELECT count(DISTINCT T1.pilot_name) FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name = T2.plane_name WHERE T2.location = 'Chicago'
# SELECT  count(DISTINCT T1.pilot_name) FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name = T2.plane_name WHERE T2.location = 'Chicago' GROUP BY T1.pilot_name
# Processing index 21
# SELECT t1.customer_details FROM customers AS t1 JOIN customers_and_services AS t2 ON t1.customer_id  =  t2.customer_id GROUP BY t1.customer_details ORDER BY count(*) DESC LIMIT 1
# Find the details of the customer who has used services the most times.
# NON-NESTED
# SELECT Customer_Details FROM Customers WHERE Customer_ID = (SELECT Customer_ID FROM Customer_Interactions GROUP BY Customer_ID ORDER BY COUNT(*) DESC LIMIT 1)
# SELECT  Customer_Details  FROM Customers  WHERE Customer_ID = (     SELECT Customer_ID      FROM Customer_Interactions      GROUP BY Customer_ID      ORDER BY COUNT(*) DESC      LIMIT 1 )
# Processing index 22
# SELECT T3.CustomerId FROM goods AS T1 JOIN items AS T2 ON T1.id  =  T2.item JOIN receipts AS T3 ON T2.receipt  =  T3.ReceiptNumber GROUP BY T3.CustomerId HAVING avg(T1.price)  >  5
# What are the ids of customers who spend more than 5 on average for each good?
# NON-NESTED
# SELECT DISTINCT T1.Id FROM customers AS T1 JOIN receipts AS T2 ON T1.Id = T2.CustomerId JOIN items AS T3 ON T2.ReceiptNumber = T3.Receipt JOIN goods AS T4 ON T3.Item = T4.Id GROUP BY T1.Id HAVING AVG(T4.Price) > 5
# SELECT  T1.Id  FROM customers AS T1  JOIN receipts AS T2 ON T1.Id = T2.CustomerId  JOIN items AS T3 ON T2.ReceiptNumber = T3.Receipt  JOIN goods AS T4 ON T3.Item = T4.Id  GROUP BY T1.Id  HAVING AVG(T4.Price) > 5
# Processing index 23
# SELECT product_name FROM Products EXCEPT SELECT T1.product_name FROM Products AS t1 JOIN Order_items AS T2 ON T1.product_id  =  T2.product_id
# Show all product names without an order.
# NON-NESTED
# SELECT product_name FROM Products LEFT JOIN Order_Items ON Products.product_id = Order_Items.product_id WHERE Order_Items.product_id IS NULL
# SELECT  product_name  FROM Products  LEFT JOIN Order_Items ON Products.product_id = Order_Items.product_id  WHERE Order_Items.product_id IS NULL
# Processing index 24
# select document_object_id , count(*) from document_subset_members group by document_object_id having count(*) between 2 and 4;
# Which document has between 2 and 4 number of documents ? List the document id and the number of related documents .
# EASY
# SELECT Document_Object_ID, COUNT(Related_Document_Object_ID) AS Number_of_Related_Documents
# FROM Document_Subset_Members
# GROUP BY Document_Object_ID
# HAVING COUNT(Related_Document_Object_ID) BETWEEN 2 AND 4
# SELECT  Document_Object_ID, COUNT(Related_Document_Object_ID) AS Number_of_Related_Documents FROM Document_Subset_Members GROUP BY Document_Object_ID HAVING COUNT(Related_Document_Object_ID) BETWEEN 2 AND 4
# Processing index 25
# SELECT T1.detention_type_code ,  T2.detention_type_description FROM Detention AS T1 JOIN Ref_Detention_Type AS T2 ON T1.detention_type_code  =  T2.detention_type_code GROUP BY T1.detention_type_code ORDER BY count(*) ASC LIMIT 1
# Give me the type code and description of the least common detention type.
# NON-NESTED
# SELECT T1.detention_type_code ,  T2.detention_type_description FROM Detention AS T1 JOIN Ref_Detention_Type AS T2 ON T1.detention_type_code  =  T2.detention_type_code GROUP BY T1.detention_type_code, T2.detention_type_description ORDER BY COUNT(*) ASC LIMIT 1
# SELECT  T1.detention_type_code, T2.detention_type_description  FROM Detention AS T1  JOIN Ref_Detention_Type AS T2 ON T1.detention_type_code = T2.detention_type_code  GROUP BY T1.detention_type_code, T2.detention_type_description  ORDER BY COUNT(*)  LIMIT 1
# Processing index 26
# SELECT Student_Answer_Text FROM Student_Answers GROUP BY Student_Answer_Text ORDER BY COUNT(*) DESC
# List all the student answer texts in descending order of count.
# EASY
# SELECT Student_Answer_Text, COUNT(*) AS count FROM Student_Answers GROUP BY Student_Answer_Text ORDER BY count DESC
# SELECT  Student_Answer_Text, COUNT(*) AS count  FROM Student_Answers  GROUP BY Student_Answer_Text  ORDER BY count DESC
# Processing index 27
# SELECT Collection_Name FROM Collections EXCEPT SELECT T2.Collection_Name FROM Collections AS T1 JOIN Collections AS T2 ON T1.Parent_Collection_ID = T2.Collection_ID;
# Which collection is not the parent of other collection? List the collection's name.
# EASY
# SELECT Collection_Name
# FROM Collections
# WHERE Collection_ID NOT IN (SELECT DISTINCT Parent_Collection_ID FROM Collections)
# SELECT  Collection_Name  FROM Collections  WHERE Collection_ID NOT IN (SELECT DISTINCT Parent_Collection_ID FROM Collections)
# Processing index 28
# SELECT T1.Name ,  T2.Dish_Name FROM customer AS T1 JOIN customer_order AS T2 ON T1.Customer_ID  =  T2.Customer_ID
# For each order, return the customer name and the dish name.
# NON-NESTED
# SELECT T2.Name ,  T1.Dish_Name FROM customer_order AS T1 JOIN customer AS T2 ON T1.Customer_ID  =  T2.Customer_ID
# SELECT  T2.Name, T1.Dish_Name  FROM customer_order AS T1  JOIN customer AS T2 ON T1.Customer_ID = T2.Customer_ID
# Processing index 29
# SELECT T1.lname ,  T1.fname FROM artists AS T1 JOIN paintings AS T2 ON T1.artistID  =  T2.painterID EXCEPT SELECT T3.lname ,  T3.fname FROM artists AS T3 JOIN sculptures AS T4 ON T3.artistID  =  T4.sculptorID
# What are the first and last names of the artists who did not sculpt but could paint.
# NON-NESTED
# SELECT fname, lname FROM Artists WHERE artistID NOT IN (SELECT sculptorID FROM Sculptures) AND artistID IN (SELECT painterID FROM Paintings)
# SELECT  fname, lname  FROM Artists  WHERE artistID IN (SELECT painterID FROM Paintings) AND artistID NOT IN (SELECT sculptorID FROM Sculptures)
# Processing index 30
# SELECT T2.Email_Adress ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID ORDER BY T1.Date_of_Answer DESC
# For each student answer, find the email address of the student and the date of the answer. Sort them in descending order of dates.
# NON-NESTED
# SELECT T1.Email_Address ,  T2.Date_of_Answer FROM Students AS T1 JOIN Student_Answers AS T2 ON T1.Student_ID  =  T2.Student_ID ORDER BY T2.Date_of_Answer DESC
# SELECT  T1.Email_Address, T2.Date_of_Answer  FROM Students AS T1  JOIN Student_Answers AS T2 ON T1.Student_ID = T2.Student_ID  ORDER BY T2.Date_of_Answer DESC
# Processing index 31
# SELECT T2.Transmitter ,  COUNT(*) FROM city_channel_radio AS T1 JOIN radio AS T2 ON T1.Radio_ID  =  T2.Radio_ID GROUP BY T2.Transmitter
# Show the transmitters of the radios and the number of city channels they are associated with.
# NON-NESTED
# SELECT T1.Transmitter , COUNT(T2.ID) FROM radio AS T1 JOIN city_channel_radio AS T2 ON T1.Radio_ID = T2.Radio_ID GROUP BY T1.Transmitter
# SELECT  T1.Transmitter, COUNT(T2.City_channel_ID)  FROM radio AS T1  JOIN city_channel_radio AS T2 ON T1.Radio_ID = T2.Radio_ID  GROUP BY T1.Transmitter
# Processing index 32
# SELECT count(T1.pilot_name) ,  avg(T1.age) ,  T2.location FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name GROUP BY T2.location
# For each city, find the number and average age of pilots who have a plane.
# NON-NESTED
# SELECT T1.location, COUNT(T2.pilot_name), AVG(T2.age) FROM Hangar AS T1 JOIN PilotSkills AS T2 ON T1.plane_name = T2.plane_name GROUP BY T1.location
# SELECT  T1.location, COUNT(DISTINCT T2.pilot_name), AVG(T2.age)  FROM Hangar AS T1  JOIN PilotSkills AS T2 ON T1.plane_name = T2.plane_name  GROUP BY T1.location
# Processing index 33
# SELECT T3.name FROM Paper AS T1 JOIN Author_list AS T2 ON T1.paper_id  =  T2.paper_id JOIN Affiliation AS T3 ON T2.affiliation_id  =  T3.affiliation_id WHERE T1.year  =  2009 GROUP BY T2.affiliation_id ORDER BY count(*) DESC LIMIT 3
# Which 3 affiliations had the most papers in 2009?
# NON-NESTED
# SELECT T1.name , COUNT(T3.paper_id) AS paper_count FROM Affiliation AS T1 JOIN Author_list AS T2 ON T1.affiliation_id = T2.affiliation_id JOIN Paper AS T3 ON T2.paper_id = T3.paper_id WHERE T3.year = 2009 GROUP BY T1.name ORDER BY paper_count DESC LIMIT 3
# SELECT  T1.name , COUNT(T3.paper_id) AS paper_count  FROM Affiliation AS T1  JOIN Author_list AS T2 ON T1.affiliation_id = T2.affiliation_id  JOIN Paper AS T3 ON T2.paper_id = T3.paper_id  WHERE T3.year = 2009  GROUP BY T1.affiliation_id  ORDER BY paper_count DESC  LIMIT 3
# Processing index 34
# SELECT T1.start_date_time ,  T1.end_date_time ,  T2.client_details ,  T4.staff_details FROM meetings AS T1 JOIN clients AS T2 ON T1.client_id  =  T2.client_id JOIN staff_in_meetings AS T3 ON T1.meeting_id  =  T3.meeting_id JOIN staff AS T4 ON T3.staff_id  =  T4.staff_id
# What are the start and end times of each meeting, as well as the corresponding client and staff details the attendees?
# NON-NESTED
# SELECT T1.start_date_time, T1.end_date_time, T3.client_details, T4.staff_details FROM Meetings AS T1 JOIN Clients AS T2 ON T1.client_id = T2.client_id JOIN Staff_in_Meetings AS T3 ON T1.meeting_id = T3.meeting_id JOIN Staff AS T4 ON T3.staff_id = T4.staff_id
# SELECT  T1.start_date_time, T1.end_date_time, T2.client_details, T4.staff_details  FROM Meetings AS T1  JOIN Clients AS T2 ON T1.client_id = T2.client_id  JOIN Staff_in_Meetings AS T3 ON T1.meeting_id = T3.meeting_id  JOIN Staff AS T4 ON T3.staff_id = T4.staff_id
# Processing index 35
# SELECT T2.First_Name ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID
# For each student answer, find the first name of the student and the date of the answer.
# NON-NESTED
# SELECT T1.First_Name ,  T2.Date_of_Answer FROM Students AS T1 JOIN Student_Answers AS T2 ON T1.Student_ID  =  T2.Student_ID
# SELECT T1.First_Name, T2.Date_of_Answer  FROM Students AS T1  JOIN Student_Answers AS T2 ON T1.Student_ID = T2.Student_ID
# Processing index 36
# SELECT 	count(DISTINCT T1.pilot_name) FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  'Chicago'
# How many pilots whose planes are in Chicago?
# NON-NESTED
# SELECT count(DISTINCT T1.pilot_name) FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name = T2.plane_name WHERE T2.location = 'Chicago'
# SELECT  count(DISTINCT T1.pilot_name) FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name = T2.plane_name WHERE T2.location = 'Chicago' GROUP BY T1.pilot_name
# Processing index 37
# SELECT DISTINCT T1.title FROM book AS T1 JOIN books_order AS T2 ON T1.isbn  =  T2.isbn
# Show the titles of books that have been ordered.
# NON-NESTED
# SELECT DISTINCT T1.Title FROM Book AS T1 JOIN Books_Order AS T2 ON T1.ISBN = T2.ISBN
# SELECT  T1.Title  FROM Book AS T1  JOIN Books_Order AS T2 ON T1.ISBN = T2.ISBN
# Processing index 38
# SELECT T1.date_of_transcript FROM Transcripts AS T1 JOIN Student_Loans AS T2 ON T1.student_id  =  T2.student_id ORDER BY T2.amount_of_loan DESC LIMIT 1
# What is the transcript issuance date for the student with the largest amount of loan?
# NON-NESTED
# SELECT T1.date_of_transcript FROM Transcripts AS T1 JOIN Students AS T2 ON T1.student_id = T2.student_id JOIN Student_Loans AS T3 ON T2.student_id = T3.student_id WHERE T3.amount_of_loan = (SELECT MAX(amount_of_loan) FROM Student_Loans)
# SELECT  T1.date_of_transcript  FROM Transcripts AS T1  JOIN Students AS T2 ON T1.student_id = T2.student_id  JOIN Student_Loans AS T3 ON T2.student_id = T3.student_id  WHERE T3.amount_of_loan = (SELECT MAX(amount_of_loan) FROM Student_Loans)
# Processing index 39
# SELECT agency_id FROM Agencies EXCEPT SELECT agency_id FROM Clients
# Show all agency ids without any client.
# NON-NESTED
# SELECT T1.agency_id FROM Agencies AS T1 LEFT JOIN Clients AS T2 ON T1.agency_id = T2.agency_id WHERE T2.agency_id IS NULL
# SELECT  T1.agency_id  FROM Agencies AS T1  LEFT JOIN Clients AS T2 ON T1.agency_id = T2.agency_id  WHERE T2.agency_id IS NULL
# Processing index 40
# SELECT conference_name ,  count(*) FROM conference GROUP BY conference_name
# Show all conference names and the number of times each conference has.
# NON-NESTED
# SELECT Conference_Name, COUNT(*) FROM conference GROUP BY Conference_Name
# SELECT  Conference_Name, COUNT(*) FROM conference_participation  JOIN conference ON conference_participation.Conference_ID = conference.Conference_ID GROUP BY Conference_Name
# Processing index 41
# SELECT DISTINCT OWNER FROM Document_Subset_Members AS T1 JOIN Document_Objects AS T2 ON T1.Related_Document_Object_ID  =  T2.Document_Object_ID WHERE T2.Owner  =  'Braeden';
# What are the different owners of documents that are related to ones owned by Braeden?
# EASY
# SELECT DISTINCT Owner FROM Document_Objects WHERE Parent_Document_Object_ID IN (SELECT Document_Object_ID FROM Document_Objects WHERE Owner = 'Braeden')
# SELECT  DISTINCT Owner  FROM Document_Objects  WHERE Parent_Document_Object_ID IN      (SELECT Document_Object_ID       FROM Document_Objects       WHERE Owner = 'Braeden')
# Processing index 42
# SELECT sum(population) ,  avg(population) FROM district WHERE district_id IN (SELECT district_id FROM spokesman_district)
# Find the total and average population of the districts which have some spokesman.
# NON-NESTED
# SELECT SUM(T2.Population) AS total_population, AVG(T2.Population) AS average_population FROM spokesman_district AS T1 JOIN district AS T2 ON T1.District_ID = T2.District_ID
# SELECT  SUM(T2.Population) AS total_population, AVG(T2.Population) AS average_population  FROM spokesman_district AS T1  JOIN district AS T2 ON T1.District_ID = T2.District_ID GROUP BY T2.District_ID
# Processing index 43
# SELECT pilot_name FROM pilotskills WHERE plane_name  =  'Piper Cub' EXCEPT SELECT pilot_name FROM pilotskills WHERE plane_name  =  'B-52 Bomber'
# Find pilots who own plane Piper Cub but not B-52 Bomber.
# NESTED
# SELECT pilot_name FROM PilotSkills WHERE plane_name = 'Piper Cub' AND pilot_name NOT IN (SELECT pilot_name FROM PilotSkills WHERE plane_name = 'B-52 Bomber')
# SELECT  pilot_name  FROM PilotSkills  WHERE plane_name = 'Piper Cub'  AND pilot_name NOT IN  (SELECT pilot_name  FROM PilotSkills  WHERE plane_name = 'B-52 Bomber') GROUP BY pilot_name
# Processing index 44
# SELECT T1.conference_name FROM Conference AS T1 JOIN Conference_participation AS T2 ON T1.conference_id  =  T2.conference_id GROUP BY T2.conference_id ORDER BY count(*) DESC LIMIT 2
# Find the name of the conferences that have the top 2 most number of attendants.
# NON-NESTED
# SELECT T1.Conference_Name FROM conference AS T1 JOIN conference_participation AS T2 ON T1.Conference_ID = T2.Conference_ID GROUP BY T1.Conference_Name ORDER BY COUNT(T2.staff_ID) DESC LIMIT 2
# SELECT  T1.Conference_Name  FROM conference AS T1  JOIN conference_participation AS T2 ON T1.Conference_ID = T2.Conference_ID  GROUP BY T1.Conference_ID, T1.Conference_Name  ORDER BY COUNT(T2.staff_ID) DESC  LIMIT 2
# Processing index 45
# SELECT sum(value) ,  count(*) ,  CONTENTS FROM boxes GROUP BY CONTENTS
# For each content, what is the total value and number of boxes?
# EASY
# SELECT Contents, SUM(Value) AS total_value, COUNT(*) AS total_boxes FROM Boxes GROUP BY Contents
# SELECT  Contents, SUM(Value) AS total_value, COUNT(*) AS total_boxes FROM Boxes GROUP BY Contents
# Processing index 46
# SELECT T1.PackageNumber ,  max(T1.Weight) FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Sender  =  T2.AccountNumber WHERE T2.Name LIKE "John";
# What is the heaviest package sent by the clients which 'John' is part of their name? List package number and weight.
# NON-NESTED
# SELECT Package.PackageNumber , Package.Weight FROM Package JOIN Client ON Package.Recipient = Client.AccountNumber WHERE Client.Name LIKE '%John%' ORDER BY Package.Weight DESC LIMIT 1
# SELECT  Package.PackageNumber, MAX(Package.Weight) as Weight FROM Package  JOIN Client ON Package.Recipient = Client.AccountNumber  WHERE Client.Name LIKE '%John%'  GROUP BY Package.PackageNumber ORDER BY Weight DESC
# Processing index 47
# SELECT DISTINCT T2.stage_presence FROM songs AS T1 JOIN performance_score AS T2 ON T1.id  =  T2.songs_id WHERE T1.language  =  'English'
# What are the distinct stage presence scores for all the songs that are in language 'English' ?
# NON-NESTED
# SELECT DISTINCT T1.stage_presence FROM performance_score AS T1 JOIN songs AS T2 ON T1.songs_id = T2.id WHERE T2.language = 'English'
# SELECT  DISTINCT T1.stage_presence  FROM performance_score AS T1  JOIN songs AS T2 ON T1.songs_id = T2.id  WHERE T2.language = 'English'
# Processing index 48
# SELECT T2.First_Name ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID
# Please show the first names of students and the dates of their answers.
# EASY
# SELECT First_Name, Date_of_Answer FROM Students JOIN Student_Answers ON Students.Student_ID = Student_Answers.Student_ID
# SELECT Students.First_Name, Student_Answers.Date_of_Answer  FROM Students  JOIN Student_Answers ON Students.Student_ID = Student_Answers.Student_ID
# Processing index 49
# SELECT avg(age) ,  plane_name FROM pilotskills GROUP BY plane_name
# What is the average age of pilots for different types of planes?
# NON-NESTED
# SELECT AVG(T1.age) ,  T2.plane_name FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name  =  T2.plane_name GROUP BY T2.plane_name
# SELECT  AVG(T1.age) ,  T2.plane_name FROM PilotSkills AS T1 JOIN Hangar AS T2 ON T1.plane_name  =  T2.plane_name GROUP BY T2.plane_name
# Processing index 50
# SELECT T2.width_mm FROM artists AS T1 JOIN paintings AS T2 ON T1.artistID  =  T2.painterID WHERE T1.birthYear  <  1850
# What are the widths of the paintings that were created by the artist who was born before 1850?
# NON-NESTED
# SELECT Paintings.width_mm FROM Paintings JOIN Artists ON Paintings.painterID = Artists.artistID WHERE Artists.birthYear < 1850
# SELECT  Paintings.width_mm  FROM Paintings  JOIN Artists ON Paintings.painterID = Artists.artistID  WHERE Artists.birthYear < 1850
# Processing index 51
# SELECT Neighborhood FROM store EXCEPT SELECT t1.Neighborhood FROM store AS t1 JOIN stock AS t2 ON t1.store_id  =  t2.store_id
# Which neighborhood does not have any headphone in stock?
# NON-NESTED
# SELECT T1.Neighborhood FROM store AS T1 WHERE T1.Store_ID NOT IN (SELECT T2.Store_ID FROM stock AS T2)
# SELECT  T1.Neighborhood  FROM store AS T1  WHERE T1.Store_ID NOT IN (SELECT T2.Store_ID FROM stock AS T2 WHERE T1.Store_ID = T2.Store_ID)
# Processing index 52
# SELECT T1.Title FROM game AS T1 JOIN platform AS T2 ON T1.Platform_ID  =  T2.Platform_ID WHERE T2.Market_district  =  "Asia" OR T2.Market_district  =  "USA"
# Please list the title of games with platforms that have market district in Asia or USA.
# NON-NESTED
# SELECT game.Title FROM game JOIN platform ON game.Platform_ID = platform.Platform_ID WHERE platform.Market_district = 'Asia' OR platform.Market_district = 'USA'
# SELECT  game.Title  FROM game  JOIN platform ON game.Platform_ID = platform.Platform_ID  WHERE platform.Market_district = 'Asia' OR platform.Market_district = 'USA'
# Processing index 53
# SELECT T1.bio_data ,  T1.student_details FROM Students AS T1 JOIN Student_Loans AS T2 ON T1.student_id  =  T2.student_id WHERE T2.amount_of_loan  >  ( SELECT avg(amount_of_loan) FROM Student_Loans )
# Find the biographical data and details for students whose student loan is above the average amount.
# EASY
# SELECT bio_data, student_details
# FROM Students
# WHERE student_id IN (SELECT student_id FROM Student_Loans GROUP BY student_id HAVING amount_of_loan > (SELECT AVG(amount_of_loan) FROM Student_Loans))
# SELECT  bio_data, student_details  FROM Students  WHERE student_id IN (SELECT student_id FROM Student_Loans GROUP BY student_id HAVING amount_of_loan > (SELECT AVG(amount_of_loan) FROM Student_Loans))
# Processing index 54
# SELECT name FROM Client EXCEPT SELECT T1.name FROM Client AS T1 JOIN Orders AS T2 ON T1.idClient  =  T2.idClient
# Show all client names for clients who have not made orders.
# NESTED
# SELECT Client.Name FROM Client WHERE Client.IdClient NOT IN (SELECT DISTINCT IdClient FROM Orders)
# SELECT  Client.Name  FROM Client  LEFT JOIN Orders ON Client.IdClient = Orders.IdClient  WHERE Orders.IdOrder IS NULL
# Processing index 55
# SELECT make FROM team GROUP BY team HAVING count(*)  >  1
# Which make has more than one team?
# EASY
# SELECT Make FROM team GROUP BY Make HAVING count(*) > 1
# SELECT  Make FROM team GROUP BY Make HAVING COUNT(DISTINCT Team_ID) > 1
# Processing index 56
# SELECT sum(capacity) ,  avg(capacity) ,  max(capacity) ,  LOCATION FROM warehouses GROUP BY LOCATION
# Find the total, average, and maximum capacity for different locations.
# EASY
# SELECT building, SUM(capacity) AS total_capacity, AVG(capacity) AS average_capacity, MAX(capacity) AS max_capacity FROM classroom GROUP BY building
# SELECT  location, SUM(capacity) AS total_capacity, AVG(capacity) AS average_capacity, MAX(capacity) AS max_capacity FROM Warehouses GROUP BY location
# Processing index 57
# SELECT Player_name FROM player WHERE Player_ID NOT IN (SELECT Player_ID FROM game_player)
# What are the names of players who do not play any games?
# NON-NESTED
# SELECT Player_name FROM player WHERE Player_ID NOT IN (SELECT Player_ID FROM game_player)
# SELECT  Player_name  FROM player  WHERE Player_ID NOT IN (SELECT Player_ID FROM game_player)
# Processing index 58
# SELECT T1.meeting_id ,  T1.meeting_outcome ,  T1.meeting_type ,  T2.client_details FROM meetings AS T1 JOIN clients AS T2 ON T1.client_id  =  T2.client_id
# What are the meeting ids, meeting outcomes, meeting types, and client details for all meetings?
# NON-NESTED
# SELECT Meetings.meeting_id, Meetings.meeting_outcome, Meetings.meeting_type, Clients.client_details FROM Meetings JOIN Clients ON Meetings.client_id = Clients.client_id
# SELECT  Meetings.meeting_id, Meetings.meeting_outcome, Meetings.meeting_type, Clients.client_details  FROM Meetings  JOIN Clients ON Meetings.client_id = Clients.client_id
# Processing index 59
# SELECT TYPE FROM book GROUP BY TYPE HAVING COUNT(*)  >=  3
# What are the types of books that have at least three books belonging to?
# NON-NESTED
# SELECT T1.Type FROM book AS T1 JOIN review AS T2 ON T1.Book_ID = T2.Book_ID GROUP BY T1.Type HAVING COUNT(T2.Book_ID) >= 3
# SELECT  T1.Type  FROM book AS T1  JOIN review AS T2 ON T1.Book_ID = T2.Book_ID  GROUP BY T1.Type  HAVING COUNT(T1.Book_ID) >= 3
# Processing index 60
# SELECT DISTINCT T1.birthYear FROM artists AS T1 JOIN sculptures AS T2 ON T1.artistID  =  T2.sculptorID WHERE T2.year  >  1920
# What is the birth year of each distinct artists who created sculptures after 1920?
# NON-NESTED
# SELECT DISTINCT T1.birthYear, T2.sculptorID FROM Artists AS T1 JOIN Sculptures AS T2 ON T1.artistID = T2.sculptorID WHERE T2.year > 1920
# SELECT  DISTINCT T1.birthYear, T2.sculptorID  FROM Artists AS T1  JOIN Sculptures AS T2 ON T1.artistID = T2.sculptorID  WHERE T2.year > 1920 GROUP BY T1.birthYear, T2.sculptorID
# Processing index 61
# SELECT author_name FROM Documents GROUP BY author_name HAVING count(*)  >=  2
# Show the names for authors with at least two documents.
# NON-NESTED
# SELECT author_name FROM Authors JOIN Documents ON Authors.author_name = Documents.author_name GROUP BY Authors.author_name HAVING COUNT(Documents.document_id) >= 2
# SELECT  Authors.author_name  FROM Authors  JOIN Documents ON Authors.author_name = Documents.author_name  GROUP BY Authors.author_name  HAVING COUNT(DISTINCT Documents.document_id) >= 2
# Processing index 62
# SELECT earpads FROM headphone GROUP BY earpads ORDER BY count(*) DESC LIMIT 2
# What are the top 2 earpads in terms of the number of headphones using them?
# NON-NESTED
# SELECT T1.Earpads , COUNT(T2.Headphone_ID) AS num_headphones FROM headphone AS T1 JOIN stock AS T2 ON T1.Headphone_ID = T2.Headphone_ID GROUP BY T1.Earpads ORDER BY num_headphones DESC LIMIT 2
# SELECT  T1.Earpads , COUNT(T2.Headphone_ID) AS num_headphones  FROM headphone AS T1  JOIN stock AS T2 ON T1.Headphone_ID = T2.Headphone_ID  GROUP BY T1.Earpads  ORDER BY num_headphones DESC  LIMIT 2
# Processing index 63
# SELECT T1.fname ,  count(*) FROM artists AS T1 JOIN paintings AS T2 ON T1.artistID  =  T2.painterID GROUP BY T2.painterID HAVING count(*)  >=  2
# What are the first names of all artists who have at least two paintings, and how many works did each create?
# NON-NESTED
# SELECT T1.fname , COUNT(T2.paintingID) AS num_paintings FROM Artists AS T1 JOIN Paintings AS T2 ON T1.artistID = T2.painterID GROUP BY T1.artistID HAVING COUNT(T2.paintingID) >= 2
# SELECT  T1.fname , COUNT(T2.paintingID) AS num_paintings  FROM Artists AS T1  JOIN Paintings AS T2 ON T1.artistID = T2.painterID  GROUP BY T1.fname  HAVING COUNT(T2.paintingID) >= 2
# Processing index 64
# SELECT Country FROM player GROUP BY Country HAVING COUNT(*)  >  1
# List the country that have more than one player.
# EASY
# SELECT Country FROM player GROUP BY Country HAVING COUNT(Player_ID) > 1
# SELECT  Country FROM player GROUP BY Country HAVING COUNT(DISTINCT Player_ID) > 1
# Processing index 65
# SELECT analytical_layer_type_code FROM analytical_layer GROUP BY analytical_layer_type_code ORDER BY count(*) DESC LIMIT 1
# What is the most common analytical layer type code?
# EASY
# SELECT Analytical_Layer_Type_Code FROM Analytical_Layer GROUP BY Analytical_Layer_Type_Code ORDER BY count(*) DESC LIMIT 1
# SELECT Analytical_Layer_Type_Code FROM Analytical_Layer GROUP BY Analytical_Layer_Type_Code ORDER BY COUNT(*) DESC LIMIT 1
# Processing index 66
# SELECT T1.name FROM staff AS T1 JOIN conference_participation AS T2 ON T1.staff_id  =  T2.staff_id WHERE T2.role  =  'Speaker' INTERSECT SELECT T1.name FROM staff AS T1 JOIN conference_participation AS T2 ON T1.staff_id  =  T2.staff_id WHERE T2.role  =  'Sponsor'
# Show all staff names who have been both speaker and sponsor in some conference.
# NON-NESTED
# SELECT DISTINCT T1.name FROM staff AS T1 JOIN conference_participation AS T2 ON T1.staff_ID = T2.staff_ID WHERE T2.role IN ("speaker","sponsor") GROUP BY T1.name HAVING COUNT(DISTINCT T2.role) = 2
# SELECT  T1.name  FROM staff AS T1  JOIN conference_participation AS T2 ON T1.staff_ID = T2.staff_ID  WHERE T2.role IN ("speaker","sponsor")  GROUP BY T1.name  HAVING COUNT(DISTINCT T2.role) = 2
# Processing index 67
# SELECT construction ,  avg(price) FROM headphone GROUP BY construction
# How much does headphones cost on average for each headphone construction?
# EASY
# SELECT Construction, AVG(Price) AS Average_Price FROM headphone GROUP BY Construction
# SELECT  Construction, AVG(Price) AS Average_Price FROM headphone GROUP BY Construction
# Processing index 68
# SELECT Manufacturer FROM club GROUP BY Manufacturer ORDER BY COUNT(*) DESC LIMIT 1
# Please show the most common manufacturer of clubs.
# EASY
# SELECT Manufacturer FROM club GROUP BY Manufacturer ORDER BY count(*) DESC LIMIT 1
# SELECT  Manufacturer FROM club GROUP BY Manufacturer ORDER BY COUNT(*) DESC LIMIT 1
# Processing index 69
# SELECT state FROM Student AS T1 JOIN City AS T2 ON T1.city_code  =  T2.city_code WHERE T1.Fname  =  "Linda"
# Give the state that the student with first name Linda lives in.
# NON-NESTED
# SELECT T1.state FROM City AS T1 JOIN Student AS T2 ON T1.city_code = T2.city_code WHERE T2.Fname = 'Linda'
# SELECT  T1.state  FROM City AS T1  JOIN Student AS T2 ON T1.city_code = T2.city_code  WHERE T2.Fname = 'Linda'
# Processing index 70
# SELECT DISTINCT T1.Name FROM driver AS T1 JOIN vehicle_driver AS T2 ON T1.driver_id  =  T2.driver_id JOIN vehicle AS T3 ON T2.vehicle_id  =  T3.vehicle_id WHERE T3.power  >  5000
# Return the names of drivers who have driven vehicles with power over 5000.
# NON-NESTED
# SELECT DISTINCT T1.Name FROM driver AS T1 JOIN vehicle_driver AS T2 ON T1.Driver_ID = T2.Driver_ID JOIN vehicle AS T3 ON T2.Vehicle_ID = T3.Vehicle_ID WHERE T3.Power > 5000
# SELECT  T1.Name  FROM driver AS T1  JOIN vehicle_driver AS T2 ON T1.Driver_ID = T2.Driver_ID  JOIN vehicle AS T3 ON T2.Vehicle_ID = T3.Vehicle_ID  WHERE T3.Power > 5000
# Processing index 71
# SELECT count(DISTINCT T1.driver_id) FROM vehicle_driver AS T1 JOIN vehicle AS T2 ON T1.vehicle_id  =  T2.vehicle_id WHERE T2.build_year  =  2012
# How many drivers have driven vehicles built in 2012?
# NON-NESTED
# SELECT count(DISTINCT T1.Driver_ID) FROM driver AS T1 JOIN vehicle_driver AS T2 ON T1.Driver_ID = T2.Driver_ID JOIN vehicle AS T3 ON T2.Vehicle_ID = T3.Vehicle_ID WHERE T3.Build_Year = 2012
# SELECT  count(DISTINCT T1.Driver_ID)  FROM driver AS T1  JOIN vehicle_driver AS T2 ON T1.Driver_ID = T2.Driver_ID  JOIN vehicle AS T3 ON T2.Vehicle_ID = T3.Vehicle_ID  WHERE T3.Build_Year = 2012
# Processing index 72
# SELECT DISTINCT T1.birthYear FROM artists AS T1 JOIN sculptures AS T2 ON T1.artistID  =  T2.sculptorID WHERE T2.year  >  1920
# Find the birth years of all distinct artists who made sculptures after 1920?
# NON-NESTED
# SELECT DISTINCT T1.birthYear FROM Artists AS T1 JOIN Sculptures AS T2 ON T1.artistID = T2.sculptorID WHERE T2.year > 1920
# SELECT  DISTINCT T1.birthYear  FROM Artists AS T1  JOIN Sculptures AS T2 ON T1.artistID = T2.sculptorID  WHERE T2.year > 1920 GROUP BY T1.birthYear
# Processing index 73
# SELECT T2.code FROM boxes AS T1 JOIN Warehouses AS T2 ON T1.warehouse  =  T2.code GROUP BY T2.code HAVING count(*)  >  T2.capacity
# What are the codes of warehouses that have more boxes than their capacity?
# NON-NESTED
# SELECT DISTINCT T1.Warehouse FROM Boxes AS T1 JOIN Warehouses AS T2 ON T1.Warehouse = T2.Code GROUP BY T1.Warehouse HAVING COUNT(T1.Code) > T2.Capacity
# SELECT  T1.Warehouse  FROM Boxes AS T1  JOIN Warehouses AS T2 ON T1.Warehouse = T2.Code  GROUP BY T1.Warehouse  HAVING COUNT(T1.Code) > T2.Capacity
# Processing index 74
# select count (distinct t2.author_id) from author_list as t1 join author_list as t2 on t1.paper_id  =  t2.paper_id and t1.author_id != t2.author_id join author as t3 on t1.author_id  =  t3.author_id where t3.name = "mckeown ,  kathleen"
# Count the number of collaborators that Mckeown , Kathleen has had .
# NON-NESTED
# SELECT count(*) FROM Author_list WHERE author_id = (SELECT author_id FROM Author WHERE name = 'Mckeown, Kathleen')
# SELECT  COUNT(DISTINCT al.author_id)  FROM Author_list al JOIN Author a ON al.author_id = a.author_id WHERE a.name = 'Mckeown, Kathleen'
# Processing index 75
# SELECT T1.code FROM boxes AS T1 JOIN warehouses AS T2 ON T1.warehouse  =  T2.code WHERE T2.location  =  'Chicago' OR T2.location  =  'New York'
# What are the codes of boxes stored in warehouses in either Chicago or New York?
# NON-NESTED
# SELECT Boxes.Code FROM Boxes JOIN Warehouses ON Boxes.Warehouse = Warehouses.Code WHERE Warehouses.Location = 'Chicago' OR Warehouses.Location = 'New York'
# SELECT  Boxes.Code  FROM Boxes  JOIN Warehouses ON Boxes.Warehouse = Warehouses.Code  WHERE Warehouses.Location = 'Chicago' OR Warehouses.Location = 'New York'
# Processing index 76
# SELECT T1.datestamp ,  T2.property_name FROM User_Property_History AS T1 JOIN Properties AS T2 ON T1.property_id  =  T2.property_id ORDER BY datestamp;
# What are the date stamps and property names for each item of property history, ordered by date stamp?
# NON-NESTED
# SELECT T1.datestamp, T2.property_name FROM User_Property_History AS T1 JOIN Properties AS T2 ON T1.property_id = T2.property_id ORDER BY T1.datestamp
# SELECT T1.datestamp, T2.property_name  FROM User_Property_History AS T1  JOIN Properties AS T2 ON T1.property_id = T2.property_id  ORDER BY T1.datestamp
# Processing index 77
# SELECT T1.PackageNumber FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Recipient  =  T2.AccountNumber WHERE T2.Name = "Leo Wong";
# What are all of the package numbers received by Leo Wong?
# NON-NESTED
# SELECT Package.PackageNumber FROM Package JOIN Client ON Package.Recipient = Client.AccountNumber WHERE Client.Name = 'Leo Wong'
# SELECT  DISTINCT Package.PackageNumber  FROM Package  JOIN Client ON Package.Recipient = Client.AccountNumber  WHERE Client.Name = 'Leo Wong'
# Processing index 78
# SELECT T2.name ,  sum(T1.total_hours) FROM renting_history AS T1 JOIN vehicles AS T2 ON T1.vehicles_id  =  T2.id GROUP BY T2.id
# What are the names and total rental hours for each vehicle?
# NON-NESTED
# SELECT T1.name , SUM(T2.total_hours) AS total_rental_hours FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id GROUP BY T1.name
# SELECT  T1.name , SUM(T2.total_hours) AS total_rental_hours FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id GROUP BY T1.name
# Processing index 79
# SELECT invoice_id ,  count(*) FROM Payments GROUP BY invoice_id
# Show all invoice ids and the number of payments for each invoice.
# NON-NESTED
# SELECT Invoices.invoice_id, COUNT(Payments.payment_id) FROM Invoices LEFT JOIN Payments ON Invoices.invoice_id = Payments.invoice_id GROUP BY Invoices.invoice_id
# SELECT  Invoices.invoice_id, COUNT(Payments.payment_id)  FROM Invoices  LEFT JOIN Payments ON Invoices.invoice_id = Payments.invoice_id  GROUP BY Invoices.invoice_id
# Processing index 80
# SELECT T1.lname ,  T1.fname FROM artists AS T1 JOIN sculptures AS T2 ON T1.artistID  =  T2.sculptorID INTERSECT SELECT T3.lname ,  T3.fname FROM artists AS T3 JOIN paintings AS T4 ON T3.artistID  =  T4.painterID
# Find the first and last names of the artists who have both works of paintings and sculptures?
# NESTED
# SELECT Artists.fname, Artists.lname FROM Artists WHERE artistID IN (SELECT painterID FROM Paintings) AND artistID IN (SELECT sculptorID FROM Sculptures)
# SELECT  Artists.fname, Artists.lname  FROM Artists  WHERE artistID IN (SELECT painterID FROM Paintings)  AND artistID IN (SELECT sculptorID FROM Sculptures)
# Processing index 81
# SELECT count(*) FROM Products WHERE product_id NOT IN ( SELECT product_id FROM Order_items )
# How many kinds of products have not been sold?
# NON-NESTED
# SELECT COUNT(*) FROM Products WHERE product_id NOT IN (SELECT DISTINCT product_id FROM Order_Items)
# SELECT  COUNT(DISTINCT product_id) FROM Products WHERE product_id NOT IN (SELECT DISTINCT product_id FROM Order_Items)
# Processing index 82
# SELECT pilot_name FROM PilotSkills WHERE age  <  (SELECT avg(age) FROM PilotSkills) ORDER BY age
# Return the names of pilots who are younger than average, ordered by age ascending.
# EASY
# SELECT pilot_name FROM PilotSkills WHERE age < (SELECT AVG(age) FROM PilotSkills) ORDER BY age ASC
# SELECT  pilot_name  FROM PilotSkills  WHERE age < (SELECT AVG(age) FROM PilotSkills)  GROUP BY pilot_name  ORDER BY age ASC
# Processing index 83
# SELECT t3.service_details FROM customers AS t1 JOIN customers_and_services AS t2 ON t1.customer_id  =  t2.customer_id JOIN services AS t3 ON t2.service_id  =  t3.service_id WHERE t1.customer_details  =  "Hardy Kutch"
# Find all the services that has been used by the customer with details "Hardy Kutch".
# NON-NESTED
# SELECT Services.Service_Details FROM Services JOIN Customers_and_Services ON Services.Service_ID = Customers_and_Services.Service_ID JOIN Customers ON Customers_and_Services.Customer_ID = Customers.Customer_ID WHERE Customers.Customer_Details = "Hardy Kutch"
# SELECT  Services.Service_Details  FROM Services  JOIN Customers_and_Services ON Services.Service_ID = Customers_and_Services.Service_ID  JOIN Customers ON Customers_and_Services.Customer_ID = Customers.Customer_ID  WHERE Customers.Customer_Details = "Hardy Kutch"
# Processing index 84
# SELECT product_price ,  product_size FROM Products WHERE product_price  >  ( SELECT avg(product_price) FROM Products )
# What are the product price and the product size of the products whose price is above average?
# EASY
# SELECT product_price, product_size FROM Products WHERE product_price > (SELECT AVG(product_price) FROM Products)
# SELECT  product_price, product_size  FROM Products  WHERE product_price > (SELECT AVG(product_price) FROM Products)
# Processing index 85
# SELECT T2.Rank FROM book AS T1 JOIN review AS T2 ON T1.Book_ID  =  T2.Book_ID ORDER BY T1.Pages ASC LIMIT 1
# What is the rank of the book with the smallest number of pages?
# NON-NESTED
# SELECT T1.Rank FROM review AS T1 JOIN book AS T2 ON T1.Book_ID = T2.Book_ID WHERE T2.Pages = (SELECT MIN(Pages) FROM book)
# SELECT  T1.Rank  FROM review AS T1  JOIN book AS T2 ON T1.Book_ID = T2.Book_ID  WHERE T2.Pages = (SELECT MIN(Pages) FROM book) GROUP BY T1.Rank
# Processing index 86
# SELECT Name FROM club WHERE Club_ID NOT IN (SELECT Club_ID FROM player)
# What are the names of clubs that do not have any players?
# NON-NESTED
# SELECT T1.Name FROM club AS T1 LEFT JOIN player AS T2 ON T1.Club_ID = T2.Club_ID WHERE T2.Club_ID IS NULL
# SELECT  T1.Name  FROM club AS T1  LEFT JOIN player AS T2 ON T1.Club_ID = T2.Club_ID  WHERE T2.Club_ID IS NULL
# Processing index 87
# SELECT model FROM headphone WHERE headphone_id NOT IN (SELECT headphone_id FROM stock)
# Find the headphone models that are not in stock in any store.
# NON-NESTED
# SELECT Model FROM headphone WHERE Headphone_ID NOT IN (SELECT Headphone_ID FROM stock)
# SELECT  Model  FROM headphone  WHERE Headphone_ID NOT IN (SELECT Headphone_ID FROM stock)
# Processing index 88
# ...
# SELECT  book.Title, MAX(book.Chapters) AS Max_Chapters, MIN(book.Chapters) AS Min_Chapters FROM book GROUP BY book.Title
# Processing index 245
# SELECT name ,  age FROM customers ORDER BY membership_credit DESC LIMIT 1
# Show the name and age of the customer with maximum membership credit.
# EASY
# SELECT name, age FROM Customers WHERE membership_credit = (SELECT MAX(membership_credit) FROM Customers)
# SELECT  name, age  FROM Customers  WHERE membership_credit = (SELECT MAX(membership_credit) FROM Customers)
# Processing index 246
# SELECT date_registered FROM Users WHERE login_name  =  'ratione';
# When did the user with login name ratione register?
# EASY
# SELECT date_registered FROM Users WHERE login_name = 'ratione'
# SELECT  date_registered FROM Users WHERE login_name = 'ratione'
# Processing index 247
# SELECT count(*) FROM Paper WHERE venue  =  "NAACL" AND YEAR  =  2000
# How many papers do we have in NAACL 2000?
# EASY
# SELECT COUNT(paper_id) FROM Paper WHERE venue = 'NAACL 2000' AND year = 2000
# SELECT  COUNT(paper_id)  FROM Paper  WHERE venue = 'NAACL 2000'  AND year = 2000
# Processing index 248
# SELECT count(*) FROM paintings WHERE LOCATION  =  "Gallery 240"
# How many paintings are exhibited at gallery 240?
# EASY
# SELECT COUNT(*) FROM Paintings WHERE location = 240
# SELECT  COUNT(*) FROM Paintings WHERE location = '240'
# Processing index 249
# SELECT count(DISTINCT Engine) FROM driver WHERE Age  >  30 OR Age  <  20
# Count the number of different engines used by drivers who had an age either over 30 or under 20.
# EASY
# SELECT COUNT(DISTINCT Engine) FROM driver WHERE Age > 30 OR Age < 20
# SELECT  COUNT(DISTINCT Engine)  FROM driver  WHERE Age > 30 OR Age < 20
# Processing index 250
# SELECT COUNT (DISTINCT Country) FROM player
# What is the number of distinct countries of all players?
# EASY
# SELECT COUNT(DISTINCT Country) FROM player
# SELECT  COUNT(DISTINCT Country) FROM player
# Processing index 251
# SELECT count(*) FROM Business_processes
# How many business processes do we have?
# EASY
# SELECT COUNT(*) FROM Business_Processes
# SELECT  COUNT(process_id) FROM Business_Processes
# Processing index 252
# SELECT CONTENTS FROM boxes ORDER BY value DESC LIMIT 1
# Find the content that has the highest total values in all boxes.
# EASY
# SELECT Contents FROM Boxes GROUP BY Contents ORDER BY sum(Value) DESC LIMIT 1
# SELECT  Contents FROM Boxes GROUP BY Contents ORDER BY sum(Value) DESC LIMIT 1
# Processing index 253
# SELECT max(weight) ,  min(weight) FROM bike
# What are the maximum and minimum weight of all bikes?
# EASY
# SELECT MAX(weight) AS max_weight, MIN(weight) AS min_weight FROM bike
# SELECT  MAX(weight) AS max_weight, MIN(weight) AS min_weight FROM bike
# Processing index 254
# SELECT product_id ,  product_type_code ,  product_name FROM Products
# What are the ids, type codes, and names for all products?
# EASY
# SELECT product_id, product_type_code, product_name FROM Products
# SELECT  product_id, product_type_code, product_name FROM Products
# Processing index 255
# SELECT count(*) FROM institution WHERE founded BETWEEN 1850 AND 1900
# How many institutions were founded between 1850 and 1900?
# EASY
# SELECT COUNT(*) FROM institution WHERE Founded BETWEEN 1850 AND 1900
# SELECT  COUNT(DISTINCT Institution_ID) FROM institution WHERE Founded BETWEEN 1850 AND 1900
# Processing index 256
# SELECT count(*) FROM services
# How many services are there?
# EASY
# SELECT COUNT(Service_ID) FROM Services
# SELECT  COUNT(DISTINCT Service_ID) FROM Services
# Processing index 257
# SELECT Player_name FROM player ORDER BY Player_name ASC
# What are the names of all players in alphabetical order?
# EASY
# SELECT Player_name FROM player ORDER BY Player_name ASC
# SELECT  Player_name  FROM player  ORDER BY Player_name ASC
# Processing index 258
# SELECT name FROM district WHERE Government_website LIKE "%gov%"
# Find the names of districts whose government links use a 'gov' domain.
# EASY
# SELECT Name FROM district WHERE Government_website LIKE '%.gov'
# SELECT  Name  FROM district  WHERE Government_website LIKE '%.gov'
# Processing index 259
# SELECT OWNER FROM Document_Objects WHERE Description  =  'Braeden Collection'
# What are the owners of the document objects described as the 'Braeden Collection'?
# NON-NESTED
# SELECT T1.Owner FROM Document_Objects AS T1 JOIN Documents_in_Collections AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID JOIN Collections AS T3 ON T2.Collection_ID = T3.Collection_ID WHERE T3.Collection_Name = 'Braeden Collection'
# SELECT  T1.Owner  FROM Document_Objects AS T1  JOIN Documents_in_Collections AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID  JOIN Collections AS T3 ON T2.Collection_ID = T3.Collection_ID  WHERE T3.Collection_Name = 'Braeden Collection'
# Processing index 260
# SELECT title FROM paintings WHERE width_mm  <  600 OR height_mm  >  800
# What are the names of paintings whose width is less than 600 or height is larger than 800?
# EASY
# SELECT title FROM Paintings WHERE width_mm < 600 OR height_mm > 800
# SELECT title  FROM Paintings  WHERE width_mm < 600 OR height_mm > 800
# Processing index 261
# SELECT title FROM paintings WHERE YEAR  >  1910 AND medium  =  "oil"
# Give the names of all oil paintings created after 1910.
# NON-NESTED
# SELECT T1.title FROM Paintings AS T1 JOIN Artists AS T2 ON T1.painterID = T2.artistID WHERE T1.medium = 'oil' AND T1.year > 1910
# SELECT  T1.title  FROM Paintings AS T1  JOIN Artists AS T2 ON T1.painterID = T2.artistID  WHERE T1.medium = 'oil' AND T1.year > 1910
# Processing index 262
# SELECT count(*) FROM Properties WHERE parking_lots  =  1 OR garage_yn  =  1;
# Count the number of properties that have 1 parking lot or 1 garage.
# EASY
# SELECT COUNT(*) FROM Properties WHERE (parking_lots = 1 OR garage_yn = 1)
# SELECT  COUNT(*) FROM Properties WHERE (parking_lots = 1 OR garage_yn = 1)
# Processing index 263
# SELECT Coordinates FROM Planet WHERE Name  =  "Mars";
# What are the Coordinates of planet Mars?
# EASY
# SELECT Coordinates FROM Planet WHERE Name = "Mars"
# SELECT  Coordinates FROM Planet WHERE Name = "Mars"
# Processing index 264
# SELECT Exam_Date ,  Exam_Name FROM Exams WHERE Subject_Code != 'Database'
# What are the names and dates of the exams with subject code that is not "Database"?
# EASY
# SELECT Exam_Name, Exam_Date FROM Exams WHERE Subject_Code != "Database"
# SELECT  Exam_Name, Exam_Date  FROM Exams  WHERE Subject_Code != "Database"
# Processing index 265
# SELECT DISTINCT bid FROM Reserves
# What are the ids of all boats that are reserved by someone?
# NON-NESTED
# SELECT DISTINCT T1.bid FROM Boats AS T1 JOIN Reserves AS T2 ON T1.bid = T2.bid
# SELECT  T1.bid  FROM Boats AS T1  JOIN Reserves AS T2 ON T1.bid = T2.bid
# Processing index 266
# SELECT count(DISTINCT Comments) FROM Student_Answers
# How many different comments are there for student answers?
# EASY
# SELECT COUNT(DISTINCT Comments) FROM Student_Answers
# SELECT  COUNT(DISTINCT Comments) FROM Student_Answers
# Processing index 267
# SELECT avg(distance) ,  min(distance) ,  max(distance) FROM Direct_distance
# Give the average, minimum, and maximum distances between two cities.
# EASY
# SELECT AVG(distance) AS average_distance, MIN(distance) AS min_distance, MAX(distance) AS max_distance FROM Direct_distance
# SELECT  AVG(distance) AS average_distance, MIN(distance) AS min_distance, MAX(distance) AS max_distance FROM Direct_distance
# Processing index 268
# SELECT meeting_type ,  other_details FROM meetings
# What are all meeting types and other details?
# EASY
# SELECT meeting_type, other_details FROM Meetings
# SELECT  DISTINCT meeting_type, other_details FROM Meetings
# Processing index 269
# SELECT model ,  CLASS ,  construction FROM headphone ORDER BY price LIMIT 1
# Find the model, class, and construction of the headphone with the lowest price.
# EASY
# SELECT Model, Class, Construction FROM headphone WHERE Price = (SELECT MIN(Price) FROM headphone)
# SELECT  Model, Class, Construction  FROM headphone  WHERE Price = (SELECT MIN(Price) FROM headphone)
# Processing index 270
# SELECT count(DISTINCT student_id) FROM Detention
# Count the number of students who have a detention record.
# NON-NESTED
# SELECT COUNT(DISTINCT T1.student_id) FROM Students AS T1 JOIN Detention AS T2 ON T1.student_id = T2.student_id
# SELECT  COUNT(DISTINCT T1.student_id)  FROM Students AS T1  JOIN Detention AS T2 ON T1.student_id = T2.student_id
# Processing index 271
# SELECT DISTINCT title FROM paintings ORDER BY title
# List the names of all distinct paintings in alphabetical order.
# EASY
# SELECT DISTINCT title FROM Paintings ORDER BY title ASC
# SELECT  DISTINCT title FROM Paintings ORDER BY title ASC
# Processing index 272
# SELECT count(*) FROM player WHERE Rank_of_the_year  <=  3
# Count the number of players that have a rank of year of at most 3.
# EASY
# SELECT COUNT(*) FROM player WHERE Rank_of_the_year <= 3
# SELECT  COUNT(Player_ID) FROM player WHERE Rank_of_the_year <= 3
# Processing index 273
# SELECT count(*) FROM Client
# Return the number of clients.
# EASY
# SELECT COUNT(IdClient) FROM Client
# SELECT  COUNT(IdClient) FROM Client
# Processing index 274
# SELECT Name FROM region ORDER BY Area DESC LIMIT 5
# List the names of the regions with the top 5 largest areas.
# EASY
# SELECT Name FROM region ORDER BY Area DESC LIMIT 5
# SELECT Name  FROM region  GROUP BY Name  ORDER BY Area DESC  LIMIT 5
# Processing index 275
# SELECT title FROM movies WHERE rating  =  'G' OR rating  =  'PG'
# What are the names of the movie theaters that are playing 'G' or 'PG' rated movies?
# NON-NESTED
# SELECT T1.Name FROM MovieTheaters AS T1 JOIN Movies AS T2 ON T1.Movie = T2.Code WHERE T2.Rating = 'G' OR T2.Rating = 'PG'
# SELECT  T1.Name  FROM MovieTheaters AS T1  JOIN Movies AS T2 ON T1.Movie = T2.Code  WHERE T2.Rating = 'G' OR T2.Rating = 'PG' GROUP BY T1.Name
# Processing index 276
# SELECT avg(value) FROM boxes
# Select the average value of all the boxes.
# EASY
# SELECT AVG(Value) FROM Boxes
# SELECT  AVG(Value) FROM Boxes
# Processing index 277
# SELECT agency_id ,  agency_details FROM Agencies
# Show all agency ids and details.
# EASY
# SELECT agency_id, agency_details FROM Agencies
# SELECT  agency_id, agency_details  FROM Agencies
# Processing index 278
# SELECT name ,  age FROM Sailors ORDER BY rating DESC
# What are the names and ages of all sailors sorted by decreasing rating?
# EASY
# SELECT name, age FROM Sailors ORDER BY rating DESC
# SELECT  Sailors.name, Sailors.age  FROM Sailors  ORDER BY Sailors.rating DESC
# Processing index 279
# SELECT product_name ,  weight FROM bike ORDER BY price ASC
# List the product names and weights of the bikes in ascending order of price.
# EASY
# SELECT product_name, weight FROM bike ORDER BY price ASC
# SELECT  product_name, weight FROM bike ORDER BY price
# Processing index 280
# SELECT count(*) FROM Paper
# How many papers do we have?
# EASY
# SELECT COUNT(paper_id) FROM Paper
# SELECT  COUNT(DISTINCT paper_id) FROM Paper
# Processing index 281
# select title from book order by saleprice asc limit 1
# What are the titles of books that have a sale price equal to the lowest sale price across all books ?
# EASY
# SELECT Title FROM Book WHERE SalePrice = (SELECT MIN(SalePrice) FROM Book)
# SELECT  Title  FROM Book  WHERE SalePrice = (SELECT MIN(SalePrice) FROM Book)
# Processing index 282
# SELECT customer_details FROM customers WHERE customer_details LIKE "%Kutch%"
# Find all the customers whose name contains "Kutch".
# EASY
# SELECT * FROM Customers WHERE Customer_Details LIKE '%Kutch%'
# SELECT Customer_ID, Customer_Details  FROM Customers  WHERE Customer_Details LIKE '%Kutch%'
# Processing index 283
# SELECT DISTINCT payment_method_code FROM Customers
# Give the different payment method codes that customers use.
# EASY
# SELECT DISTINCT payment_method_code FROM Customers
# SELECT  DISTINCT payment_method_code FROM Customers
# Processing index 284
# SELECT count(*) FROM Staff
# How many staff do we have?
# EASY
# SELECT COUNT(*) FROM Staff
# SELECT  COUNT(staff_id) FROM Staff
# Processing index 285
# SELECT count(*) FROM pilotskills WHERE age  >  40
# How many pilots who are older than 40?
# EASY
# SELECT COUNT(*) FROM PilotSkills WHERE age > 40
# SELECT  COUNT(DISTINCT pilot_name) FROM PilotSkills WHERE age > 40
# Processing index 286
# SELECT flavor FROM goods WHERE food  =  "Cake" AND price  >  10
# Find flavor of cakes that cost more than 10 dollars.
# EASY
# SELECT Flavor FROM goods WHERE Price > 10 AND Food = 'cake'
# SELECT  Flavor  FROM goods  WHERE Price > 10  AND Food = 'cake'
# Processing index 287
# SELECT city_name FROM City WHERE state  =  "PA"
# Show names for all cities in state PA.
# EASY
# SELECT city_name FROM City WHERE state = 'PA'
# SELECT  city_name  FROM City  WHERE state = 'PA'
# Processing index 288
# SELECT count(*) FROM performance_score WHERE stage_presence  <  7 OR stage_presence  >  9
# How many performances have a stage presence score less than 7 or higher than 9?
# NESTED
# SELECT count(*) FROM performance_score WHERE stage_presence < 7 OR stage_presence > 9
# SELECT  count(DISTINCT participant_id) FROM performance_score WHERE stage_presence < 7 OR stage_presence > 9
# Processing index 289
# SELECT DISTINCT title FROM paintings ORDER BY height_mm
# List the names of all distinct paintings ordered by length.
# EASY
# SELECT DISTINCT title FROM Paintings ORDER BY width_mm
# SELECT  DISTINCT title FROM Paintings ORDER BY width_mm DESC
# Processing index 290
# SELECT fname  ,  deathYear - birthYear FROM artists ORDER BY deathYear - birthYear DESC LIMIT 1
# What is the first name and age of the artist who lived the longest?
# EASY
# SELECT fname, MAX(deathYear - birthYear) AS age FROM Artists ORDER BY age DESC LIMIT 1
# SELECT  fname, (MAX(deathYear) - birthYear) AS age  FROM Artists  ORDER BY age DESC  LIMIT 1
# Processing index 291
# SELECT customer_address ,  customer_phone ,  customer_email FROM Customers WHERE customer_name  =  "Jeromy"
# What is the customer address, customer phone, and customer email for Jeromy?
# EASY
# SELECT customer_address, customer_phone, customer_email FROM Customers WHERE customer_name = 'Jeromy'
# SELECT  customer_address, customer_phone, customer_email FROM Customers WHERE customer_name = 'Jeromy'
# Processing index 292
# SELECT paintingID ,  height_mm FROM paintings WHERE LOCATION  =  'Gallery 240' ORDER BY width_mm DESC LIMIT 1
# What are the id and height of the painting with the longest width in gallery 240?
# EASY
# SELECT paintingID, height_mm FROM Paintings WHERE width_mm = (SELECT MAX(width_mm) FROM Paintings WHERE location = 240) AND location = 240
# SELECT  paintingID, height_mm  FROM Paintings  WHERE width_mm = (SELECT MAX(width_mm) FROM Paintings WHERE location = 240) AND location = 240 GROUP BY paintingID, height_mm
# Processing index 293
# SELECT count(DISTINCT CONTENTS) FROM boxes
# How many different contents are stored in boxes?
# EASY
# SELECT COUNT(DISTINCT Contents) FROM Boxes
# SELECT  COUNT(DISTINCT Contents) FROM Boxes
# Processing index 294
# SELECT count(*) FROM author WHERE age  <  30
# how many authors are under age 30?
# EASY
# SELECT COUNT(*) FROM author WHERE Age < 30
# SELECT  COUNT(*) FROM author WHERE Age < 30
# Processing index 295
# SELECT avg(product_price) FROM Products
# What is the product average price?
# EASY
# SELECT AVG(product_price) FROM Products
# SELECT  AVG(product_price) FROM Products
# Processing index 296
# SELECT Name FROM player ORDER BY Wins_count ASC
# Return the names of players in order of count of wins, ascending.
# EASY
# SELECT Name FROM player ORDER BY Wins_count ASC
# SELECT  player.Name  FROM player  ORDER BY Wins_count ASC
# Processing index 297
# SELECT address_id ,  address_details FROM Addresses
# List all address ids and address details.
# EASY
# SELECT address_id, address_details FROM address
# SELECT  address_id, address_details FROM Addresses
# Processing index 298
# SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  < 1885 OR YEAR  >  1930
# Which locations have paintings created before 1885 or after 1930?
# EASY
# SELECT DISTINCT location FROM Paintings WHERE year < 1885 OR year > 1930
# SELECT  DISTINCT location FROM Paintings WHERE year < 1885 OR year > 1930
# Processing index 299
# SELECT name ,  address FROM Client ORDER BY name
# What are the names and addressed of all clients, ordered alphabetically by name?
# EASY
# SELECT Name, Address FROM Client ORDER BY Name ASC
# SELECT  Name, Address FROM Client ORDER BY Name ASC

# %%
df.to_csv("./result-gpt-3.5-turbo.csv")

# %% [markdown]
# # Few Shot Prompting - **Mistral** api
#
# In this part we used `Mistral api` but the result was very bad and we don't report results in our **Final Report**.

# %%
! pip install mistralai
# Out:
# Collecting mistralai
#   Downloading mistralai-0.4.2-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.25 (from mistralai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.0 MB/s eta 0:00:00
# Collecting orjson<3.11,>=3.9.10 (from mistralai)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from mistralai) (2.8.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.25->mistralai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.25->mistralai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.25->mistralai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.25->mistralai) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.25->mistralai) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.25->mistralai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.5.2->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.5.2->mistralai) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.5.2->mistralai) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.25->mistralai) (1.2.2)
# Installing collected packages: orjson, h11, httpcore, httpx, mistralai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 mistralai-0.4.2 orjson-3.10.6

# %% [markdown]
# **Sample Test**

# %%
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage
import os

api_key = os.getenv("****")
if not api_key:
    raise ValueError("MISTRAL_API_KEY is not set in environment variables.")

model = "mistral-large-latest"

client = MistralClient(api_key=api_key)

try:
    chat_response = client.chat(
        model=model,
        messages=[ChatMessage(role="user", content="Write a SQL query to find the names of customers from the 'Orders' table in the 'Sales' database who ordered more than 5 units of any product after January 1, 2022. The table includes columns for order_id, customer_name, product_name, quantity, and order_date.")]
    )
    # Directly accessing the content of the response
    if chat_response.choices:
        print(chat_response.choices[0].message.content)
    else:
        print("No response received.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Sure, here's a SQL query that should give you the desired result:
#
# ```sql
# USE Sales;
#
# SELECT customer_name
# FROM Orders
# WHERE order_date > '2022-01-01'
# GROUP BY customer_name, product_name
# HAVING SUM(quantity) > 5;
# ```
#
# This query first selects the 'Sales' database. Then it selects the 'customer_name' from the 'Orders' table where the 'order_date' is after January 1, 2022. It groups the results by 'customer_name' and 'product_name' and only includes those groups where the sum of 'quantity' is more than 5.

# %% [markdown]
# **Final Test**

# %%
import pandas as pd
import time
import os
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

# Set your Mistral API key
API_KEY = '****'
os.environ["MISTRAL_API_KEY"] = API_KEY

# Initialize the Mistral Client
client = MistralClient(api_key=os.getenv("MISTRAL_API_KEY"))

# Paths for input and output
DATASET_SCHEMA = "/content/drive/MyDrive/Colab Notebooks/data_usage/dev_tables.json"
DATASET = "/content/drive/MyDrive/Colab Notebooks/data_usage/sampled_dev.json"
OUTPUT_FILE = "./predicted_sql.txt"

def load_data(DATASET):
    return pd.read_json(DATASET)

def hard_prompt_maker(test_sample_text, database, schema_links, sub_questions):
    instruction = "# Use the intermediate representation and the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    stepping = f'''\nA: Let's think step by step. "{test_sample_text}" can be solved by knowing the answer to the following sub-question "{sub_questions}".'''
    fields += "\n"
    prompt = instruction + fields + hard_prompt + 'Q: "' + test_sample_text + '"' + '\nschema_links: ' + schema_links + stepping + '\nThe SQL query for the sub-question'
    return prompt

def medium_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links and Intermediate_representation to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + medium_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def easy_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "\n"
    prompt = instruction + fields + easy_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nSQL:'
    return prompt

def classification_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# For the given question, classify it as EASY, NON-NESTED, or NESTED based on nested queries and JOIN.\n"
    instruction += "\nif need nested queries: predict NESTED\n"
    instruction += "elif need JOIN and don't need nested queries: predict NON-NESTED\n"
    instruction += "elif don't need JOIN and don't need nested queries: predict EASY\n\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + classification_prompt + 'Q: "' + test_sample_text + '\nschema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def schema_linking_prompt_maker(test_sample_text, database):
    instruction = "# Find the schema_links for generating SQL queries for each question based on the database schema and Foreign keys.\n"
    fields = find_fields_MYSQL_like(database)
    foreign_keys = "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    prompt = instruction + schema_linking_prompt + fields + foreign_keys + 'Q: "' + test_sample_text + """"\nA: Let’s think step by step."""
    return prompt

def find_foreign_keys_MYSQL_like(db_name):
    df = spider_foreign[spider_foreign['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['First Table Name'] + '.' + row['First Table Foreign Key'] + " = " + row['Second Table Name'] + '.' + row['Second Table Foreign Key'] + ','
    output = output[:-1] + "]"
    return output

def find_fields_MYSQL_like(db_name):
    df = spider_schema[spider_schema['Database name'] == db_name]
    df = df.groupby(' Table Name')
    output = ""
    for name, group in df:
        output += "Table " + name + ', columns = ['
        for index, row in group.iterrows():
            output += row[" Field Name"] + ','
        output = output[:-1]
        output += "]\n"
    return output

def find_primary_keys_MYSQL_like(db_name):
    df = spider_primary[spider_primary['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['Table Name'] + '.' + row['Primary Key'] + ','
    output = output[:-1]
    output += "]\n"
    return output

def creating_schema(DATASET_JSON):
    schema_df = pd.read_json(DATASET_JSON)
    schema_df = schema_df.drop(['column_names', 'table_names'], axis=1)
    schema = []
    f_keys = []
    p_keys = []
    for index, row in schema_df.iterrows():
        tables = row['table_names_original']
        col_names = row['column_names_original']
        col_types = row['column_types']
        foreign_keys = row['foreign_keys']
        primary_keys = row['primary_keys']
        for col, col_type in zip(col_names, col_types):
            index, col_name = col
            if index == -1:
                for table in tables:
                    schema.append([row['db_id'], table, '*', 'text'])
            else:
                schema.append([row['db_id'], tables[index], col_name, col_type])
        for primary_key in primary_keys:
            index, column = col_names[primary_key]
            p_keys.append([row['db_id'], tables[index], column])
        for foreign_key in foreign_keys:
            first, second = foreign_key
            first_index, first_column = col_names[first]
            second_index, second_column = col_names[second]
            f_keys.append([row['db_id'], tables[first_index], tables[second_index], first_column, second_column])
    spider_schema = pd.DataFrame(schema, columns=['Database name', ' Table Name', ' Field Name', ' Type'])
    spider_primary = pd.DataFrame(p_keys, columns=['Database name', 'Table Name', 'Primary Key'])
    spider_foreign = pd.DataFrame(f_keys,
                                  columns=['Database name', 'First Table Name', 'Second Table Name', 'First Table Foreign Key',
                                           'Second Table Foreign Key'])
    return spider_schema, spider_primary, spider_foreign

# Function to create prompts for Mistral (similar structure as your original functions)
def create_mistral_prompt(test_sample_text, database, schema_links):
    instruction = "Write a SQL query for the following scenario using the schema provided."
    schema_description = "Schema and foreign keys information."  # Define how you structure schema information here
    prompt = f"{instruction}\n{schema_description}\nQuestion: {test_sample_text}\nSchema Links: {schema_links}"
    return prompt

# Function to call Mistral and get the SQL generation
def mistral_sql_generation(prompt):
    try:
        chat_response = client.chat(
            model="mistral-large-latest",
            messages=[ChatMessage(role="user", content=prompt)]
        )
        if chat_response.choices:
            return chat_response.choices[0].message.content
        return "No valid response received."
    except Exception as e:
        print(f"Error during Mistral call: {e}")
        return None

if __name__ == '__main__':
    # Assuming schema and data loading functions are defined and working
    spider_schema, spider_primary, spider_foreign = creating_schema(DATASET_SCHEMA)
    val_df = load_data(DATASET)
    print(f"Number of data samples {val_df.shape[0]}")
    results = []

    for index, row in val_df.iterrows():
        print(f"Processing index {index}")
        print(row['query'])
        print(row['question'])

        prompt = create_mistral_prompt(row['question'], row['db_id'], "Your schema links here")  # Adjust how schema links are passed
        sql_prediction = mistral_sql_generation(prompt)
        print(sql_prediction)
        results.append([row['question'], sql_prediction, row['query'], row['db_id']])

    df = pd.DataFrame(results, columns=['NLQ', 'PREDICTED SQL', 'GOLD SQL', 'DATABASE'])
    with open(OUTPUT_FILE, 'w') as f:
        for line in df['PREDICTED SQL']:
            f.write(f"{line}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#   invoices i
#   INNER JOIN MaxPayments mp ON i.invoice_id = mp.invoice_id
#   INNER JOIN InvoicesWithPaymentCounts ipc ON i.invoice_id = ipc.invoice_id AND ipc.payment_count = mp.max_payment_count;
# ```
#
# Please replace the table names (invoices, payments) and column names (invoice_id, payment_id, status_code, details) with the appropriate ones from your schema. The query assumes that the relationships between tables are defined by invoice_id and payment_id, so you might need to adjust the join conditions depending on your schema.
# Processing index 9
# SELECT product_name FROM Products WHERE product_price  >  (SELECT avg(product_price) FROM Products)
# Show all product names with price higher than the average.
# Based on the schema you provided, the SQL query to show all product names with a price higher than the average would look like this:
#
# ```sql
# SELECT product_name
# FROM Products
# WHERE price > (SELECT AVG(price) FROM Products);
# ```
#
# This query first calculates the average price of all products in the subquery `(SELECT AVG(price) FROM Products)`. Then, it selects the names of the products from the `Products` table where the price is greater than the calculated average price.
# Processing index 10
# SELECT sum(T1.Weight) FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Sender  =  T2.AccountNumber WHERE T2.Name  =  "Leo Wong";
# What is the total weight for all packages that Leo Wong sent?
# Based on the provided schema, I'm assuming you have tables named `customer`, `package`, and `employee`. Here is a SQL query to find the total weight for all packages that Leo Wong sent:
#
# ```sql
# SELECT SUM(p.weight) as total_weight
# FROM package p
# JOIN shipment s ON p.shipment_id = s.shipment_id
# JOIN employee e ON s.employee_id = e.employee_id
# JOIN customer c ON p.sender_customer_id = c.customer_id
# WHERE c.name = 'Leo Wong';
# ```
#
# This query first joins the `package`, `shipment`, `employee`, and `customer` tables together based on their foreign key relationships. It then filters the results to only include packages sent by Leo Wong and calculates the sum of the weights of those packages.
#
# Please replace the table and column names with the actual ones from your schema if they are different.
# Processing index 11
# SELECT pilot_name ,  age FROM pilotskills WHERE plane_name  =  'Piper Cub' AND age  >  35 UNION SELECT pilot_name ,  age FROM pilotskills WHERE plane_name  =  'F-14 Fighter' AND age  <  30
# Return the names and ages of pilors who have flown Piper Cub and are older than 35, or have flown the F-14 Fighter and are younger than 30.
# Sure, I'd be happy to help you construct a SQL query for that scenario. However, I can't access links directly. Based on your description, I'll assume a schema that includes tables for pilots, planes, and a table to link pilots to the planes they've flown. Let's call these tables `pilots`, `planes`, and `pilot_planes`.
#
# Here's a SQL query that should work:
#
# ```sql
# SELECT pilots.name, pilots.age
# FROM pilots
# JOIN pilot_planes ON pilots.id = pilot_planes.pilot_id
# JOIN planes ON pilot_planes.plane_id = planes.id
# WHERE
#   (planes.name = 'Piper Cub' AND pilots.age > 35)
#   OR (planes.name = 'F-14 Fighter' AND pilots.age < 30);
# ```
#
# This query will return the names and ages of pilots who have flown the 'Piper Cub' and are older than 35, or have flown the 'F-14 Fighter' and are younger than 30. Please replace the table and column names with the actual ones from your schema.
# Processing index 12
# SELECT client_id FROM Invoices GROUP BY client_id HAVING count(*)  >=  2
# What are client ids for clients with at least 2 invoices.
# Based on the information you provided, I will assume that there are two tables: `Clients` and `Invoices`. The `Invoices` table has a foreign key `client_id` that references the `Clients` table. Here's a SQL query to find the client ids for clients with at least 2 invoices:
#
# ```sql
# SELECT client_id
# FROM Invoices
# GROUP BY client_id
# HAVING COUNT(*) >= 2;
# ```
#
# This query works as follows:
#
# 1. `SELECT client_id FROM Invoices`: Selects the `client_id` column from the `Invoices` table.
# 2. `GROUP BY client_id`: Groups the selected data by the `client_id` column.
# 3. `HAVING COUNT(*) >= 2`: Filters the grouped data to only include those with at least 2 invoices (rows) per `client_id`.
# Processing index 13
# SELECT DISTINCT T1.Document_Subset_Name FROM Document_Subsets AS T1 JOIN Document_Subset_Members AS T2 ON T1.Document_Subset_ID =  T2.Document_Subset_ID JOIN Document_Objects AS T3 ON T2.Document_Object_ID  =  T3.Document_Object_ID WHERE T3.owner  =  'Braeden'
# Which unique subset does document owned by Braeden belong to? List the subset name.
# I'm sorry for the inconvenience, but I'm unable to access external links or images. However, I can help you construct a SQL query based on a given schema description.
#
# Here's a general SQL query that might help you get the information you need. Please replace the table names, column names, and values with the ones from your schema:
#
# ```sql
# SELECT SubsetName
# FROM Subsets
# JOIN Documents ON Subsets.SubsetID = Documents.SubsetID
# JOIN Owners ON Documents.OwnerID = Owners.OwnerID
# WHERE Owners.OwnerName = 'Braeden';
# ```
#
# In this query:
#
# - `Subsets`, `Documents`, and `Owners` are assumed to be the table names.
# - `SubsetName` is the column that contains the name of the subsets.
# - `SubsetID` is the common column between `Subsets` and `Documents` tables.
# - `OwnerID` is the common column between `Documents` and `Owners` tables.
# - `OwnerName` is the column in the `Owners` table that contains the name of the document owners.
#
# Please adjust the table names, column names, and values according to your schema.
# Processing index 14
# SELECT avg(distance) FROM Direct_distance AS T1 JOIN City AS T2 ON T1.city1_code  =  T2.city_code WHERE T2.city_name  =  "Boston"
# What is the average distance between Boston and all other cities.
# To answer your question, I will assume that you have two tables: `cities` and `distances`. The `cities` table contains the `city_id`, `city_name`, and other city details. The `distances` table contains the `distance_id`, `city_id_1`, `city_id_2`, and `distance` between the two cities.
#
# Here is a SQL query to find the average distance between Boston and all other cities:
#
# ```sql
# SELECT
#   AVG(distance) AS average_distance
# FROM
#   (
#     SELECT
#       distance
#     FROM
#       cities c1
#       JOIN distances d ON (c1.city_id = d.city_id_1 OR c1.city_id = d.city_id_2)
#     WHERE
#       c1.city_name = 'Boston'
#   ) AS distances_to_from_boston;
# ```
#
# This query first creates a subquery that selects the distances between Boston and all other cities. It then calculates the average distance using the `AVG()` function. Make sure to replace the table and column names if they are different in your schema.
# Processing index 15
# SELECT count(DISTINCT T1.code) FROM movies AS T1 JOIN movietheaters AS T2 ON T1.code  =  T2.movie
# How many distinct movies are on in theaters?
# Based on the information you've provided, I'll assume that there are two tables: `movies` and `theaters`. The `movies` table has a column named `movie_id` and the `theaters` table has a column named `movie_id` as a foreign key.
#
# Here's a SQL query that should give you the number of distinct movies currently showing in theaters:
#
# ```sql
# SELECT COUNT(DISTINCT m.movie_id) AS distinct_movies_in_theaters
# FROM movies m
# JOIN theaters t ON m.movie_id = t.movie_id;
# ```
#
# This query joins the `movies` and `theaters` tables using the `movie_id` column, then counts the number of distinct `movie_id` values in the joined tables.
# Processing index 16
# SELECT T2.age_category_code FROM Ref_User_Categories AS T1 JOIN Users AS T2 ON T1.user_category_code  =  T2.user_category_code WHERE T1.User_category_description LIKE "%Mother";
# For users whose description contain the string 'Mother', which age categories are they in?
# Sure, I'd be happy to help you write a SQL query for that scenario. However, as I can't directly access links or images, I'll need you to provide a brief description of the schema.
#
# Assuming you have a `Users` table with columns `description` and `age`, and an `AgeCategories` table with columns `age` and `category`, here's a basic query that might suit your needs:
#
# ```sql
# SELECT AgeCategories.category
# FROM Users
# JOIN AgeCategories ON Users.age = AgeCategories.age
# WHERE Users.description LIKE '%Mother%';
# ```
#
# This query will return the age categories for all users whose description contains the string 'Mother'. Please replace the table and column names with the correct ones if they are different in your schema.
# Processing index 17
# SELECT isbn ,  count(*) FROM Books_Order GROUP BY isbn
# What are all isbns for each book, and how many times has each been ordered?
# Sure, I can help you write a SQL query for that scenario. However, as I can't directly access links or images, I'll assume a basic schema based on your description.
#
# Let's assume you have two tables: `Books` and `Orders`. The `Books` table has an `isbn` column, and the `Orders` table has an `isbn` column as a foreign key referencing the `Books` table.
#
# Here's a basic SQL query that should give you the desired result:
#
# ```sql
# SELECT
#     Books.isbn,
#     COUNT(Orders.isbn) AS order_count
# FROM
#     Books
# LEFT JOIN
#     Orders ON Books.isbn = Orders.isbn
# GROUP BY
#     Books.isbn;
# ```
#
# This query will return each ISBN from the `Books` table along with the number of times it appears in the `Orders` table, which corresponds to the number of times each book has been ordered. If a book has never been ordered, it will still appear in the result set with a count of 0, thanks to the LEFT JOIN.
# Processing index 18
# SELECT T1.pilot_name FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  "Austin" INTERSECT SELECT T1.pilot_name FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.LOCATION  =  "Boston"
# What are the names of pilots who have planes in both Austin and Boston?
# Based on the provided schema, I'm assuming that there are three tables: `pilots`, `planes`, and `hangars`. The `pilots` table has a `pilot_id` column, the `planes` table has a `pilot_id` foreign key referencing `pilots(pilot_id)`, and the `hangars` table has a `plane_id` foreign key referencing `planes(plane_id)` and a `city` column.
#
# Here's a SQL query that should give you the names of pilots who have planes in both Austin and Boston:
#
# ```sql
# SELECT p.name
# FROM pilots p
# WHERE EXISTS (
#   SELECT 1
#   FROM planes pl
#   JOIN hangars h ON h.plane_id = pl.plane_id
#   WHERE pl.pilot_id = p.pilot_id
#   AND h.city IN ('Austin', 'Boston')
#   GROUP BY pl.plane_id
#   HAVING COUNT(DISTINCT h.city) = 2
# );
# ```
#
# This query first selects the `name` column from the `pilots` table. The `WHERE EXISTS` clause checks if there are any planes for the current pilot that are located in hangars in both Austin and Boston. The subquery joins the `planes` and `hangars` tables and filters for rows where the `pilot_id` matches the current pilot and the `city` is either Austin or Boston. The `GROUP BY` clause groups the results by `plane_id`, and the `HAVING` clause checks if there are two distinct cities for each `plane_id`, indicating that the plane is located in both Austin and Boston. If the subquery returns any rows for a given pilot, the pilot's name will be included in the result set.
# Processing index 19
# SELECT t1.name ,  t1.gender FROM author AS t1 JOIN book AS t2 ON t1.author_id  =  t2.author_id GROUP BY t2.author_id ORDER BY count(*) DESC LIMIT 1
# Who wrote the largest number of books? Give me the author name and gender.
# Sure, I can help you construct a SQL query for that. However, I can't access links directly. But based on your description, I'll assume you have two tables: `Authors` and `Books`. The `Authors` table has `author_id`, `name`, and `gender`, and the `Books` table has `book_id` and `author_id`.
#
# Here's a SQL query that should give you the desired result:
#
# ```sql
# SELECT a.name, a.gender
# FROM Authors a
# JOIN (
#     SELECT author_id, COUNT(*) as book_count
#     FROM Books
#     GROUP BY author_id
#     ORDER BY book_count DESC
#     LIMIT 1
# ) b ON a.author_id = b.author_id;
# ```
#
# This query first counts the number of books each author has written and selects the author with the highest count. Then it joins this result with the `Authors` table to get the author's name and gender. Please replace the table and column names with the actual ones in your database if they are different.
# Processing index 20
# SELECT 	count(DISTINCT T1.pilot_name) FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  'Chicago'
# Count the number of pilots who have planes in Chicago.
# Based on the schema you've provided, I'm assuming that there are three tables: `pilots`, `planes`, and `locations`. I'm also assuming that the `planes` table has a `pilot_id` column to link it to the `pilots` table, and a `location_id` column to link it to the `locations` table. Here's a SQL query that should give you the count of pilots who have planes in Chicago:
#
# ```sql
# SELECT COUNT(DISTINCT p.id)
# FROM pilots p
# JOIN planes pl ON p.id = pl.pilot_id
# JOIN locations l ON pl.location_id = l.id
# WHERE l.city = 'Chicago';
# ```
#
# This query joins the `pilots`, `planes`, and `locations` tables together, then counts the number of distinct pilot IDs where the location city is Chicago.
# Processing index 21
# SELECT t1.customer_details FROM customers AS t1 JOIN customers_and_services AS t2 ON t1.customer_id  =  t2.customer_id GROUP BY t1.customer_details ORDER BY count(*) DESC LIMIT 1
# Find the details of the customer who has used services the most times.
# Based on the information provided, I will assume that the schema consists of two tables: `Customers` and `Services`. The `Services` table has a foreign key `customer_id` that references the `id` column in the `Customers` table.
#
# Here's the SQL query to find the details of the customer who has used services the most times:
#
# ```sql
# SELECT c.id, c.name, COUNT(s.id) AS service_count
# FROM Customers c
# JOIN Services s ON c.id = s.customer_id
# GROUP BY c.id, c.name
# ORDER BY service_count DESC
# LIMIT 1;
# ```
#
# In this query, we join the `Customers` and `Services` tables using the foreign key relationship. We then group the results by customer details, count the occurrences of each customer's services, order the results in descending order based on the service count, and limit the output to the top 1 row, which represents the customer who has used services the most times.
# Processing index 22
# SELECT T3.CustomerId FROM goods AS T1 JOIN items AS T2 ON T1.id  =  T2.item JOIN receipts AS T3 ON T2.receipt  =  T3.ReceiptNumber GROUP BY T3.CustomerId HAVING avg(T1.price)  >  5
# What are the ids of customers who spend more than 5 on average for each good?
# Based on the information provided, I will assume that there are two tables: `Customers` and `Orders`. The `Orders` table contains the `customer_id`, `good_id`, and `price` columns. Here is a SQL query to get the ids of customers who spend more than 5 on average for each good:
#
# ```sql
# SELECT customer_id
# FROM (
#   SELECT customer_id, AVG(price) as avg_spend
#   FROM Orders
#   GROUP BY customer_id, good_id
#   HAVING AVG(price) > 5
# ) AS T
# GROUP BY customer_id;
# ```
#
# This query first calculates the average price spent by each customer on each good. Then, it filters out the records with an average spend of less than or equal to 5. Finally, it groups the results by `customer_id` to get the unique customer ids who spent more than 5 on average per good.
# Processing index 23
# SELECT product_name FROM Products EXCEPT SELECT T1.product_name FROM Products AS t1 JOIN Order_items AS T2 ON T1.product_id  =  T2.product_id
# Show all product names without an order.
# Sure, I'd be happy to help you with that. However, I can't access links directly. But based on your description, I'll assume you have two tables: `Products` and `Orders`, with a foreign key in `Orders` referencing `Products`.
#
# Here's a SQL query that should work:
#
# ```sql
# SELECT ProductName
# FROM Products
# WHERE ProductId NOT IN (
#     SELECT ProductId
#     FROM Orders
# );
# ```
#
# This query selects all product names from the `Products` table where the product ID is not found in the `Orders` table, effectively returning all product names without an order. Please replace `ProductId`, `ProductName`, `Products`, and `Orders` with your actual column and table names if they are different.
# Processing index 24
# select document_object_id , count(*) from document_subset_members group by document_object_id having count(*) between 2 and 4;
# Which document has between 2 and 4 number of documents ? List the document id and the number of related documents .
# Based on the information provided, I will assume that there are two tables: `documents` and `related_documents`. The `documents` table has a `document_id` column, and the `related_documents` table has `document_id` and `related_document_id` columns.
#
# Here's a SQL query that should give the desired result:
#
# ```sql
# SELECT d.document_id, COUNT(rd.related_document_id) AS related_documents_count
# FROM documents d
# LEFT JOIN related_documents rd ON d.document_id = rd.document_id
# GROUP BY d.document_id
# HAVING COUNT(rd.related_document_id) BETWEEN 2 AND 4
# ORDER BY related_documents_count;
# ```
#
# This query will join the `documents` and `related_documents` tables based on the `document_id` column. It will then group the results by `document_id` and count the number of related documents for each document. The `HAVING` clause filters the results to only include documents with between 2 and 4 related documents. Finally, the results are ordered by the number of related documents.
# Processing index 25
# SELECT T1.detention_type_code ,  T2.detention_type_description FROM Detention AS T1 JOIN Ref_Detention_Type AS T2 ON T1.detention_type_code  =  T2.detention_type_code GROUP BY T1.detention_type_code ORDER BY count(*) ASC LIMIT 1
# Give me the type code and description of the least common detention type.
# Based on the schema you've provided, I'll assume that there is a table named `detention_types` that contains `type_code` and `description`, and another table named `detentions` that contains `type_code` as a foreign key linking to `detention_types`. To find the type code and description of the least common detention type, you can use the following SQL query:
#
# ```sql
# WITH detention_type_counts AS (
#   SELECT type_code, COUNT(*) AS count
#   FROM detentions
#   GROUP BY type_code
# )
# SELECT dt.type_code, dt.description
# FROM detention_types dt
# LEFT JOIN detention_type_counts dtc ON dt.type_code = dtc.type_code
# ORDER BY dtc.count ASC, dt.type_code ASC
# LIMIT 1;
# ```
#
# This query first creates a Common Table Expression (CTE) named `detention_type_counts` that calculates the number of occurrences of each `type_code` in the `detentions` table. Then, it joins the `detention_types` table with the `detention_type_counts` CTE and orders the results by the count of detention types in ascending order and `type_code` also in ascending order. Finally, it limits the results to the least common detention type by using `LIMIT 1`.
# Processing index 26
# SELECT Student_Answer_Text FROM Student_Answers GROUP BY Student_Answer_Text ORDER BY COUNT(*) DESC
# List all the student answer texts in descending order of count.
# Based on the information provided, I'll assume that there are two tables: `Students` and `Answers`. The `Answers` table has a foreign key `student_id` that references the `Students` table, and it also has a column `answer_text` that stores the student's answer text.
#
# Here's a SQL query that retrieves all the student answer texts in descending order of count:
#
# ```sql
# SELECT answer_text, COUNT(*) as answer_count
# FROM Answers
# GROUP BY answer_text
# ORDER BY answer_count DESC;
# ```
#
# This query groups the `Answers` table by `answer_text` and counts the occurrences of each unique `answer_text`. The result is then ordered in descending order based on the count of `answer_text`.
# Processing index 27
# SELECT Collection_Name FROM Collections EXCEPT SELECT T2.Collection_Name FROM Collections AS T1 JOIN Collections AS T2 ON T1.Parent_Collection_ID = T2.Collection_ID;
# Which collection is not the parent of other collection? List the collection's name.
# Based on the schema you've provided, I'll assume that there is a table named `collections` with columns `collection_id` and `parent_collection_id`. If a collection is not a parent of another collection, it means that its `collection_id` does not appear as a `parent_collection_id` in any other record.
#
# Here's the SQL query to find the names of the collections that are not the parent of any other collection:
#
# ```sql
# SELECT c1.name
# FROM collections AS c1
# LEFT JOIN collections AS c2
# ON c1.collection_id = c2.parent_collection_id
# WHERE c2.parent_collection_id IS NULL;
# ```
#
# This query uses a LEFT JOIN to connect the `collections` table to itself, attempting to match each collection with its potential children. By filtering with the WHERE clause for cases where there is no match (`c2.parent_collection_id IS NULL`), we'll get the collections that are not parents of any other collection.
# Processing index 28
# SELECT T1.Name ,  T2.Dish_Name FROM customer AS T1 JOIN customer_order AS T2 ON T1.Customer_ID  =  T2.Customer_ID
# For each order, return the customer name and the dish name.
# Based on the information you've provided, I'll assume that there are three tables: `Customers`, `Orders`, and `Dishes`. The `Orders` table has foreign keys `customer_id` and `dish_id` that reference the `Customers` and `Dishes` tables, respectively.
#
# Here's a SQL query that would return the customer name and dish name for each order:
#
# ```sql
# SELECT c.name AS customer_name, d.name AS dish_name
# FROM Orders o
# JOIN Customers c ON o.customer_id = c.id
# JOIN Dishes d ON o.dish_id = d.id;
# ```
#
# This query joins the `Orders` table with the `Customers` and `Dishes` tables using the foreign keys and selects the desired columns. Replace `name` with the actual column names for customer and dish names in your tables if they are different.
# Processing index 29
# SELECT T1.lname ,  T1.fname FROM artists AS T1 JOIN paintings AS T2 ON T1.artistID  =  T2.painterID EXCEPT SELECT T3.lname ,  T3.fname FROM artists AS T3 JOIN sculptures AS T4 ON T3.artistID  =  T4.sculptorID
# What are the first and last names of the artists who did not sculpt but could paint.
# Based on the schema you've provided, I'll assume there are three tables: `Artist`, `Painting`, and `Sculpture`. The `Artist` table has `artist_id`, `first_name`, and `last_name`. Both `Painting` and `Sculpture` tables have `artist_id` as a foreign key.
#
# Here's a SQL query to get the first and last names of the artists who did not sculpt but could paint:
#
# ```sql
# SELECT Artist.first_name, Artist.last_name
# FROM Artist
# WHERE Artist.artist_id IN (
#     SELECT Painting.artist_id
#     FROM Painting
# )
# AND Artist.artist_id NOT IN (
#     SELECT Sculpture.artist_id
#     FROM Sculpture
# );
# ```
#
# This query first selects all `artist_id` values from the `Painting` table, representing artists who can paint. Then it selects all `artist_id` values from the `Sculpture` table, representing artists who can sculpt. The main query selects the first and last names of artists whose `artist_id` is present in the `Painting` table but not in the `Sculpture` table.
# Processing index 30
# SELECT T2.Email_Adress ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID ORDER BY T1.Date_of_Answer DESC
# For each student answer, find the email address of the student and the date of the answer. Sort them in descending order of dates.
# Based on the schema provided, it seems like we have two tables: `Students` and `Answers`. The `Students` table has an `email` column, and the `Answers` table has a `student_id` foreign key referencing the `Students` table, as well as an `answer_date` column.
#
# Here's a SQL query to fetch the required information:
#
# ```sql
# SELECT
#   Students.email AS student_email,
#   Answers.answer_date
# FROM
#   Students
# JOIN
#   Answers
# ON
#   Students.id = Answers.student_id
# ORDER BY
#   Answers.answer_date DESC;
# ```
#
# This query joins the `Students` table with the `Answers` table using the `student_id` foreign key. It then selects the `email` column from the `Students` table and the `answer_date` column from the `Answers` table. Finally, it orders the results by the `answer_date` in descending order.
# Processing index 31
# SELECT T2.Transmitter ,  COUNT(*) FROM city_channel_radio AS T1 JOIN radio AS T2 ON T1.Radio_ID  =  T2.Radio_ID GROUP BY T2.Transmitter
# Show the transmitters of the radios and the number of city channels they are associated with.
# Based on the schema you provided, I have created a SQL query to show the transmitters of the radios and the number of city channels they are associated with. Since I cannot directly include the schema links in my response, I am assuming that the tables are named as follows:
#
# 1. radio (radio_id, transmitter_id, ...)
# 2. transmitter (transmitter_id, name, ...)
# 3. city_channel (city_channel_id, city_id, radio_id, ...)
#
# Here's the SQL query:
#
# ```sql
# SELECT
#   t.name AS transmitter_name,
#   COUNT(cc.city_channel_id) AS num_city_channels
# FROM
#   transmitter t
# JOIN
#   radio r ON t.transmitter_id = r.transmitter_id
# LEFT JOIN
#   city_channel cc ON r.radio_id = cc.radio_id
# GROUP BY
#   t.transmitter_id, t.name
# ORDER BY
#   t.name;
# ```
#
# This query first joins the 'transmitter' and 'radio' tables using the transmitter_id foreign key to get the transmitter details for each radio. Then, it left joins the 'city_channel' table using the radio_id foreign key to include all city channels for each radio. The 'LEFT JOIN' ensures that transmitters with no associated city channels are still included in the result.
#
# Finally, the query groups the results by the transmitter_id and transmitter name, counts the number of city channels associated with each transmitter, and orders the results by the transmitter name.
# Processing index 32
# SELECT count(T1.pilot_name) ,  avg(T1.age) ,  T2.location FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name GROUP BY T2.location
# For each city, find the number and average age of pilots who have a plane.
# Sure, I'd be happy to help you construct a SQL query for this scenario. However, without the actual schema, I'll have to make some assumptions about your database structure. I'm assuming you have tables named `pilots`, `cities`, and `planes`, and that the `pilots` table has columns `city_id`, `age`, and `plane_id`. Here's a basic query:
#
# ```sql
# SELECT
#     c.name AS city,
#     COUNT(p.id) AS number_of_pilots,
#     AVG(p.age) AS average_age
# FROM
#     pilots p
# JOIN
#     cities c ON p.city_id = c.id
# WHERE
#     p.plane_id IS NOT NULL
# GROUP BY
#     c.name;
# ```
#
# This query joins the `pilots` and `cities` tables on the `city_id` field, filters out pilots who don't have a plane (`plane_id IS NOT NULL`), and then groups the results by city. For each city, it counts the number of pilots and calculates the average age. Please replace the table and column names with your actual table and column names if they are different.
# Processing index 33
# SELECT T3.name FROM Paper AS T1 JOIN Author_list AS T2 ON T1.paper_id  =  T2.paper_id JOIN Affiliation AS T3 ON T2.affiliation_id  =  T3.affiliation_id WHERE T1.year  =  2009 GROUP BY T2.affiliation_id ORDER BY count(*) DESC LIMIT 3
# Which 3 affiliations had the most papers in 2009?
# Based on the schema you've provided, I'll assume that the `Paper` table has a column named `year` to store the publication year, and the `Affiliation` table is linked to the `Paper` table via the `AuthorAffiliation` table. Here's a SQL query that should give you the desired result:
#
# ```sql
# SELECT a.name, COUNT(p.id) as paper_count
# FROM Affiliation a
# JOIN AuthorAffiliation aa ON a.id = aa.affiliation_id
# JOIN Paper p ON p.id = aa.paper_id
# WHERE p.year = 2009
# GROUP BY a.name
# ORDER BY paper_count DESC
# LIMIT 3;
# ```
#
# This query first joins the necessary tables (`Affiliation`, `AuthorAffiliation`, and `Paper`). It then filters the results to only include papers published in 2009. The results are grouped by the affiliation name, and ordered in descending order based on the number of papers each affiliation has. Finally, the query limits the results to the top 3 affiliations with the most papers in 2009.
# Processing index 34
# SELECT T1.start_date_time ,  T1.end_date_time ,  T2.client_details ,  T4.staff_details FROM meetings AS T1 JOIN clients AS T2 ON T1.client_id  =  T2.client_id JOIN staff_in_meetings AS T3 ON T1.meeting_id  =  T3.meeting_id JOIN staff AS T4 ON T3.staff_id  =  T4.staff_id
# What are the start and end times of each meeting, as well as the corresponding client and staff details the attendees?
# Sure, I'd be happy to help you write a SQL query for this scenario. However, as I'm a text-based AI, I'm unable to directly access links or external resources. But I can certainly help you construct a query based on a textual description of your schema.
#
# Assuming your schema includes the following tables:
#
# 1. `Meetings`: with columns `meeting_id`, `start_time`, and `end_time`.
# 2. `Attendees`: with columns `attendee_id`, `meeting_id`, and `person_id`.
# 3. `Clients`: with columns `client_id`, `name`, and other client details.
# 4. `Staff`: with columns `staff_id`, `name`, and other staff details.
#
# And assuming that `person_id` in the `Attendees` table can refer to either a client or a staff member, we'll need to join the `Attendees` table with both the `Clients` and `Staff` tables. Here's a basic query:
#
# ```sql
# SELECT
#     m.start_time,
#     m.end_time,
#     c.name AS client_name,
#     c.other_client_details,
#     s.name AS staff_name,
#     s.other_staff_details
# FROM
#     Meetings m
# JOIN
#     Attendees a ON m.meeting_id = a.meeting_id
# LEFT JOIN
#     Clients c ON a.person_id = c.client_id
# LEFT JOIN
#     Staff s ON a.person_id = s.staff_id;
# ```
#
# This query will return the start and end times of each meeting, along with the names and other details of the corresponding clients and staff members who are attendees. Please replace `other_client_details` and `other_staff_details` with the actual column names you want to retrieve from the `Clients` and `Staff` tables, respectively.
# Processing index 35
# SELECT T2.First_Name ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID
# For each student answer, find the first name of the student and the date of the answer.
# Sure, I can help you with that. However, I can't access links directly. But based on your description, I'll assume you have tables named `Students` and `Answers`. The `Students` table has a `first_name` field and the `Answers` table has a `student_id`, `answer`, and `answer_date` fields.
#
# Here's a basic SQL query that should work:
#
# ```sql
# SELECT Students.first_name, Answers.answer_date
# FROM Students
# JOIN Answers ON Students.student_id = Answers.student_id;
# ```
#
# This query will join the `Students` and `Answers` tables on the `student_id` field, and then select the `first_name` from the `Students` table and the `answer_date` from the `Answers` table.
#
# Please replace the table and field names with the actual ones from your schema if they are different.
# Processing index 36
# SELECT 	count(DISTINCT T1.pilot_name) FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  'Chicago'
# How many pilots whose planes are in Chicago?
# Based on the provided schema, I am assuming that there are three tables: `pilots`, `planes`, and `airports`. The `pilots` table has a foreign key `plane_id` that links to the `planes` table, and the `planes` table has a foreign key `airport_id` that links to the `airports` table. The `airports` table contains information about different airports, including the city where they are located.
#
# With this information, we can write a SQL query to find the number of pilots whose planes are in Chicago using the following query:
# ```vbnet
# SELECT COUNT(*)
# FROM pilots
# JOIN planes ON pilots.plane_id = planes.id
# JOIN airports ON planes.airport_id = airports.id
# WHERE airports.city = 'Chicago';
# ```
# This query joins the `pilots`, `planes`, and `airports` tables using their respective foreign keys. It then filters the results to only include rows where the `city` column in the `airports` table is equal to 'Chicago'. Finally, it counts the number of rows in the resulting table to find the number of pilots whose planes are in Chicago.
# Processing index 37
# SELECT DISTINCT T1.title FROM book AS T1 JOIN books_order AS T2 ON T1.isbn  =  T2.isbn
# Show the titles of books that have been ordered.
# Based on the schema you've provided, I'm assuming there are tables named `books` and `orders` with relevant columns `book_id`, `title` in the `books` table and `book_id` in the `orders` table. Here's the SQL query to show the titles of books that have been ordered:
#
# ```sql
# SELECT books.title
# FROM books
# JOIN orders ON books.book_id = orders.book_id;
# ```
#
# This query will join the `books` and `orders` tables on the `book_id` column and return the `title` of the books that have been ordered. If the schema differs, please provide the correct schema, and I'll modify the query accordingly.
# Processing index 38
# SELECT T1.date_of_transcript FROM Transcripts AS T1 JOIN Student_Loans AS T2 ON T1.student_id  =  T2.student_id ORDER BY T2.amount_of_loan DESC LIMIT 1
# What is the transcript issuance date for the student with the largest amount of loan?
# I cannot access links directly, but I can help you write the SQL query based on the schema information you provide. Here's a query that should work, assuming the schema has tables named `students`, `loans`, and `transcripts` with appropriate columns:
#
# ```sql
# SELECT t.issuance_date
# FROM transcripts t
# JOIN students s ON t.student_id = s.student_id
# JOIN
# (
#   SELECT student_id, MAX(amount) AS max_loan_amount
#   FROM loans
#   GROUP BY student_id
#   ORDER BY max_loan_amount DESC
#   LIMIT 1
# ) l ON s.student_id = l.student_id;
# ```
#
# Please replace the table and column names with the actual ones from your schema. This query first finds the student with the largest loan amount and then retrieves the transcript issuance date for that student.
# Processing index 39
# SELECT agency_id FROM Agencies EXCEPT SELECT agency_id FROM Clients
# Show all agency ids without any client.
# Based on the schema you provided, I will assume that there are two tables named `agencies` and `clients`. The `clients` table has a foreign key `agency_id` that refers to the `id` column in the `agencies` table. To show all agency ids without any client, we can use a LEFT JOIN and filter out rows where there is no matching client. Here is the SQL query:
#
# ```sql
# SELECT a.id AS agency_id
# FROM agencies a
# LEFT JOIN clients c ON a.id = c.agency_id
# WHERE c.agency_id IS NULL;
# ```
#
# This query will return all agency ids from the `agencies` table that do not have any corresponding clients in the `clients` table.
# Processing index 40
# SELECT conference_name ,  count(*) FROM conference GROUP BY conference_name
# Show all conference names and the number of times each conference has.
# Based on your request, I'll assume the schema has two tables: `Conferences` and `Papers`. The `Conferences` table has a primary key `conference_id` and a column `conference_name`. The `Papers` table has a foreign key `conference_id` linking to the `Conferences` table.
#
# Here's a SQL query that should give you the desired result:
#
# ```sql
# SELECT c.conference_name, COUNT(p.paper_id) AS number_of_times
# FROM Conferences c
# JOIN Papers p ON c.conference_id = p.conference_id
# GROUP BY c.conference_name;
# ```
#
# This query joins the `Conferences` and `Papers` tables using the `conference_id` column, groups the results by `conference_name`, and counts the number of associated papers for each conference.
# Processing index 41
# SELECT DISTINCT OWNER FROM Document_Subset_Members AS T1 JOIN Document_Objects AS T2 ON T1.Related_Document_Object_ID  =  T2.Document_Object_ID WHERE T2.Owner  =  'Braeden';
# What are the different owners of documents that are related to ones owned by Braeden?
# I cannot access external links, but based on your question, I'll assume the following tables exist in your schema: `documents` and `owners`. I'll also assume there is a table `document_relations` that connects related documents. The query might look like this:
#
# ```sql
# SELECT DISTINCT o2.owner_name
# FROM owners AS o1
# JOIN documents AS d1 ON o1.owner_id = d1.owner_id
# JOIN document_relations AS dr ON d1.document_id = dr.document_id_1
# JOIN documents AS d2 ON dr.document_id_2 = d2.document_id
# JOIN owners AS o2 ON d2.owner_id = o2.owner_id
# WHERE o1.owner_name = 'Braeden' AND o2.owner_name <> 'Braeden';
# ```
#
# This query does the following:
#
# 1. Selects distinct owner names (o2.owner_name)
# 2. Joins the owners table (o1) with the documents table (d1) on owner_id
# 3. Joins the document_relations table (dr) with the documents table (d1) on document_id_1
# 4. Joins the documents table (d2) with the document_relations table (dr) on document_id_2
# 5. Joins the owners table (o2) with the documents table (d2) on owner_id
# 6. Filters the results where the owner name is 'Braeden' for the first joined owners table (o1) and excludes 'Braeden' from the second joined owners table (o2) to find different owners that have documents related to Braeden's documents.
# Processing index 42
# SELECT sum(population) ,  avg(population) FROM district WHERE district_id IN (SELECT district_id FROM spokesman_district)
# Find the total and average population of the districts which have some spokesman.
# I'm unable to access links provided in the text, but based on the information you've given, I'll make some assumptions to create a SQL query. I'll assume there exists a `districts` table with columns `district_id`, `population`, and a `spokesmen` table with columns `spokesman_id`, `district_id`.
#
# Here's a SQL query to find the total and average population of the districts that have at least one spokesman:
#
# ```sql
# WITH districts_with_spokesman AS (
#   SELECT districts.district_id, districts.population
#   FROM districts
#   WHERE districts.district_id IN (SELECT spokesmen.district_id FROM spokesmen)
# )
#
# SELECT
#   SUM(population) AS total_population,
#   AVG(population) AS average_population
# FROM districts_with_spokesman;
# ```
#
# This query first creates a common table expression (CTE) named `districts_with_spokesman` that contains the `district_id` and `population` columns of the districts that have at least one spokesman. Then, it selects the total and average population from this CTE.
# Processing index 43
# SELECT pilot_name FROM pilotskills WHERE plane_name  =  'Piper Cub' EXCEPT SELECT pilot_name FROM pilotskills WHERE plane_name  =  'B-52 Bomber'
# Find pilots who own plane Piper Cub but not B-52 Bomber.
# Sure, I'll write a SQL query for you based on the assumption that your schema has two tables: `Pilots` and `Planes`. The `Pilots` table has a `pilot_id` column, and the `Planes` table has a `plane_id`, `pilot_id`, and `plane_name` columns. The `pilot_id` in the `Planes` table is a foreign key that references the `pilot_id` in the `Pilots` table.
#
# Here's the SQL query that should give you the desired result:
#
# ```sql
# SELECT DISTINCT p.pilot_id, p.pilot_name -- Assuming pilot_name exists in Pilots table
# FROM Pilots p
# JOIN Planes pl ON p.pilot_id = pl.pilot_id
# WHERE pl.plane_name = 'Piper Cub'
# AND p.pilot_id NOT IN (
#     SELECT pl2.pilot_id
#     FROM Planes pl2
#     WHERE pl2.plane_name = 'B-52 Bomber'
# );
# ```
#
# This query first selects all pilots who own a 'Piper Cub' and then excludes those who also own a 'B-52 Bomber' using the NOT IN clause.
# Processing index 44
# SELECT T1.conference_name FROM Conference AS T1 JOIN Conference_participation AS T2 ON T1.conference_id  =  T2.conference_id GROUP BY T2.conference_id ORDER BY count(*) DESC LIMIT 2
# Find the name of the conferences that have the top 2 most number of attendants.
# Based on the schema you've provided, I'll assume that there are two tables: `Conferences` and `Attendants`. The `Conferences` table has a primary key `ConferenceID` and a column `Name` for the conference name. The `Attendants` table has a foreign key `ConferenceID` linking to the `Conferences` table.
#
# Here's a SQL query that should give you the desired result:
#
# ```sql
# SELECT c.Name
# FROM Conferences c
# JOIN (
#     SELECT ConferenceID, COUNT(*) as AttendantsCount
#     FROM Attendants
#     GROUP BY ConferenceID
#     ORDER BY COUNT(*) DESC
#     LIMIT 2
# ) a ON c.ConferenceID = a.ConferenceID;
# ```
#
# This query first finds the top 2 conferences with the most attendants by counting the number of attendants per conference and ordering the results in descending order. It then joins the result with the `Conferences` table to get the names of these conferences.
# Processing index 45
# SELECT sum(value) ,  count(*) ,  CONTENTS FROM boxes GROUP BY CONTENTS
# For each content, what is the total value and number of boxes?
# I'm sorry for the inconvenience, but I'm unable to access external links or images. However, I can help you write a SQL query based on a text description of your schema.
#
# Assuming you have two tables, `content` and `box`, with `box` having a foreign key `content_id` that references `content`'s primary key `id`, and `box` has columns `value` and `number`, here's a query that should give you the desired result:
#
# ```sql
# SELECT
#     c.id AS content_id,
#     COALESCE(SUM(b.value), 0) AS total_value,
#     COALESCE(SUM(b.number), 0) AS total_number_of_boxes
# FROM
#     content c
# LEFT JOIN
#     box b ON c.id = b.content_id
# GROUP BY
#     c.id;
# ```
#
# This query uses a `LEFT JOIN` to include all contents, even those that do not have any associated boxes. The `COALESCE` function is used to replace `NULL` values with `0` in case there are no boxes associated with a content. The `SUM` function calculates the total value and number of boxes for each content, and the `GROUP BY` clause groups the results by content.
# Processing index 46
# SELECT T1.PackageNumber ,  max(T1.Weight) FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Sender  =  T2.AccountNumber WHERE T2.Name LIKE "John";
# What is the heaviest package sent by the clients which 'John' is part of their name? List package number and weight.
# Sure, I can help you construct a SQL query for that scenario. However, without the actual schema, I'll have to make some assumptions about the table names and column names. I'm assuming there are tables named `Clients` and `Packages`, and that the `Clients` table has a `ClientName` column and the `Packages` table has a `ClientID`, `PackageNumber`, and `Weight` columns.
#
# Here's a basic SQL query that should work:
#
# ```sql
# SELECT PackageNumber, MAX(Weight) as HeaviestWeight
# FROM Packages
# JOIN Clients ON Packages.ClientID = Clients.ClientID
# WHERE Clients.ClientName LIKE '%John%'
# GROUP BY PackageNumber;
# ```
#
# This query will join the `Clients` and `Packages` tables on the `ClientID` field, filter for clients whose name contains 'John', and then select the `PackageNumber` and the maximum `Weight` for each package.
# Processing index 47
# SELECT DISTINCT T2.stage_presence FROM songs AS T1 JOIN performance_score AS T2 ON T1.id  =  T2.songs_id WHERE T1.language  =  'English'
# What are the distinct stage presence scores for all the songs that are in language 'English' ?
# Based on the information you've provided, I'll assume that there are two tables: `songs` and `scores`. The `songs` table has columns `song_id`, `title`, and `language`, while the `scores` table has columns `score_id`, `song_id`, and `stage_presence_score`.
#
# Here's a SQL query that should return the distinct stage presence scores for all songs in the 'English' language:
#
# ```sql
# SELECT DISTINCT scores.stage_presence_score
# FROM scores
# JOIN songs ON scores.song_id = songs.song_id
# WHERE songs.language = 'English';
# ```
#
# This query first joins the `scores` table with the `songs` table on the `song_id` column. Then, it filters the results to only include songs where the language is 'English'. Finally, it selects the distinct `stage_presence_score` values from the filtered results.
# Processing index 48
# SELECT T2.First_Name ,  T1.Date_of_Answer FROM Student_Answers AS T1 JOIN Students AS T2 ON T1.Student_ID  =  T2.Student_ID
# Please show the first names of students and the dates of their answers.
# I'm sorry for the inconvenience, but I'm unable to access external links or images. However, I can help you construct a SQL query based on a text description of the schema.
#
# Assuming you have two tables, `Students` and `Answers`, where `Students` has a column `first_name` and `Answers` has columns `student_id`, `answer`, and `answer_date`, and `student_id` in `Answers` is a foreign key referencing `Students`, the SQL query would look like this:
#
# ```sql
# SELECT Students.first_name, Answers.answer_date
# FROM Students
# JOIN Answers ON Students.student_id = Answers.student_id;
# ```
#
# This query will return the first names of students along with the dates of their answers. If there are multiple answers per student, each answer date will be listed separately. Please replace the table and column names with the ones that match your schema.
# Processing index 49
# SELECT avg(age) ,  plane_name FROM pilotskills GROUP BY plane_name
# What is the average age of pilots for different types of planes?
# I cannot access links directly, but I can help you write the SQL query based on the schema information you provide. Please provide the necessary table names and column names for me to assist you better.
#
# Based on your question, I assume you have the following tables:
# 1. pilots - with columns: pilot_id, name, birthdate
# 2. planes - with columns: plane_id, name, type
# 3. pilot_plane - with columns: pilot_id, plane_id
#
# Here's a sample SQL query that calculates the average age of pilots for different types of planes:
#
# ```sql
# SELECT
#   p.type AS plane_type,
#   AVG(EXTRACT(YEAR FROM CURRENT_DATE) - EXTRACT(YEAR FROM pi.birthdate)) AS average_age
# FROM
#   planes p
# JOIN
#   pilot_plane pp ON p.plane_id = pp.plane_id
# JOIN
#   pilots pi ON pp.pilot_id = pi.pilot_id
# GROUP BY
#   p.type;
# ```
#
# Please replace the table and column names with the actual ones from your schema.
# Processing index 50
# SELECT T2.width_mm FROM artists AS T1 JOIN paintings AS T2 ON T1.artistID  =  T2.painterID WHERE T1.birthYear  <  1850
# What are the widths of the paintings that were created by the artist who was born before 1850?
# Based on the schema links you provided, I have assumed the following table names and column names for writing the SQL query:
#
# - The table for paintings is named 'paintings' and has columns 'painting_id', 'title', 'artist_id', 'width', and 'height'.
# - The table for artists is named 'artists' and has columns 'artist_id', 'name', 'birth_year', and 'death_year'.
#
# Here's the SQL query for the given scenario:
#
# ```sql
# SELECT p.width
# FROM paintings AS p
# JOIN artists AS a ON p.artist_id = a.artist_id
# WHERE a.birth_year < 1850;
# ```
#
# This query selects the widths of the paintings from the 'paintings' table and joins it with the 'artists' table based on the artist_id foreign key. The WHERE clause filters the results to only show the paintings created by artists who were born before 1850.
# Processing index 51
# SELECT Neighborhood FROM store EXCEPT SELECT t1.Neighborhood FROM store AS t1 JOIN stock AS t2 ON t1.store_id  =  t2.store_id
# Which neighborhood does not have any headphone in stock?
# I cannot access links directly, but I can help you write the SQL query based on the information you provide. Please provide the table names and relevant columns.
#
# Assuming you have two tables, `neighborhoods` and `stores`:
#
# - `neighborhoods` table has a column `id` and `name`.
# - `stores` table has columns `id`, `neighborhood_id`, `product`, and `stock`.
#
# The query to find the neighborhoods without any headphones in stock would look like this:
#
# ```sql
# SELECT n.name
# FROM neighborhoods n
# LEFT JOIN stores s ON n.id = s.neighborhood_id AND s.product = 'headphone' AND s.stock > 0
# WHERE s.id IS NULL;
# ```
#
# ...
# How many papers do we have?
# I'm sorry for the inconvenience, but I'm unable to access external links or resources. However, I can help you write a SQL query to count the number of papers based on the assumption that you have a table named `papers`.
#
# Here's the SQL query:
#
# ```sql
# SELECT COUNT(*) AS total_papers
# FROM papers;
# ```
#
# This query will return the total number of rows in the `papers` table, which should correspond to the number of papers you have. If the table has a different name, please replace `papers` with the correct table name.
# Processing index 281
# select title from book order by saleprice asc limit 1
# What are the titles of books that have a sale price equal to the lowest sale price across all books ?
# Based on the information you've provided, I'll assume that there is a table named `Books` with columns `title` and `sale_price`. Here's a SQL query that should give you the desired result:
#
# ```sql
# SELECT title
# FROM Books
# WHERE sale_price = (
#   SELECT MIN(sale_price)
#   FROM Books
# );
# ```
#
# This query first finds the minimum sale price across all books using a subquery. Then, it selects the titles of the books that have a sale price equal to the found minimum sale price. If there are multiple books with the same lowest sale price, this query will return all of them.
# Processing index 282
# SELECT customer_details FROM customers WHERE customer_details LIKE "%Kutch%"
# Find all the customers whose name contains "Kutch".
# Based on the information provided, I will assume that the schema includes a table named "Customers" with a column named "Name". The SQL query to find all the customers whose name contains "Kutch" would be:
#
# ```sql
# SELECT *
# FROM Customers
# WHERE Name LIKE '%Kutch%';
# ```
#
# This query will return all the records from the "Customers" table where the "Name" column contains the substring "Kutch". If the schema or table names are different, please provide the correct names, and I will adjust the query accordingly.
# Processing index 283
# SELECT DISTINCT payment_method_code FROM Customers
# Give the different payment method codes that customers use.
# Based on the information you've provided, I'll assume that there is a table named `payments` or `orders` which contains information about customer payments, including a column for the payment method code. Let's call this column `payment_method_code`. Here's a SQL query that will return the different payment method codes used by customers:
#
# ```sql
# SELECT DISTINCT payment_method_code
# FROM payments;
# ```
#
# Replace `payments` with the actual table name containing the payment method information. If the column name for the payment method code is different, replace `payment_method_code` with the correct column name.
# Processing index 284
# SELECT count(*) FROM Staff
# How many staff do we have?
# Sure, I'd be happy to help you write a SQL query to find out how many staff members you have. However, I'm unable to access external links, so I'll provide a general query based on the assumption that you have a table named `staff` or something similar.
#
# Here's a simple SQL query that should do the trick:
#
# ```sql
# SELECT COUNT(*) FROM staff;
# ```
#
# This query will return the total number of rows in the `staff` table, which should correspond to the number of staff members you have. Please replace `staff` with the actual table name in your database that stores staff information.
# Processing index 285
# SELECT count(*) FROM pilotskills WHERE age  >  40
# How many pilots who are older than 40?
# Based on the schema you've provided, I'm assuming there's a table named `pilots` with a column named `age` or `date_of_birth`. If there's an `age` column, we can directly compare it with 40. Otherwise, if there's a `date_of_birth` column, we'll need to calculate the age first.
#
# Here are the queries for both scenarios:
#
# 1. With an `age` column:
#
# ```sql
# SELECT COUNT(*)
# FROM pilots
# WHERE age > 40;
# ```
#
# 2. With a `date_of_birth` column (assuming the `date_of_birth` is in the format 'YYYY-MM-DD'):
#
# ```sql
# SELECT COUNT(*)
# FROM pilots
# WHERE YEAR(CURRENT_DATE) - YEAR(date_of_birth) > 40;
# ```
# Processing index 286
# SELECT flavor FROM goods WHERE food  =  "Cake" AND price  >  10
# Find flavor of cakes that cost more than 10 dollars.
# Sure, I'd be happy to help you write a SQL query for that scenario. However, I'm unable to access links or external resources. But based on your description, I can provide a general query.
#
# Assuming you have two tables, `Cakes` and `Flavors`, where `Cakes` has columns `cake_id`, `price`, and `flavor_id`, and `Flavors` has columns `flavor_id` and `flavor_name`, the query would look something like this:
#
# ```sql
# SELECT Flavors.flavor_name
# FROM Flavors
# JOIN Cakes ON Flavors.flavor_id = Cakes.flavor_id
# WHERE Cakes.price > 10;
# ```
#
# This query will return the flavor names of cakes that cost more than 10 dollars. Please replace the table and column names with the actual ones from your schema.
# Processing index 287
# SELECT city_name FROM City WHERE state  =  "PA"
# Show names for all cities in state PA.
# Based on the information you've provided, I'll assume that there are two tables: `cities` and `states`. The `cities` table has columns `city_name` and `state_id`, while the `states` table has columns `state_id` and `state_name`.
#
# Here is the SQL query to show names for all cities in state PA:
#
# ```sql
# SELECT cities.city_name
# FROM cities
# JOIN states ON cities.state_id = states.state_id
# WHERE states.state_name = 'PA';
# ```
#
# This query joins the `cities` table and the `states` table on the `state_id` column and then filters for the state name 'PA'. The result is the names of all cities in the state of PA.
# Processing index 288
# SELECT count(*) FROM performance_score WHERE stage_presence  <  7 OR stage_presence  >  9
# How many performances have a stage presence score less than 7 or higher than 9?
# Based on the schema you've provided, I'll assume there is a table named `performances` with a column named `stage_presence_score`. Here's the SQL query to get the number of performances with a stage presence score less than 7 or higher than 9:
#
# ```sql
# SELECT COUNT(*)
# FROM performances
# WHERE stage_presence_score < 7 OR stage_presence_score > 9;
# ```
#
# This query will return the count of performances where the `stage_presence_score` is less than 7 or greater than 9. Make sure to replace the table and column names if they are different in your schema.
# Processing index 289
# SELECT DISTINCT title FROM paintings ORDER BY height_mm
# List the names of all distinct paintings ordered by length.
# Based on the information you've provided, I'll assume that there is a table named `Paintings` with a column named `name` or `title` that contains the names of the paintings. Here's a SQL query to list the names of all distinct paintings ordered by the length of their names:
#
# ```sql
# SELECT DISTINCT name
# FROM Paintings
# ORDER BY LENGTH(name);
# ```
#
# This query selects all unique painting names from the `Paintings` table and orders them by the length of their names in ascending order. If you want to order them by the length of their names in descending order, you can modify the query like this:
#
# ```sql
# SELECT DISTINCT name
# FROM Paintings
# ORDER BY LENGTH(name) DESC;
# ```
# Processing index 290
# SELECT fname  ,  deathYear - birthYear FROM artists ORDER BY deathYear - birthYear DESC LIMIT 1
# What is the first name and age of the artist who lived the longest?
# I'm unable to access links, but I can provide you with a general SQL query structure based on the information you've given. Assume that there are two tables: `Artist` and `Lifespan`, where `Artist` has columns like `ArtistID`, `FirstName`, and `Age`, and `Lifespan` has columns like `ArtistID`, `BirthYear`, and `DeathYear`.
#
# Here's the SQL query:
#
# ```sql
# SELECT Artist.FirstName, (Lifespan.DeathYear - Lifespan.BirthYear) AS Age
# FROM Artist
# JOIN Lifespan ON Artist.ArtistID = Lifespan.ArtistID
# ORDER BY (Lifespan.DeathYear - Lifespan.BirthYear) DESC
# LIMIT 1;
# ```
#
# This query performs the following actions:
# 1. Joins the `Artist` and `Lifespan` tables based on the `ArtistID` column.
# 2. Calculates the artist's age by subtracting their birth year from their death year.
# 3. Orders the results in descending order based on the calculated age.
# 4. Limits the results to just the top 1 record, which represents the artist who lived the longest.
#
# Please replace the table and column names with the actual ones from your schema.
# Processing index 291
# SELECT customer_address ,  customer_phone ,  customer_email FROM Customers WHERE customer_name  =  "Jeromy"
# What is the customer address, customer phone, and customer email for Jeromy?
# Based on the schema you've provided, it seems that the customer details can be found in the "customer" table. To retrieve the address, phone, and email for a customer named "Jeromy", you can use the following SQL query:
#
# ```sql
# SELECT address, phone, email
# FROM customer
# WHERE first_name = 'Jeromy';
# ```
#
# Please note that this query assumes that the first_name column is used to store the customer's first name and that it is unique. If there can be multiple customers with the same first name, consider using a more unique identifier such as the customer's ID or including the last name in the WHERE clause. Additionally, make sure to replace the column names in the SELECT statement with the actual column names from your schema if they are different.
# Processing index 292
# SELECT paintingID ,  height_mm FROM paintings WHERE LOCATION  =  'Gallery 240' ORDER BY width_mm DESC LIMIT 1
# What are the id and height of the painting with the longest width in gallery 240?
# Based on the schema you provided, the SQL query to find the id and height of the painting with the longest width in gallery 240 would look something like this:
#
# ```sql
# SELECT id, height
# FROM Paintings
# WHERE gallery_id = 240
# ORDER BY width DESC
# LIMIT 1;
# ```
#
# This query will first filter the paintings to only those in gallery 240, then order them by width in descending order (largest width first), and finally return the id and height of the first painting in that ordered list (the painting with the longest width).
#
# Please replace the table and column names if they are different in your schema.
# Processing index 293
# SELECT count(DISTINCT CONTENTS) FROM boxes
# How many different contents are stored in boxes?
# I cannot access links directly, but I can help you write the SQL query based on the schema information you provide.
#
# Suppose your schema has two tables, `boxes` and `contents`, with a foreign key relationship between them. Let's assume the primary key of the `boxes` table is `box_id`, and the `contents` table has a foreign key `box_id` to refer to the box where the content is stored.
#
# The query to find out how many different contents are stored in boxes would be:
#
# ```sql
# SELECT COUNT(DISTINCT content_id) AS different_contents
# FROM contents;
# ```
#
# This assumes the primary key of the `contents` table is `content_id`. If the primary key column of the `contents` table has a different name, please replace `content_id` with the correct column name in the query.
# Processing index 294
# SELECT count(*) FROM author WHERE age  <  30
# how many authors are under age 30?
# I cannot access links directly, but I can help you write the SQL query based on the assumption that your schema has an "authors" table with a "birthdate" column.
#
# The query would look something like this:
#
# ```sql
# SELECT COUNT(*)
# FROM authors
# WHERE YEAR(CURDATE()) - YEAR(birthdate) < 30;
# ```
#
# This query calculates the difference in years between the current date and the birthdate of each author, and then counts the number of authors for whom this difference is less than 30.
#
# Please adjust the table and column names accordingly if they are different in your schema.
# Processing index 295
# SELECT avg(product_price) FROM Products
# What is the product average price?
# Based on your request, I'll provide a general SQL query to find the average price of products since the actual schema isn't provided. Please replace the `products` table name and `price` column name with the appropriate ones from your schema.
#
# ```sql
# SELECT AVG(price) AS average_price
# FROM products;
# ```
#
# This query calculates the average price of all products in the `products` table. If you need a more specific query, please provide the schema link or details, and I'll be glad to help.
# Processing index 296
# SELECT Name FROM player ORDER BY Wins_count ASC
# Return the names of players in order of count of wins, ascending.
# Based on the schema you've provided, I'll assume there are two tables: `Players` and `Matches`. The `Players` table has columns `player_id` and `player_name`, while the `Matches` table has columns `match_id`, `winner_id`, and other irrelevant columns. The `winner_id` in the `Matches` table refers to the `player_id` in the `Players` table.
#
# Here's a SQL query to return the names of players in order of the count of their wins, ascending:
#
# ```sql
# SELECT p.player_name, COUNT(m.winner_id) as win_count
# FROM Players p
# LEFT JOIN Matches m ON p.player_id = m.winner_id
# GROUP BY p.player_name
# ORDER BY win_count ASC;
# ```
#
# This query first joins the `Players` and `Matches` tables based on the `player_id` and `winner_id` columns. Then, it groups the results by the `player_name` to count the number of wins for each player. Finally, it orders the results in ascending order based on the `win_count`.
# Processing index 297
# SELECT address_id ,  address_details FROM Addresses
# List all address ids and address details.
# Sure, I'd be happy to help you with that. However, I can't access links directly. But based on your request, if you have a table named `Address` with columns like `id`, `street`, `city`, `state`, `zip_code`, etc., a simple SQL query to list all address ids and address details would look like this:
#
# ```sql
# SELECT id, street, city, state, zip_code
# FROM Address;
# ```
#
# This query will return all rows from the `Address` table, showing the id and all address details for each row. Please replace the column names with the actual ones from your schema.
# Processing index 298
# SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  < 1885 OR YEAR  >  1930
# Which locations have paintings created before 1885 or after 1930?
# Sure, I'd be happy to help you construct a SQL query for this scenario. However, as I'm a text-based AI, I'm unable to directly access links or external resources. But I can certainly help you based on the information you've provided.
#
# Assuming your schema includes tables named `Paintings` and `Locations`, and the `Paintings` table has columns `painting_id`, `year_created`, and `location_id`, and the `Locations` table has columns `location_id` and `location_name`, the query might look something like this:
#
# ```sql
# SELECT Locations.location_name
# FROM Locations
# JOIN Paintings ON Locations.location_id = Paintings.location_id
# WHERE Paintings.year_created < 1885 OR Paintings.year_created > 1930;
# ```
#
# This query will return the names of locations that have paintings created before 1885 or after 1930. Please replace the table and column names with the actual ones from your schema if they are different.
# Processing index 299
# SELECT name ,  address FROM Client ORDER BY name
# What are the names and addressed of all clients, ordered alphabetically by name?
# Based on your request, I'll assume that the schema consists of two tables: `clients` and `addresses`. The `clients` table has columns `client_id`, `name`, and other columns, while the `addresses` table has columns `address_id`, `client_id`, `address`, and other columns. Here's a SQL query to get the names and addresses of all clients, ordered alphabetically by name:
#
# ```sql
# SELECT clients.name, addresses.address
# FROM clients
# JOIN addresses ON clients.client_id = addresses.client_id
# ORDER BY clients.name ASC;
# ```
#
# This query will join the `clients` table and `addresses` table based on the `client_id` column and return the names and addresses of all clients ordered alphabetically by name. If the schema is different, please provide the correct schema links, and I will update the query accordingly.

# %%
import pandas as pd
import time
import os
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

#----------------------------------------------------prompts-----------------------------------------------
schema_linking_prompt = '''Table advisor, columns = [*,s_ID,i_ID]
Table classroom, columns = [*,building,room_number,capacity]
Table course, columns = [*,course_id,title,dept_name,credits]
Table department, columns = [*,dept_name,building,budget]
Table instructor, columns = [*,ID,name,dept_name,salary]
Table prereq, columns = [*,course_id,prereq_id]
Table section, columns = [*,course_id,sec_id,semester,year,building,room_number,time_slot_id]
Table student, columns = [*,ID,name,dept_name,tot_cred]
Table takes, columns = [*,ID,course_id,sec_id,semester,year,grade]
Table teaches, columns = [*,ID,course_id,sec_id,semester,year]
Table time_slot, columns = [*,time_slot_id,day,start_hr,start_min,end_hr,end_min]
Foreign_keys = [course.dept_name = department.dept_name,instructor.dept_name = department.dept_name,section.building = classroom.building,section.room_number = classroom.room_number,section.course_id = course.course_id,teaches.ID = instructor.ID,teaches.course_id = section.course_id,teaches.sec_id = section.sec_id,teaches.semester = section.semester,teaches.year = section.year,student.dept_name = department.dept_name,takes.ID = student.ID,takes.course_id = section.course_id,takes.sec_id = section.sec_id,takes.semester = section.semester,takes.year = section.year,advisor.s_ID = student.ID,advisor.i_ID = instructor.ID,prereq.prereq_id = course.course_id,prereq.course_id = course.course_id]
Q: "Find the buildings which have rooms with capacity more than 50."
A: Let’s think step by step. In the question "Find the buildings which have rooms with capacity more than 50.", we are asked:
"the buildings which have rooms" so we need column = [classroom.capacity]
"rooms with capacity" so we need column = [classroom.building]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [50]. So the Schema_links are:
Schema_links: [classroom.building,classroom.capacity,50]

Table department, columns = [*,Department_ID,Name,Creation,Ranking,Budget_in_Billions,Num_Employees]
Table head, columns = [*,head_ID,name,born_state,age]
Table management, columns = [*,department_ID,head_ID,temporary_acting]
Foreign_keys = [management.head_ID = head.head_ID,management.department_ID = department.Department_ID]
Q: "How many heads of the departments are older than 56 ?"
A: Let’s think step by step. In the question "How many heads of the departments are older than 56 ?", we are asked:
"How many heads of the departments" so we need column = [head.*]
"older" so we need column = [head.age]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [56]. So the Schema_links are:
Schema_links: [head.*,head.age,56]

Table city, columns = [*,City_ID,Official_Name,Status,Area_km_2,Population,Census_Ranking]
Table competition_record, columns = [*,Competition_ID,Farm_ID,Rank]
Table farm, columns = [*,Farm_ID,Year,Total_Horses,Working_Horses,Total_Cattle,Oxen,Bulls,Cows,Pigs,Sheep_and_Goats]
Table farm_competition, columns = [*,Competition_ID,Year,Theme,Host_city_ID,Hosts]
Foreign_keys = [farm_competition.Host_city_ID = city.City_ID,competition_record.Farm_ID = farm.Farm_ID,competition_record.Competition_ID = farm_competition.Competition_ID]
Q: "Show the status shared by cities with population bigger than 1500 and smaller than 500."
A: Let’s think step by step. In the question "Show the status shared by cities with population bigger than 1500 and smaller than 500.", we are asked:
"the status shared by cities" so we need column = [city.Status]
"cities with population" so we need column = [city.Population]
Based on the columns and tables, we need these Foreign_keys = [].
Based on the tables, columns, and Foreign_keys, The set of possible cell values are = [1500,500]. So the Schema_links are:
Schema_links: [city.Status,city.Population,1500,500]

'''
classification_prompt = '''Q: "Find the buildings which have rooms with capacity more than 50."
schema_links: [classroom.building,classroom.capacity,50]
A: Let’s think step by step. The SQL query for the question "Find the buildings which have rooms with capacity more than 50." needs these tables = [classroom], so we don't need JOIN.
Plus, it doesn't require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we don't need JOIN and don't need nested queries, then the the SQL query can be classified as "EASY".
Label: "EASY"

Q: "What are the names of all instructors who advise students in the math depart sorted by total credits of the student."
schema_links: [advisor.i_id = instructor.id,advisor.s_id = student.id,instructor.name,student.dept_name,student.tot_cred,math]
A: Let’s think step by step. The SQL query for the question "What are the names of all instructors who advise students in the math depart sorted by total credits of the student." needs these tables = [advisor,instructor,student], so we need JOIN.
Plus, it doesn't need nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we need JOIN and don't need nested queries, then the the SQL query can be classified as "NON-NESTED".
Label: "NON-NESTED"

Q: "How many courses that do not have prerequisite?"
schema_links: [course.*,course.course_id = prereq.course_id]
A: Let’s think step by step. The SQL query for the question "How many courses that do not have prerequisite?" needs these tables = [course,prereq], so we need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["Which courses have prerequisite?"].
So, we need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

Q: "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010."
schema_links: [teaches.id,teaches.semester,teaches.year,Fall,2009,Spring,2010]
A: Let’s think step by step. The SQL query for the question "Find the id of instructors who taught a class in Fall 2009 but not in Spring 2010." needs these tables = [teaches], so we don't need JOIN.
Plus, it requires nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = ["Find the id of instructors who taught a class in Spring 2010"].
So, we don't need JOIN and need nested queries, then the the SQL query can be classified as "NESTED".
Label: "NESTED"

Q: "Find the name of the department that offers the highest total credits?"
schema_links: [course.dept_name,course.credits]
A: Let’s think step by step. The SQL query for the question "Find the name of the department that offers the highest total credits?." needs these tables = [course], so we don't need JOIN.
Plus, it doesn't require nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we don't need JOIN and don't need nested queries, then the the SQL query can be classified as "EASY".
Label: "EASY"

Q: "What is the name of the instructor who advises the student with the greatest number of total credits?"
schema_links: [advisor.i_id = instructor.id,advisor.s_id = student.id,instructor.name,student.tot_cred ]
A: Let’s think step by step. The SQL query for the question "What is the name of the instructor who advises the student with the greatest number of total credits?" needs these tables = [advisor,instructor,student], so we need JOIN.
Plus, it doesn't need nested queries with (INTERSECT, UNION, EXCEPT, IN, NOT IN), and we need the answer to the questions = [""].
So, we need JOIN and don't need nested queries, then the the SQL query can be classified as "NON-NESTED".
Label: "NON-NESTED"
'''

easy_prompt = '''Q: "Find the buildings which have rooms with capacity more than 50."
Schema_links: [classroom.building,classroom.capacity,50]
SQL: SELECT DISTINCT building FROM classroom WHERE capacity  >  50

Q: "Find the room number of the rooms which can sit 50 to 100 students and their buildings."
Schema_links: [classroom.building,classroom.room_number,classroom.capacity,50,100]
SQL: SELECT building ,  room_number FROM classroom WHERE capacity BETWEEN 50 AND 100

Q: "Give the name of the student in the History department with the most credits."
Schema_links: [student.name,student.dept_name,student.tot_cred,History]
SQL: SELECT name FROM student WHERE dept_name  =  'History' ORDER BY tot_cred DESC LIMIT 1
'''

medium_prompt = '''Q: "Find the total budgets of the Marketing or Finance department."
Schema_links: [department.budget,department.dept_name,Marketing,Finance]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = []. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select sum(department.budget) from department  where  department.dept_name = \"Marketing\"  or  department.dept_name = \"Finance\"
SQL: SELECT sum(budget) FROM department WHERE dept_name  =  'Marketing' OR dept_name  =  'Finance'

Q: "Find the name and building of the department with the highest budget."
Schema_links: [department.budget,department.dept_name,department.building]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = []. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: select department.dept_name , department.building from department  order by department.budget desc limit 1
SQL: SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1

Q: "Find the total number of students and total number of instructors for each department."
Schema_links: [department.dept_name = student.dept_name,student.id,department.dept_name = instructor.dept_name,instructor.id]
A: Let’s think step by step. For creating the SQL for the given question, we need to join these tables = [department,student,instructor]. First, create an intermediate representation, then use it to construct the SQL query.
Intermediate_representation: "select count( distinct student.ID) , count( distinct instructor.ID) , department.dept_name from department  group by instructor.dept_name
SQL: SELECT count(DISTINCT T2.id) ,  count(DISTINCT T3.id) ,  T3.dept_name FROM department AS T1 JOIN student AS T2 ON T1.dept_name  =  T2.dept_name JOIN instructor AS T3 ON T1.dept_name  =  T3.dept_name GROUP BY T3.dept_name

'''

hard_prompt = '''Q: "Find the title of courses that have two prerequisites?"
Schema_links: [course.title,course.course_id = prereq.course_id]
A: Let's think step by step. "Find the title of courses that have two prerequisites?" can be solved by knowing the answer to the following sub-question "What are the titles for courses with two prerequisites?".
The SQL query for the sub-question "What are the titles for courses with two prerequisites?" is SELECT T1.title FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  =  2
So, the answer to the question "Find the title of courses that have two prerequisites?" is =
Intermediate_representation: select course.title from course  where  count ( prereq.* )  = 2  group by prereq.course_id
SQL: SELECT T1.title FROM course AS T1 JOIN prereq AS T2 ON T1.course_id  =  T2.course_id GROUP BY T2.course_id HAVING count(*)  =  2

Q: "Find the name and building of the department with the highest budget."
Schema_links: [department.dept_name,department.building,department.budget]
A: Let's think step by step. "Find the name and building of the department with the highest budget." can be solved by knowing the answer to the following sub-question "What is the department name and corresponding building for the department with the greatest budget?".
The SQL query for the sub-question "What is the department name and corresponding building for the department with the greatest budget?" is SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1
So, the answer to the question "Find the name and building of the department with the highest budget." is =
Intermediate_representation: select department.dept_name , department.building from department  order by department.budget desc limit 1
SQL: SELECT dept_name ,  building FROM department ORDER BY budget DESC LIMIT 1

Q: "Find the salaries of all distinct instructors that are less than the largest salary."
Schema_links: [instructor.salary]
A: Let's think step by step. "Find the salaries of all distinct instructors that are less than the largest salary." can be solved by knowing the answer to the following sub-question "What is the largest salary of instructors".
The SQL query for the sub-question "What is the largest salary of instructors" is SELECT max(salary) FROM instructor
So, the answer to the question "Find the salaries of all distinct instructors that are less than the largest salary." is =
Intermediate_representation: select  distinct instructor.salary from instructor  where  @.@ < max ( instructor.salary )
SQL: SELECT DISTINCT salary FROM instructor WHERE salary  <  (SELECT max(salary) FROM instructor)
'''

# Set your Mistral API key
API_KEY = '*****'
os.environ["MISTRAL_API_KEY"] = API_KEY

# Initialize the Mistral Client
client = MistralClient(api_key=os.getenv("MISTRAL_API_KEY"))

# Paths for input and output
DATASET_SCHEMA = "/content/drive/MyDrive/Colab Notebooks/data_usage/dev_tables.json"
DATASET = "/content/drive/MyDrive/Colab Notebooks/data_usage/mistral_dev.json"
OUTPUT_FILE = "./predicted_sql.txt"

def load_data(DATASET):
    return pd.read_json(DATASET)

def hard_prompt_maker(test_sample_text, database, schema_links, sub_questions):
    instruction = "# Use the intermediate representation and the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    stepping = f'''\nA: Let's think step by step. "{test_sample_text}" can be solved by knowing the answer to the following sub-question "{sub_questions}".'''
    fields += "\n"
    prompt = instruction + fields + hard_prompt + 'Q: "' + test_sample_text + '"' + '\nschema_links: ' + schema_links + stepping + '\nThe SQL query for the sub-question'
    return prompt

def medium_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links and Intermediate_representation to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + medium_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def easy_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# Use the schema links to generate the SQL queries for each of the questions.\n"
    fields = find_fields_MYSQL_like(database)
    fields += "\n"
    prompt = instruction + fields + easy_prompt + 'Q: "' + test_sample_text + '\nSchema_links: ' + schema_links + '\nSQL:'
    return prompt

def classification_prompt_maker(test_sample_text, database, schema_links):
    instruction = "# For the given question, classify it as EASY, NON-NESTED, or NESTED based on nested queries and JOIN.\n"
    instruction += "\nif need nested queries: predict NESTED\n"
    instruction += "elif need JOIN and don't need nested queries: predict NON-NESTED\n"
    instruction += "elif don't need JOIN and don't need nested queries: predict EASY\n\n"
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "\n"
    prompt = instruction + fields + classification_prompt + 'Q: "' + test_sample_text + '\nschema_links: ' + schema_links + '\nA: Let’s think step by step.'
    return prompt

def schema_linking_prompt_maker(test_sample_text, database):
    instruction = "# Find the schema_links for generating SQL queries for each question based on the database schema and Foreign keys.\n"
    fields = find_fields_MYSQL_like(database)
    foreign_keys = "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    prompt = instruction + schema_linking_prompt + fields + foreign_keys + 'Q: "' + test_sample_text + """"\nA: Let’s think step by step."""
    return prompt

def find_foreign_keys_MYSQL_like(db_name):
    df = spider_foreign[spider_foreign['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['First Table Name'] + '.' + row['First Table Foreign Key'] + " = " + row['Second Table Name'] + '.' + row['Second Table Foreign Key'] + ','
    output = output[:-1] + "]"
    return output

def find_fields_MYSQL_like(db_name):
    df = spider_schema[spider_schema['Database name'] == db_name]
    df = df.groupby(' Table Name')
    output = ""
    for name, group in df:
        output += "Table " + name + ', columns = ['
        for index, row in group.iterrows():
            output += row[" Field Name"] + ','
        output = output[:-1]
        output += "]\n"
    return output

def find_primary_keys_MYSQL_like(db_name):
    df = spider_primary[spider_primary['Database name'] == db_name]
    output = "["
    for index, row in df.iterrows():
        output += row['Table Name'] + '.' + row['Primary Key'] + ','
    output = output[:-1]
    output += "]\n"
    return output

def create_schema(DATASET_JSON):
    schema_df = pd.read_json(DATASET_JSON)
    schema_df = schema_df.drop(['column_names', 'table_names'], axis=1)
    schema = []
    f_keys = []
    p_keys = []
    for index, row in schema_df.iterrows():
        tables = row['table_names_original']
        col_names = row['column_names_original']
        col_types = row['column_types']
        foreign_keys = row['foreign_keys']
        primary_keys = row['primary_keys']
        for col, col_type in zip(col_names, col_types):
            index, col_name = col
            if index == -1:
                for table in tables:
                    schema.append([row['db_id'], table, '*', 'text'])
            else:
                schema.append([row['db_id'], tables[index], col_name, col_type])
        for primary_key in primary_keys:
            index, column = col_names[primary_key]
            p_keys.append([row['db_id'], tables[index], column])
        for foreign_key in foreign_keys:
            first, second = foreign_key
            first_index, first_column = col_names[first]
            second_index, second_column = col_names[second]
            f_keys.append([row['db_id'], tables[first_index], tables[second_index], first_column, second_column])
    spider_schema = pd.DataFrame(schema, columns=['Database name', ' Table Name', ' Field Name', ' Type'])
    spider_primary = pd.DataFrame(p_keys, columns=['Database name', 'Table Name', 'Primary Key'])
    spider_foreign = pd.DataFrame(f_keys,
                                  columns=['Database name', 'First Table Name', 'Second Table Name', 'First Table Foreign Key',
                                           'Second Table Foreign Key'])
    return spider_schema, spider_primary, spider_foreign

def debuger(test_sample_text, database, sql):
    instruction = """#### For the given question, use the provided tables, columns, foreign keys, and primary keys to fix the given SQLite SQL QUERY for any issues. If there are any problems, fix them. If there are no issues, return the SQLite SQL QUERY as is.
#### Use the following instructions for fixing the SQL QUERY:
1) Use the database values that are explicitly mentioned in the question.
2) Pay attention to the columns that are used for the JOIN by using the Foreign_keys.
3) Use DESC and DISTINCT when needed.
4) Pay attention to the columns that are used for the GROUP BY statement.
5) Pay attention to the columns that are used for the SELECT statement.
6) Only change the GROUP BY clause when necessary (Avoid redundant columns in GROUP BY).
7) Use GROUP BY on one column only.

"""
    fields = find_fields_MYSQL_like(database)
    fields += "Foreign_keys = " + find_foreign_keys_MYSQL_like(database) + '\n'
    fields += "Primary_keys = " + find_primary_keys_MYSQL_like(database)
    prompt = instruction + fields + '#### Question: ' + test_sample_text + '\n#### SQLite SQL QUERY\n' + sql + '\n#### SQLite FIXED SQL QUERY\nSELECT'
    return prompt

def mistral_generation(prompt, temperature=0.0, max_tokens=600):
    try:
        chat_response = client.chat(
            model="mistral-large-latest",
            messages=[ChatMessage(role="user", content=prompt)]
        )
        if chat_response.choices:
            return chat_response.choices[0].message.content
        return "No valid response received."
    except Exception as e:
        print(f"Error during Mistral call: {e}")
        return None

if __name__ == '__main__':
    spider_schema, spider_primary, spider_foreign = create_schema(DATASET_SCHEMA)
    val_df = load_data(DATASET)
    print(f"Number of data samples {val_df.shape[0]}")
    CODEX = []

    for index, row in val_df.iterrows():
        print(f"Processing index {index}")
        print(row['query'])
        print(row['question'])

        schema_links = None
        while schema_links is None:
            try:
                schema_links = mistral_generation(schema_linking_prompt_maker(row['question'], row['db_id']))
            except Exception as e:
                print(f"Error getting schema links for index {index}: {e}")
                time.sleep(3)

        try:
            schema_links = schema_links.split("Schema_links: ")[1]
        except Exception as e:
            print(f"Slicing error for the schema_linking module at index {index}: {e}")
            schema_links = "[]"

        classification = None
        while classification is None:
            try:
                classification = mistral_generation(classification_prompt_maker(row['question'], row['db_id'], schema_links[1:]))
            except Exception as e:
                print(f"Error during classification at index {index}: {e}")
                time.sleep(3)

        try:
            predicted_class = classification.split("Label: ")[1]
        except Exception as e:
            print(f"Slicing error for the classification module at index {index}: {e}")
            predicted_class = '"NESTED"'

        if '"EASY"' in predicted_class:
            print("EASY")
            SQL = None
            while SQL is None:
                try:
                    SQL = mistral_generation(easy_prompt_maker(row['question'], row['db_id'], schema_links))
                except Exception as e:
                    print(f"Error generating easy SQL at index {index}: {e}")
                    time.sleep(10)

        elif '"NON-NESTED"' in predicted_class:
            print("NON-NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = mistral_generation(medium_prompt_maker(row['question'], row['db_id'], schema_links))
                except Exception as e:
                    print(f"Error generating medium SQL at index {index}: {e}")
                    time.sleep(10)

            try:
                SQL = SQL.split("SQL: ")[1]
            except Exception as e:
                print(f"SQL slicing error at index {index}: {e}")
                SQL = "SELECT"
        else:
            try:
                sub_questions = classification.split('questions = ["')[1].split('"]')[0]
            except Exception as e:
                print(f"Sub-questions slicing error at index {index}: {e}")
                sub_questions = ""

            print("NESTED")
            SQL = None
            while SQL is None:
                try:
                    SQL = mistral_generation(hard_prompt_maker(row['question'], row['db_id'], schema_links, sub_questions))
                except Exception as e:
                    print(f"Error generating hard SQL at index {index}: {e}")
                    time.sleep(10)

            try:
                SQL = SQL.split("SQL: ")[1]
            except Exception as e:
                print(f"SQL slicing error at index {index}: {e}")
                SQL = "SELECT"

        print(SQL)
        debugged_SQL = None
        while debugged_SQL is None:
            try:
                debugged_SQL = mistral_generation(debuger(row['question'], row['db_id'], SQL), max_tokens=350).replace("\n", " ")
            except Exception as e:
                print(f"Error during SQL debugging at index {index}: {e}")
                time.sleep(3)

        SQL = "SELECT " + debugged_SQL
        print(SQL)
        CODEX.append([row['question'], SQL, row['query'], row['db_id']])

    df = pd.DataFrame(CODEX, columns=['NLQ', 'PREDICTED SQL', 'GOLD SQL', 'DATABASE'])
    results = df['PREDICTED SQL'].tolist()
    with open(OUTPUT_FILE, 'w') as f:
        for line in results:
            f.write(f"{line}\n")
# Out:
# Number of data samples 200
# Processing index 0
# select t2.name ,  count(*) from package as t1 join client as t2 on t1.recipient  =  t2.accountnumber group by t1.recipient order by count(*) limit 1;
# What is the smallest number of packages received and by whom ?
# NON-NESTED
# SELECT T1.Name, count(T2.PackageNumber) FROM Client AS T1 JOIN Package AS T2 ON T1.AccountNumber = T2.Recipient GROUP BY T1.Name ORDER BY count(T2.PackageNumber) ASC LIMIT 1
# SELECT The SQLite SQL QUERY provided seems to be correct according to the instructions and the information given. It is correctly joining the Client and Package tables using the foreign key relationship between Client.AccountNumber and Package.Recipient. It is also correctly grouping by the client's name and ordering by the count of packages received in ascending order to find the smallest number of packages received. The LIMIT 1 at the end ensures that only the client with the smallest number of packages received is returned.  However, to ensure that the query returns the smallest number of packages received and the name of the client who received them, it would be better to include an alias for the count column in the SELECT statement for clarity. Here is the updated query:  SELECT T1.Name, count(T2.PackageNumber) AS NumPackagesReceived FROM Client AS T1 JOIN Package AS T2 ON T1.AccountNumber = T2.Recipient GROUP BY T1.Name ORDER BY count(T2.PackageNumber) ASC LIMIT 1
# Processing index 1
# SELECT T2.code FROM boxes AS T1 JOIN Warehouses AS T2 ON T1.warehouse  =  T2.code GROUP BY T2.code HAVING count(*)  >  T2.capacity
# What are the codes of warehouses that have more boxes than their capacity?
# NESTED
# SELECT Warehouses.Code FROM Warehouses LEFT JOIN Boxes ON Warehouses.Code = Boxes.Warehouse GROUP BY Warehouses.Code HAVING COUNT(Boxes.Code) > Warehouses.Capacity
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the tables using the foreign key, grouping by the warehouse code, and using the having clause to filter out the warehouses that have more boxes than their capacity. Here is the query:  ```sql SELECT Warehouses.Code FROM Warehouses LEFT JOIN Boxes ON Warehouses.Code = Boxes.Warehouse GROUP BY Warehouses.Code HAVING COUNT(Boxes.Code) > Warehouses.Capacity ```  This query will return the codes of warehouses that have more boxes than their capacity.
# Processing index 2
# SELECT T2.name ,  T2.Type_of_powertrain FROM renting_history AS T1 JOIN vehicles AS T2 ON T1.vehicles_id  =  T2.id GROUP BY T1.vehicles_id HAVING sum(T1.total_hours)  >  30
# Find the name and powertrain type of the cars that rented for more than 30 total hours.
# NON-NESTED
# SELECT T1.name, T1.Type_of_powertrain FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id WHERE T2.total_hours > 30
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the 'Vehicles' and 'Renting_history' tables using the foreign key 'vehicles_id' and is correctly filtering the results to only include rows where 'total_hours' is greater than 30. However, since there is no aggregation function used, there is no need for a GROUP BY clause. Here is the SQLite SQL QUERY as is:  ```sql SELECT T1.name, T1.Type_of_powertrain FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id WHERE T2.total_hours > 30 ```
# Processing index 3
# SELECT DISTINCT T4.FirstName ,  T4.LastName FROM goods AS T1 JOIN items AS T2 ON T1.id  =  T2.item JOIN receipts AS T3 ON T2.receipt  =  T3.ReceiptNumber JOIN customers AS T4 ON T3.CustomerId  =  T4.id WHERE T1.flavor  =  "Apple" AND T1.food  =  "Tart"
# What are the full names of customers who bought apple flavored Tarts?
# NON-NESTED
# SELECT T1.FirstName, T1.LastName FROM customers AS T1 JOIN receipts AS T2 ON T1.Id = T2.CustomerId JOIN items AS T3 ON T2.ReceiptNumber = T3.Receipt JOIN goods AS T4 ON T3.Item = T4.Id WHERE T4.Flavor = 'apple' AND T4.Food = 'Tarts'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is properly joining the tables using the foreign keys and primary keys, and it is selecting the correct columns for the full name of the customers. It is also correctly filtering the results to only include customers who bought apple flavored Tarts. Here is the SQLite SQL QUERY as is:  ```sql SELECT T1.FirstName, T1.LastName FROM customers AS T1 JOIN receipts AS T2 ON T1.Id = T2.CustomerId JOIN items AS T3 ON T2.ReceiptNumber = T3.Receipt JOIN goods AS T4 ON T3.Item = T4.Id WHERE T4.Flavor = 'apple' AND T4.Food = 'Tarts' ```
# Processing index 4
# SELECT DISTINCT T1.name FROM Client AS T1 JOIN Orders AS T2 ON T1.idClient  =  T2.idClient
# Show the names of clients who have ordered at least once.
# NON-NESTED
# SELECT Client.Name FROM Client JOIN Orders ON Client.IdClient = Orders.IdClient;
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the Client and Orders tables using the IdClient foreign key. However, to ensure that the query shows the names of clients who have ordered at least once, we can add a DISTINCT keyword to avoid duplicate names in the result. Here is the fixed SQL query:  ```sql SELECT DISTINCT Client.Name FROM Client JOIN Orders ON Client.IdClient = Orders.IdClient; ```
# Processing index 5
# SELECT paper_id ,  count(*) FROM Citation GROUP BY cited_paper_id ORDER BY count(*) DESC LIMIT 1
# What is the id and the number of citations of the most cited paper?
# NON-NESTED
# "SELECT T1.paper_id, COUNT(T2.paper_id) as citations FROM Paper AS T1 LEFT JOIN Citation AS T2 ON T1.paper_id = T2.cited_paper_id GROUP BY T1.paper_id ORDER BY citations DESC LIMIT 1"
# SELECT The SQLite SQL QUERY provided seems to be correct according to the instructions and the given tables, columns, foreign keys, and primary keys. It is correctly joining the Paper and Citation tables using the foreign key relationship, counting the number of citations for each paper, and grouping by the paper_id. It also correctly orders the results in descending order by the number of citations and limits the result to the top 1. Therefore, the SQLite FIXED SQL QUERY remains the same:  "SELECT T1.paper_id, COUNT(T2.paper_id) as citations FROM Paper AS T1 LEFT JOIN Citation AS T2 ON T1.paper_id = T2.cited_paper_id GROUP BY T1.paper_id ORDER BY citations DESC LIMIT 1"
# Processing index 6
# SELECT product_name FROM Products WHERE product_type_code  =  "Hardware" AND product_price  >  (SELECT avg(product_price) FROM Products WHERE product_type_code  =  "Hardware")
# Show all hardware product names with price higher than the average price of hardware type products.
# NESTED
# SELECT product_name FROM Products WHERE product_type_code = 'hardware' AND product_price > (SELECT AVG(product_price) FROM Products WHERE product_type_code = 'hardware')
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question you've asked. It's selecting the product_name from the Products table where the product_type_code is 'hardware' and the product_price is greater than the average price of hardware products. However, I would recommend adding a GROUP BY clause to the subquery to avoid any potential issues, even though it's not necessary in this case because SQLite allows it. Here's the slightly modified query:  ```sql SELECT product_name FROM Products WHERE product_type_code = 'hardware' AND product_price > (SELECT AVG(product_price) FROM Products WHERE product_type_code = 'hardware' GROUP BY product_type_code) ```
# Processing index 7
# SELECT Team FROM team WHERE Team_ID NOT IN (SELECT Team_ID FROM team_driver)
# List the names of teams that do not have any drivers.
# NESTED
# SELECT T1.Team FROM team AS T1 WHERE NOT EXISTS (SELECT * FROM team_driver AS T2 WHERE T2.Team_ID = T1.Team_ID)
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question you asked. It is correctly selecting the names of teams that do not have any drivers by using a subquery with the NOT EXISTS operator. Here is the query:  ```sql SELECT T1.Team FROM team AS T1 WHERE NOT EXISTS (SELECT * FROM team_driver AS T2 WHERE T2.Team_ID = T1.Team_ID) ```  This query will return the names of all teams in the 'team' table that do not have a corresponding entry in the 'team_driver' table, which would indicate that they have no drivers.
# Processing index 8
# SELECT analytical_layer_type_code ,  count(*) FROM analytical_layer GROUP BY analytical_layer_type_code
# For each analytical layer, return the analytical layer type code and the number of times it was used.
# EASY
# SELECT Analytical_Layer_Type_Code, COUNT(Analytical_ID)
# FROM Analytical_Layer
# GROUP BY Analytical_Layer_Type_Code;
#
# This SQL query will group the data in the Analytical_Layer table by the Analytical_Layer_Type_Code and then count the number of Analytical_IDs associated with each type. This will effectively give us the number of times each analytical layer type was used.
# SELECT The SQL query provided is already correct for the given question. It will return the analytical layer type code and the number of times it was used from the Analytical_Layer table. Therefore, no changes are needed.  SELECT Analytical_Layer_Type_Code, COUNT(Analytical_ID) FROM Analytical_Layer GROUP BY Analytical_Layer_Type_Code;
# Processing index 9
# SELECT Collection_Name FROM Collections EXCEPT SELECT T2.Collection_Name FROM Collections AS T1 JOIN Collections AS T2 ON T1.Parent_Collection_ID = T2.Collection_ID;
# What are the names of the collections that are not the parent of the other collections?
# NESTED
# SELECT Collections.Collection_Name FROM Collections WHERE Collections.Collection_ID NOT IN (SELECT Collections.Parent_Collection_ID FROM Collections)
# SELECT The SQLite SQL QUERY provided seems to be correct for the given question. It is selecting the names of the collections where the collection ID is not in the list of parent collection IDs, which would give us the collections that are not the parent of any other collections.  However, to ensure the query is efficient and uses the correct join columns, I would suggest adding a DISTINCT keyword to avoid any duplicate collection names in the result.  Here is the fixed SQLite SQL QUERY:  ```sql SELECT DISTINCT Collections.Collection_Name FROM Collections WHERE Collections.Collection_ID NOT IN (SELECT Collections.Parent_Collection_ID FROM Collections) ```
# Processing index 10
# SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  <  1885 INTERSECT SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  >  1930
# What are the locations that have works painted before 1885 and after 1930?
# EASY
# SELECT DISTINCT location FROM Paintings WHERE year < 1885 OR year > 1930
# SELECT The SQL query you provided is almost correct, but it seems like you want to find the locations that have works painted both before 1885 and after 1930. The current query will return locations that have works painted either before 1885 or after 1930. To fix this, you can use two subqueries and the INTERSECT operator, which returns the intersection of two result sets. Here's the corrected query:  ```sql SELECT DISTINCT location FROM Paintings WHERE year < 1885 INTERSECT SELECT DISTINCT location FROM Paintings WHERE year > 1930; ```  This query will return the locations that appear in both result sets, i.e., locations that have works painted both before 1885 and after 1930.
# Processing index 11
# SELECT DISTINCT T1.name ,  T1.sid FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid  =  T2.sid
# What is the name and id of every sailor who reserved one or more boats?
# NON-NESTED
# SELECT T1.sid, T1.name FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid = T2.sid
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the Sailors and Reserves tables on the sid column, and selecting the sid and name from the Sailors table. So, the SQLite FIXED SQL QUERY is:  SELECT T1.sid, T1.name FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid = T2.sid
# Processing index 12
# SELECT T1.Nickname FROM championship AS T1 JOIN institution AS T2 ON T1.Institution_ID  =  T2.Institution_ID ORDER BY T2.Enrollment ASC LIMIT 1
# What is the nickname of the institution with the smallest enrollment?
# NON-NESTED
# SELECT T1.Nickname FROM Championship AS T1 JOIN institution AS T2 ON T1.Institution_ID = T2.Institution_ID ORDER BY T2.Enrollment ASC LIMIT 1
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the tables using the foreign key, selecting the required column, and ordering the results by the enrollment in ascending order to find the institution with the smallest enrollment. Here is the same query:  ```sql SELECT T1.Nickname FROM Championship AS T1 JOIN institution AS T2 ON T1.Institution_ID = T2.Institution_ID ORDER BY T2.Enrollment ASC LIMIT 1 ```  This query will return the nickname of the institution with the smallest enrollment.
# Processing index 13
# SELECT T1.conference_name ,  T1.year ,  count(*) FROM Conference AS T1 JOIN Conference_participation AS T2 ON T1.conference_id  =  T2.conference_id GROUP BY T2.conference_id
# Show the conference name and year and the number of participants for each conference.
# NON-NESTED
# SELECT T1.Conference_Name, T1.Year, COUNT(T2.staff_ID) FROM conference AS T1 JOIN conference_participation AS T2 ON T1.Conference_ID = T2.Conference_ID GROUP BY T1.Conference_ID
# SELECT The SQL query you provided is almost correct, but the GROUP BY clause should include the same columns as in the SELECT clause that are not used in any aggregate functions. In this case, those are `T1.Conference_Name` and `T1.Year`. Here is the corrected query:  ```sql SELECT T1.Conference_Name, T1.Year, COUNT(T2.staff_ID) AS Number_of_Participants FROM conference AS T1 JOIN conference_participation AS T2 ON T1.Conference_ID = T2.Conference_ID GROUP BY T1.Conference_Name, T1.Year; ```  This query will return the name and year of each conference, along with the number of participants for each conference.
# Processing index 14
# SELECT T1.id ,  T1.Name ,  T1.popularity FROM participants AS T1 JOIN performance_score AS T2 ON T2.participant_id  =  T1.id GROUP BY T1.id ORDER BY count(*)
# What are the ids, names and popularity of the participants, order by the number of songs they perform?
# NON-NESTED
# SELECT T1.id, T1.name, T1.popularity, count(T2.songs_id) FROM participants AS T1 JOIN performance_score AS T2 ON T1.id = T2.participant_id GROUP BY T1.id ORDER BY count(T2.songs_id)
# SELECT The SQLite SQL QUERY provided seems to be correct according to the instructions given. It is properly joining the tables using the foreign keys, selecting the correct columns, using the count function to count the number of songs each participant has performed, grouping by the participant's id, and ordering by the count of songs. So, the SQLite FIXED SQL QUERY remains the same:  SELECT T1.id, T1.name, T1.popularity, count(T2.songs_id) FROM participants AS T1 JOIN performance_score AS T2 ON T1.id = T2.participant_id GROUP BY T1.id ORDER BY count(T2.songs_id)
# Processing index 15
# SELECT Founded ,  COUNT(*) FROM institution GROUP BY Founded HAVING COUNT(*)  >  1
# In which years were more than one institution founded?
# EASY
# SELECT Founded FROM institution
# GROUP BY Founded
# HAVING COUNT(*) > 1
# SELECT The SQLite SQL QUERY provided seems to be correct for the given question. It is correctly grouping by the 'Founded' column and using the HAVING clause to filter out the years in which more than one institution was founded. Therefore, no changes are needed.  SELECT Founded FROM institution GROUP BY Founded HAVING COUNT(*) > 1
# Processing index 16
# SELECT StuID FROM City AS T1 JOIN Student AS T2 ON T1.city_code  =  T2.city_code WHERE T1.state  =  "PA"  AND T2.sex  =  'F'
# What are the student ids for female students in the state of PA?
# NON-NESTED
# SELECT T1.StuID FROM Student AS T1 JOIN City AS T2 ON T1.city_code = T2.city_code WHERE T2.state = 'PA' AND T1.Sex = 'female'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the Student and City tables using the city_code foreign key, and it is correctly filtering for female students in the state of PA. Here is the SQLite SQL QUERY as is:  ```sql SELECT T1.StuID FROM Student AS T1 JOIN City AS T2 ON T1.city_code = T2.city_code WHERE T2.state = 'PA' AND T1.Sex = 'female' ```
# Processing index 17
# SELECT country FROM City GROUP BY country ORDER BY count(*) ASC LIMIT 1
# Give the country with the fewest number of cities.
# EASY
# SELECT country FROM City
# GROUP BY country
# ORDER BY COUNT(city_code) ASC
# LIMIT 1
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question "Give the country with the fewest number of cities". It correctly groups the cities by country and orders the results by the count of city codes (which represents the number of cities) in ascending order. The LIMIT 1 clause ensures that only the country with the fewest cities is returned.  Here is the SQLite SQL QUERY:  ```sql SELECT country FROM City GROUP BY country ORDER BY COUNT(city_code) ASC LIMIT 1; ```  This query will return the country with the fewest cities.
# Processing index 18
# SELECT T2.Document_Object_ID FROM Collections AS T1 JOIN Documents_in_Collections AS T2 ON T1.Collection_ID = T2.Collection_ID WHERE T1.Collection_Name = "Best";
# List the document id of all documents in collection named Best.
# NON-NESTED
# SELECT T1.Document_Object_ID FROM Documents_in_Collections AS T1 JOIN Document_Objects AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID JOIN Collections AS T3 ON T1.Collection_ID = T3.Collection_ID WHERE T3.Collection_Name = 'Best'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the tables using the foreign keys and selecting the required column. Here is the SQLite SQL QUERY:  ```sql SELECT T1.Document_Object_ID FROM Documents_in_Collections AS T1 JOIN Document_Objects AS T2 ON T1.Document_Object_ID = T2.Document_Object_ID JOIN Collections AS T3 ON T1.Collection_ID = T3.Collection_ID WHERE T3.Collection_Name = 'Best' ```  This query will return the document id of all documents in the collection named 'Best'.
# Processing index 19
# SELECT document_id FROM Documents EXCEPT SELECT document_id FROM Documents_processes
# Show all document ids without a process.
# NESTED
# SELECT Documents.document_id FROM Documents WHERE Documents.document_id NOT IN (SELECT Documents_Processes.document_id FROM Documents_Processes)
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question "Show all document ids without a process". It is selecting all document ids from the Documents table that are not present in the Documents_Processes table. Here is the SQL query:  ```sql SELECT Documents.document_id FROM Documents WHERE Documents.document_id NOT IN (     SELECT Documents_Processes.document_id     FROM Documents_Processes ) ```  This query will return all the document ids from the Documents table that do not have a corresponding record in the Documents_Processes table, effectively showing all documents without a process.
# Processing index 20
# SELECT amount_of_loan ,  date_of_loan FROM Student_Loans WHERE student_id IN ( SELECT student_id FROM Achievements GROUP BY student_id HAVING count(*)  >=  2 )
# What are the loan amounts and loan dates of the students who have at least 2 achievements?
# NESTED
# SELECT T1.amount_of_loan, T1.date_of_loan FROM Student_Loans AS T1 WHERE T1.student_id IN (SELECT student_id FROM Achievements GROUP BY student_id HAVING COUNT(*) >= 2)
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is properly selecting the loan amounts and loan dates from the Student_Loans table for students who have at least 2 achievements. The subquery is correctly grouping by student_id and counting the number of achievements for each student. So, the SQLite FIXED SQL QUERY remains the same:  SELECT T1.amount_of_loan, T1.date_of_loan FROM Student_Loans AS T1 WHERE T1.student_id IN (SELECT student_id FROM Achievements GROUP BY student_id HAVING COUNT(*) >= 2)
# Processing index 21
# SELECT model FROM headphone WHERE price  <  (SELECT avg(price) FROM headphone)
# Find the headphone models whose price is below the average price.
# NESTED
# SELECT Model FROM headphone WHERE Price < (SELECT AVG(Price) FROM headphone)
# SELECT The SQLite SQL QUERY provided seems to be correct for the given question. It is correctly selecting the 'Model' from the 'headphone' table where the 'Price' is less than the average 'Price' of all headphones. Therefore, no changes are needed.  SELECT Model FROM headphone WHERE Price < (SELECT AVG(Price) FROM headphone)
# Processing index 22
# SELECT Payment_method_code FROM Customer_Payment_Methods GROUP BY Payment_method_code ORDER BY count(*) DESC LIMIT 1
# What is the most popular payment method?
# EASY
# SELECT payment_method_code, COUNT(*) as count
# FROM Customer_Payment_Methods
# GROUP BY payment_method_code
# ORDER BY count DESC
# LIMIT 1;
# SELECT The SQLite SQL QUERY provided seems to be correct for the question asked. It is selecting the payment method code, counting the number of occurrences, grouping by the payment method code, ordering by the count in descending order, and limiting the result to the top 1. Therefore, no changes are needed.  SELECT payment_method_code, COUNT(*) as count FROM Customer_Payment_Methods GROUP BY payment_method_code ORDER BY count DESC LIMIT 1;
# Processing index 23
# select distinct t1.name ,  t1.sid from sailors as t1 join reserves as t2 on t1.sid  =  t2.sid group by t2.sid having count(*)  >=  2
# What are the different names of sailors who reserved two or more boats ?
# NESTED
# SELECT T2.name FROM Sailors AS T2 WHERE T2.sid IN (SELECT T1.sid FROM Reserves AS T1 GROUP BY T1.sid HAVING count(*) >= 2)
# SELECT The SQL query provided seems to be correct according to the instructions and the given tables, columns, foreign keys, and primary keys. It is correctly selecting the names of sailors who have reserved two or more boats. However, I would recommend adding a DISTINCT keyword to the SELECT statement to avoid duplicate names in the result. Here's the modified query:  ```sql SELECT DISTINCT T2.name FROM Sailors AS T2 WHERE T2.sid IN (   SELECT T1.sid   FROM Reserves AS T1   GROUP BY T1.sid   HAVING count(*) >= 2 ) ``` This query will return the distinct names of sailors who have reserved two or more boats.
# Processing index 24
# SELECT max(price) ,  min(price) ,  avg(price) ,  flavor FROM goods GROUP BY flavor ORDER BY flavor
# What are the maximum, minimum, and average prices of goods of each flavor, ordered by flavor?
# EASY
# SELECT Flavor, MAX(Price) AS MaxPrice, MIN(Price) AS MinPrice, AVG(Price) AS AvgPrice
# FROM goods
# GROUP BY Flavor
# ORDER BY Flavor;
# SELECT The given SQLite SQL QUERY seems to be correct according to the instructions and the provided tables, columns, foreign keys, and primary keys. It correctly selects the Flavor and the maximum, minimum, and average prices of goods for each flavor from the goods table, groups the results by Flavor, and orders the results by Flavor. Therefore, there is no need to fix it.  SELECT Flavor, MAX(Price) AS MaxPrice, MIN(Price) AS MinPrice, AVG(Price) AS AvgPrice FROM goods GROUP BY Flavor ORDER BY Flavor;
# Processing index 25
# SELECT DISTINCT T1.name ,  T1.sid FROM Sailors AS T1 JOIN Reserves AS T2 ON T1.sid  =  T2.sid GROUP BY T2.sid HAVING COUNT(*)  >  1
# Find the id and name of the sailors who reserved more than one boat.
# NESTED
# SELECT T1.sid, T1.name FROM Sailors AS T1 WHERE T1.sid IN (SELECT Reserves.sid FROM Reserves JOIN Boats ON Reserves.bid = Boats.bid GROUP BY Reserves.sid HAVING COUNT(Reserves.bid) > 1)
# SELECT The SQLite SQL query you provided seems to be correct according to the instructions and the given tables, columns, foreign keys, and primary keys. It is finding the sailors who have reserved more than one boat by joining the Reserves and Boats tables on the bid foreign key, grouping by the sid of the sailor, and then counting the number of boats reserved. The sailors who have reserved more than one boat are then selected from the Sailors table using a subquery. Here is the query:  ```sql SELECT T1.sid, T1.name FROM Sailors AS T1 WHERE T1.sid IN (     SELECT Reserves.sid     FROM Reserves     JOIN Boats ON Reserves.bid = Boats.bid     GROUP BY Reserves.sid     HAVING COUNT(Reserves.bid) > 1 ) ```  This query will return the id and name of the sailors who have reserved more than one boat.
# Processing index 26
# SELECT T1.city_name ,  count(*) FROM City AS T1 JOIN Student AS T2 ON T1.city_code  =  T2.city_code GROUP BY T1.city_code
# How many students live in each city?
# NON-NESTED
# SELECT count(T1.StuID), T2.city_name FROM Student AS T1 JOIN City AS T2 ON T1.city_code = T2.city_code GROUP BY T2.city_name
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the Student and City tables using the city_code foreign key, counting the number of students (StuID) in each city, and grouping by the city name. Here is the SQLite SQL QUERY as is:  ```sql SELECT COUNT(T1.StuID), T2.city_name FROM Student AS T1 JOIN City AS T2 ON T1.city_code = T2.city_code GROUP BY T2.city_name ```  This query will return a list of city names along with the number of students living in each city.
# Processing index 27
# SELECT state FROM City GROUP BY state ORDER BY count(*) DESC LIMIT 1
# Which state has most number of cities?
# EASY
# SELECT state, COUNT(city_code) AS city_count
# FROM City
# GROUP BY state
# ORDER BY city_count DESC
# LIMIT 1
#
# This query will group the cities by their respective states and count the number of cities in each state. The state with the highest count will be returned as the result. Please ensure to replace the table and column names with the actual ones in your database.
# SELECT The SQL query you provided is already correct according to the instructions and the information given. It selects the state and the count of cities in each state, groups them by state, orders them in descending order by the count of cities, and limits the result to the top 1. So, there's no need for any changes.  Here's the SQL query:  ```sql SELECT state, COUNT(city_code) AS city_count FROM City GROUP BY state ORDER BY city_count DESC LIMIT 1 ```  This query will return the state with the most number of cities.
# Processing index 28
# SELECT avg(age) FROM customers WHERE membership_credit  >  (SELECT avg(membership_credit) FROM customers)
# Return the average age for customers who have membership above the average across all customers.
# NESTED
# SELECT AVG(T1.age) FROM Customers AS T1 WHERE T1.membership_credit > (SELECT AVG(membership_credit) FROM Customers)
#
# Q: "Find the names of vehicles that have been rented for more than 50 hours in total."
# schema_links: [Vehicles.name, Renting_history.vehicles_id, Renting_history.total_hours]
# A: Let's think step by step. "Find the names of vehicles that have been rented for more than 50 hours in total." can be solved by knowing the answer to the following sub-question "What are the vehicle names that have a total rental time of more than 50 hours?".
# The SQL query for the sub-question "What are the vehicle names that have a total rental time of more than 50 hours?" is SELECT T1.name FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id GROUP BY T2.vehicles_id HAVING SUM(T2.total_hours) > 50
# So, the answer to the question "Find the names of vehicles that have been rented for more than 50 hours in total." is =
# Intermediate_representation: select Vehicles.name from Vehicles join Renting_history on Vehicles.id = Renting_history.vehicles_id group by Renting_history.vehicles_id having sum(Renting_history.total_hours) > 50
#
# SELECT SELECT T1.name FROM Vehicles AS T1 JOIN Renting_history AS T2 ON T1.id = T2.vehicles_id GROUP BY T1.name HAVING SUM(T2.total_hours) > 50
# Processing index 29
# SELECT T1.PackageNumber FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Recipient  =  T2.AccountNumber WHERE T2.Name = "Leo Wong";
# What are all of the package numbers received by Leo Wong?
# NON-NESTED
# SELECT T1.PackageNumber FROM Package AS T1 JOIN Client AS T2 ON T1.Recipient = T2.AccountNumber WHERE T2.Name = 'Leo Wong'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the database schema you've provided. It is correctly joining the Package and Client tables on the Recipient and AccountNumber columns respectively, and filtering the results to only include packages received by 'Leo Wong'. Here is the query:  ```sql SELECT T1.PackageNumber FROM Package AS T1 JOIN Client AS T2 ON T1.Recipient = T2.AccountNumber WHERE T2.Name = 'Leo Wong' ```  This query will return all the package numbers received by Leo Wong.
# Processing index 30
# SELECT Engine FROM driver GROUP BY Engine HAVING COUNT(*)  >=  2
# List the types of engines that are used by at least two drivers.
# EASY
# SELECT Engine FROM driver
# GROUP BY Engine
# HAVING COUNT(*) >= 2
# SELECT The SQL query you provided is correct for finding the types of engines that are used by at least two drivers, assuming that each driver can only have one engine type. However, the query does not take into account the relationship between the driver and race tables. Since the question does not explicitly state that a driver can only participate in one race or that they must use the same engine in every race, we should consider the possibility that a driver might use different engines in different races.  To account for this, we need to join the driver and race tables using the foreign key relationship, and then count the distinct Driver_ID for each engine type. Here is the corrected SQL query:  ```sql SELECT d.Engine FROM driver d JOIN race r ON d.Driver_ID = r.Driver_ID GROUP BY d.Engine HAVING COUNT(DISTINCT r.Driver_ID) >= 2 ```  This query will return the types of engines that are used by at least two different drivers, even if those drivers use different engines in different races.
# Processing index 31
# SELECT T2.Name ,  count(*) FROM PACKAGE AS T1 JOIN Client AS T2 ON T1.Sender  =  T2.AccountNumber GROUP BY T1.Sender HAVING count(*)  >  1;
# What is the name of all clients who sent more than one package?
# NON-NESTED
# SELECT T1.Name FROM Client AS T1 JOIN Package AS T2 ON T1.AccountNumber = T2.Sender GROUP BY T1.Name HAVING COUNT(T2.Sender) > 1
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the Client and Package tables using the AccountNumber and Sender columns respectively, which are related by the foreign key constraint. It is also correctly grouping by the Name column of the Client table and using the HAVING clause to filter only those clients who have sent more than one package. Here is the SQLite SQL QUERY:  ```sql SELECT T1.Name FROM Client AS T1 JOIN Package AS T2 ON T1.AccountNumber = T2.Sender GROUP BY T1.Name HAVING COUNT(T2.Sender) > 1 ```
# Processing index 32
# SELECT T1.state FROM City AS T1 JOIN Student AS T2 ON T1.city_code  =  T2.city_code GROUP BY T1.state HAVING count(*)  >  5
# What are the states with more than 5 students?
# NON-NESTED
# SELECT T1.state FROM City AS T1 JOIN Student AS T2 ON T1.city_code = T2.city_code GROUP BY T1.state HAVING count(T2.StuID) > 5
# SELECT The SQLite SQL query provided seems to be correct according to the instructions and the information given. It is properly joining the City and Student tables using the city_code foreign key, grouping by the state, and counting the number of students in each state. So, the SQLite FIXED SQL QUERY remains the same:  SELECT T1.state FROM City AS T1 JOIN Student AS T2 ON T1.city_code = T2.city_code GROUP BY T1.state HAVING count(T2.StuID) > 5
# Processing index 33
# SELECT T2.name ,  count(*) FROM Orders AS T1 JOIN Client AS T2 ON T1.idClient  =  T2.idClient GROUP BY T1.idClient
# Show all client names and the number of orders each has made.
# NON-NESTED
# SELECT T1.Name, count(T2.IdOrder) FROM Client AS T1 JOIN Orders AS T2 ON T1.IdClient = T2.IdClient GROUP BY T1.Name
# SELECT The SQL query provided seems to be correct according to the instructions and the given tables, columns, foreign keys, and primary keys. It is selecting the client's name and counting the number of orders each client has made. It is also grouping by the client's name which is appropriate in this context. So, the SQLite FIXED SQL QUERY is:  ```sql SELECT T1.Name, count(T2.IdOrder) FROM Client AS T1 JOIN Orders AS T2 ON T1.IdClient = T2.IdClient GROUP BY T1.Name ```
# Processing index 34
# SELECT T2.Transmitter ,  COUNT(*) FROM city_channel_radio AS T1 JOIN radio AS T2 ON T1.Radio_ID  =  T2.Radio_ID GROUP BY T2.Transmitter
# Show the transmitters of the radios and the number of city channels they are associated with.
# NON-NESTED
# SELECT T1.Transmitter, count(T2.City_channel_ID) FROM radio AS T1 JOIN city_channel_radio AS T2 ON T1.Radio_ID = T2.Radio_ID GROUP BY T1.Transmitter
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the 'radio' and 'city_channel_radio' tables using the foreign key relationship between them. It is also correctly grouping by the 'Transmitter' column and counting the number of 'City_channel_ID' for each 'Transmitter'. Here is the same query:  ```sql SELECT T1.Transmitter, count(T2.City_channel_ID) FROM radio AS T1 JOIN city_channel_radio AS T2 ON T1.Radio_ID = T2.Radio_ID GROUP BY T1.Transmitter ```
# Processing index 35
# SELECT T3.date FROM goods AS T1 JOIN items AS T2 ON T1.id  =  T2.item JOIN receipts AS T3 ON T2.receipt  =  T3.ReceiptNumber GROUP BY T3.date HAVING sum(T1.price)  >  100
# On which day did the bakery sell more than 100 dollars in total.
# NON-NESTED
# SELECT T1.Date FROM receipts AS T1 JOIN items AS T2 ON T1.ReceiptNumber = T2.Receipt JOIN goods AS T3 ON T2.Item = T3.Id WHERE SUM(T3.Price) > 100 GROUP BY T1.Date
#
# Please note that the SQL query might not work as expected because the SUM function is used in the WHERE clause, which is not allowed in SQL. The correct query would be:
#
#
# SELECT Sure, I see the issue with your SQL query. The SUM function is an aggregate function and should be used in the HAVING clause, not the WHERE clause, when you're using a GROUP BY statement. Here's the corrected query:  ```sql SELECT T1.Date FROM receipts AS T1 JOIN items AS T2 ON T1.ReceiptNumber = T2.Receipt JOIN goods AS T3 ON T2.Item = T3.Id GROUP BY T1.Date HAVING SUM(T3.Price) > 100 ```  This query will return the dates on which the total sales (sum of the price of goods sold) were more than 100 dollars.
# Processing index 36
# SELECT Driver_Name FROM driver WHERE Driver_ID NOT IN (SELECT Driver_ID FROM race)
# List the names of drivers that do not participate in any race.
# NESTED
# SELECT Driver_Name FROM driver WHERE Driver_ID NOT IN (SELECT Driver_ID FROM race)
# SELECT The SQLite SQL QUERY provided seems to be correct for the given question. It is selecting the Driver_Name from the driver table where the Driver_ID is not in the list of Driver_ID's from the race table. This will indeed list the names of drivers that do not participate in any race.  However, I would recommend adding DISTINCT keyword to avoid duplicate driver names in the result.  Here is the SQLite FIXED SQL QUERY:  SELECT DISTINCT Driver_Name FROM driver WHERE Driver_ID NOT IN (SELECT Driver_ID FROM race)
# Processing index 37
# SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  <  1885 INTERSECT SELECT DISTINCT LOCATION FROM paintings WHERE YEAR  >  1930
# Find the locations that have paintings created before 1885 and after 1930?
# EASY
# SELECT location FROM Paintings WHERE year < 1885 OR year > 1930
#
# Q: "Find the IDs of artists who were born after 1850 and died before 1950."
# Schema_links: [Artists.artistID, Artists.birthYear, Artists.deathYear, 1850, 1950]
# SQL: SELECT artistID FROM Artists WHERE birthYear > 1850 AND deathYear < 1950
#
# Q: "Find the titles of paintings that are oil on canvas."
# Schema_links: [Paintings.title, Paintings.medium, Paintings.mediumOn, 'oil', 'canvas']
# SQL: SELECT title FROM Paintings WHERE medium = 'oil' AND mediumOn = 'canvas'
#
# Q: "Find the sculptor's name and the year of their sculptures."
# Schema_links: [Sculptures.sculptorID, Artists.fname, Artists.lname, Sculptures.year]
# SQL: SELECT fname, lname, year FROM Sculptures JOIN Artists ON Sculptures.sculptorID = Artists.artistID
#
# Q: "Find the dimensions (height and width) of paintings by the artist with the last name 'Picasso'."
# Schema_links: [Paintings.painterID, Artists.lname, Paintings.height_mm, Paintings.width_mm, 'Picasso']
# SQL: SELECT height_mm, width_mm FROM Paintings JOIN Artists ON Paintings.painterID = Artists.artistID WHERE lname = 'Picasso'
# SELECT The SQL query you provided is almost correct, but it will return the locations of paintings that are either created before 1885 or after 1930. However, the question asks for paintings that are created before 1885 and after 1930, which is not possible. I assume you meant to ask for paintings that are either created before 1885 or after 1930.  Also, the query will return duplicate locations if there are multiple paintings from the same location that meet the criteria. To avoid this, we can use the DISTINCT keyword. Here is the corrected SQL query:  ```sql SELECT DISTINCT location FROM Paintings WHERE year < 1885 OR year > 1930 ```
# Processing index 38
# SELECT sum(T1.Number_of_Championships) FROM championship AS T1 JOIN institution AS T2 ON T1.Institution_ID  =  T2.Institution_ID WHERE T2.Affiliation  =  "Public"
# What is the total number of championship of institution with public affiliation?
# NON-NESTED
# SELECT sum(T1.Number_of_Championships) FROM Championship AS T1 JOIN institution AS T2 ON T1.Institution_ID = T2.Institution_ID WHERE T2.Affiliation = 'public'
# SELECT The provided SQL query seems to be correct according to the instructions and the information given. It is properly joining the tables using the foreign key, selecting the correct column, and filtering based on the condition mentioned in the question. Therefore, the fixed SQL query remains the same:  ```sql SELECT sum(T1.Number_of_Championships) FROM Championship AS T1 JOIN institution AS T2 ON T1.Institution_ID = T2.Institution_ID WHERE T2.Affiliation = 'public' ```
# Processing index 39
# SELECT 	count(DISTINCT T1.pilot_name) FROM pilotskills AS T1 JOIN hangar AS T2 ON T1.plane_name  =  T2.plane_name WHERE T2.location  =  'Chicago'
# How many pilots whose planes are in Chicago?
# NON-NESTED
# SELECT T2.pilot_name FROM Hangar AS T1 JOIN PilotSkills AS T2 ON T1.plane_name = T2.plane_name WHERE T1.location = 'Chicago'
# SELECT The provided SQL query is almost correct, but it doesn't count the number of pilots as requested by the question. To fix this, we can use the COUNT function. Here's the corrected query:  ```sql SELECT COUNT(T2.pilot_name) FROM Hangar AS T1 JOIN PilotSkills AS T2 ON T1.plane_name = T2.plane_name WHERE T1.location = 'Chicago' ```  This query will return the count of pilots whose planes are located in Chicago.
# Processing index 40
# SELECT T1.idOrder ,  T2.name FROM Orders AS T1 JOIN Client AS T2 ON T1.idClient  =  T2.idClient
# Show all order ids and their client names.
# NON-NESTED
# SELECT T1.IdOrder, T2.Name FROM Orders AS T1 JOIN Client AS T2 ON T1.IdClient = T2.IdClient
# SELECT The SQL query you provided seems to be correct according to the instructions and the tables, columns, foreign keys, and primary keys given. It is properly joining the Orders table with the Client table using the IdClient foreign key. Here is the query:  ```sql SELECT T1.IdOrder, T2.Name FROM Orders AS T1 JOIN Client AS T2 ON T1.IdClient = T2.IdClient ```  This query will return all order ids and their corresponding client names.
# Processing index 41
# SELECT count(*) FROM Book AS T1 JOIN Books_Order AS T2 ON T1.isbn  =  T2.isbn WHERE T1.title  =  "Pride and Prejudice"
# Return the number of orders received for Pride and Prejudice.
# NON-NESTED
# SELECT sum(T1.amount) FROM Books_Order AS T1 JOIN Book AS T2 ON T1.ISBN = T2.ISBN WHERE T2.Title = 'Pride and Prejudice'
# SELECT The SQLite SQL QUERY provided seems to be correct according to the instructions and the information given. It is correctly joining the Books_Order table with the Book table using the ISBN foreign key, and it is filtering the results to only include rows where the title of the book is 'Pride and Prejudice'. The SELECT statement is using the SUM function to add up the amount column from the Books_Order table, which should give the total number of orders received for 'Pride and Prejudice'.  Therefore, the SQLite FIXED SQL QUERY is:  SELECT sum(T1.amount) FROM Books_Order AS T1 JOIN Book AS T2 ON T1.ISBN = T2.ISBN WHERE T2.Title = 'Pride and Prejudice'
# Processing index 42
# SELECT T1.order_id ,  T1.date_order_placed ,  sum(T3.product_price) FROM Orders AS T1 JOIN Order_items AS T2 ON T1.order_id  =  T2.order_id JOIN Products AS T3 ON T2.product_id  =  T3.product_id GROUP BY T1.order_id
# For each order, what is its id, date, and total amount paid?
# NON-NESTED
# SELECT T1.order_id, T1.date_order_placed, sum(T3.product_price) FROM Orders AS T1 JOIN Order_Items AS T2 ON T1.order_id = T2.order_id JOIN Products AS T3 ON T2.product_id = T3.product_id GROUP BY T1.order_id, T1.date_order_placed
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is properly joining the tables using the foreign keys, selecting the required columns, and grouping by the correct columns. Here is the SQL query:  ```sql SELECT T1.order_id, T1.date_order_placed, sum(T3.product_price) FROM Orders AS T1 JOIN Order_Items AS T2 ON T1.order_id = T2.order_id JOIN Products AS T3 ON T2.product_id = T3.product_id GROUP BY T1.order_id, T1.date_order_placed ```  This query will return each order's id, date, and the total amount paid for each order.
# Processing index 43
# SELECT T1.ReceiptNumber FROM receipts AS T1 JOIN items AS T2 ON T1.ReceiptNumber  =  T2.receipt JOIN goods AS T3 ON T2.item  =  T3.id JOIN customers AS T4 ON T4.Id  =  T1.CustomerId WHERE T3.food  =  "Croissant" AND T4.LastName  =  'LOGAN'
# Find all the receipt numbers in which customer with last name LOGAN purchased Croissant.
# NON-NESTED
# SELECT T1.ReceiptNumber FROM receipts AS T1 JOIN customers AS T2 ON T1.CustomerId = T2.Id JOIN items AS T3 ON T1.Receipt = T3.Receipt JOIN goods AS T4 ON T3.Item = T4.Id WHERE T2.LastName = 'LOGAN' AND T4.Food = 'Croissant'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is properly joining the tables using the foreign keys, selecting the correct column, and filtering the results based on the conditions specified in the question. Therefore, the SQLite FIXED SQL QUERY remains the same:  ```sql SELECT T1.ReceiptNumber FROM receipts AS T1 JOIN customers AS T2 ON T1.CustomerId = T2.Id JOIN items AS T3 ON T1.Receipt = T3.Receipt JOIN goods AS T4 ON T3.Item = T4.Id WHERE T2.LastName = 'LOGAN' AND T4.Food = 'Croissant' ```  This query will return all the receipt numbers where the customer with the last name 'LOGAN' purchased a 'Croissant'.
# Processing index 44
# SELECT bid ,  count(*) FROM Reserves GROUP BY bid
# Find the number of reservations for each boat.
# NON-NESTED
# SELECT T1.order_id, sum(T2.quantity * T3.price) FROM Orders AS T1 JOIN Order_Items AS T2 ON T1.order_id = T2.order_id JOIN Products AS T3 ON T2.product_id = T3.product_id GROUP BY T1.order_id
#
# This query will give you the total price of each order by multiplying the quantity of each product in an order by its price and summing these values for each order.
# SELECT The given SQL query is not related to the tables and columns provided in the question. It seems like it's calculating the total price of each order, which is not what we want. We need to find the number of reservations for each boat. Here's the corrected SQL query:  ```sql SELECT Boats.bid, Boats.name, COUNT(Reserves.bid) AS reservations FROM Boats JOIN Reserves ON Boats.bid = Reserves.bid GROUP BY Boats.bid ```  This query will join the Boats and Reserves tables using the bid column (which is a foreign key in the Reserves table and a primary key in the Boats table). It then groups the results by the bid of each boat and counts the number of reservations for each boat. The result will be a list of boats with their corresponding number of reservations.
# Processing index 45
# SELECT T1.code FROM boxes AS T1 JOIN Warehouses AS T2 ON T1.warehouse  =  T2.code WHERE T2.location  =  'Chicago'
# What are the codes of boxes stored in warehouses in Chicago?
# NON-NESTED
# SELECT T1.Code FROM Boxes AS T1 JOIN Warehouses AS T2 ON T1.Warehouse = T2.Code WHERE T2.Location = 'Chicago'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is correctly joining the tables using the foreign key, selecting the desired column, and filtering the results based on the warehouse location. Here is the query:  ```sql SELECT T1.Code FROM Boxes AS T1 JOIN Warehouses AS T2 ON T1.Warehouse = T2.Code WHERE T2.Location = 'Chicago' ```  This query will return the codes of boxes stored in warehouses in Chicago.
# Processing index 46
# SELECT Gender_MFU ,  COUNT(*) FROM Students GROUP BY Gender_MFU
# List each gender and the corresponding number of students.
# EASY
# SELECT Gender_MFU, COUNT(Student_ID) FROM Students GROUP BY Gender_MFU
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question asked. It is correctly selecting the 'Gender_MFU' column and counting the 'Student_ID' for each gender. The GROUP BY statement is also correctly used on the 'Gender_MFU' column. Here is the SQLite SQL QUERY:  ```sql SELECT Gender_MFU, COUNT(Student_ID) FROM Students GROUP BY Gender_MFU; ```
# Processing index 47
# SELECT item FROM items GROUP BY item ORDER BY COUNT (*) DESC LIMIT 3
# Give the three most purchased items at this bakery.
# NON-NESTED
# SELECT goods.Id, goods.Flavor, goods.Food, count(items.Item) FROM goods JOIN items ON items.Item = goods.Id JOIN receipts ON receipts.ReceiptNumber = items.Receipt GROUP BY goods.Id, goods.Flavor, goods.Food ORDER BY count(items.Item) DESC LIMIT 3
# SELECT The SQLite SQL QUERY provided seems to be correct according to the instructions given. It is properly joining the tables using the foreign keys, selecting the required columns, grouping by the correct columns, and ordering by the count of items in descending order to get the three most purchased items. Here is the same SQLite SQL QUERY:  ```sql SELECT goods.Id, goods.Flavor, goods.Food, count(items.Item) FROM goods JOIN items ON items.Item = goods.Id JOIN receipts ON receipts.ReceiptNumber = items.Receipt GROUP BY goods.Id, goods.Flavor, goods.Food ORDER BY count(items.Item) DESC LIMIT 3 ```
# Processing index 48
# SELECT count(*) ,  LOCATION FROM paintings WHERE YEAR  <  1900 GROUP BY LOCATION
# How many paintings were created before 1900 in different locations?
# EASY
# SELECT COUNT(paintingID), location FROM Paintings WHERE year < 1900 GROUP BY location
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is counting the number of paintings created before 1900 and grouping them by their locations. Here is the query:  ```sql SELECT COUNT(paintingID), location FROM Paintings WHERE year < 1900 GROUP BY location ```
# Processing index 49
# select t1.document_object_id from document_subset_members as t1 join document_objects as t2 on t1.document_object_id  =  t2.document_object_id where t2.owner  =  'ransom'
# ...
# SQL:
# SELECT customers.FirstName, customers.LastName
# FROM customers
# JOIN (SELECT CustomerId, MIN(Date) as Earliest_Date FROM receipts WHERE YEAR(Date) = 2022) AS First_Receipt
# ON customers.Id = First_Receipt.CustomerId
#
# Q: "How many different types of food are sold?
# Schema_links: [goods.Food]
# SQL:
# SELECT COUNT(DISTINCT Food) FROM goods
#
# Q: "List the names of customers who have never purchased a dessert.
# Schema_links: [customers.FirstName, customers.LastName, receipts.CustomerId, receipts.ReceiptNumber, items.Receipt, items.Ordinal, items.Item, goods.Id, goods.Food, 'dessert']
# SQL:
# SELECT customers.FirstName, customers.LastName
# FROM customers
# LEFT JOIN receipts ON customers.Id = receipts.CustomerId
# LEFT JOIN items ON receipts.ReceiptNumber = items.Receipt
# LEFT JOIN goods ON items.Item = goods.Id
# WHERE goods.Food != 'dessert' OR goods.Food IS NULL
# GROUP BY customers.FirstName, customers.LastName
# HAVING COUNT(DISTINCT receipts.ReceiptNumber) = COUNT(DISTINCT IF(goods.Food != 'dessert' OR goods.Food IS NULL, receipts.ReceiptNumber, NULL))
# SELECT The SQLite SQL QUERY provided for the question "Count the number of types of cake this bakery sells." seems to be correct. It is selecting the count of distinct 'Food' from the 'goods' table where 'Food' is equal to 'cake'. This will indeed return the number of different types of cake the bakery sells.  However, if we want to ensure that we are only counting cakes that have actually been sold, we might need to join with the 'items' table to ensure that each cake type has at least one corresponding entry in the 'items' table. But since the question does not explicitly state this requirement, the provided SQL query should be sufficient.  So, the SQLite SQL QUERY remains the same:  ```sql SELECT COUNT(DISTINCT Food) FROM goods WHERE Food = 'cake' ```
# Processing index 189
# select distinct state from city
# List all different states .
# EASY
# SELECT DISTINCT state FROM City
# SELECT The SQLite SQL QUERY you provided is already correct for the question "List all different states". It will select all distinct states from the City table. So, the fixed SQL query is:  SELECT DISTINCT state FROM City
# Processing index 190
# SELECT count(*) FROM Documents
# Show the number of documents.
# EASY
# SELECT COUNT(document_id) FROM Documents
#
# Q: "List the names of authors who have written more than one document."
# Schema_links: [Authors.author_name, Documents.author_name]
# SQL: SELECT Authors.author_name FROM Authors WHERE Authors.author_name IN (SELECT Documents.author_name FROM Documents GROUP BY Documents.author_name HAVING COUNT(Documents.author_name) > 1)
#
# Q: "Find the process names and their descriptions where the outcome is 'Approved'."
# Schema_links: [Business_Processes.process_name, Business_Processes.process_description, Process_Outcomes.process_outcome_code, Process_Outcomes.process_outcome_description, 'Approved']
# SQL: SELECT Business_Processes.process_name, Business_Processes.process_description FROM Business_Processes INNER JOIN Documents_Processes ON Business_Processes.process_id = Documents_Processes.process_id INNER JOIN Process_Outcomes ON Documents_Processes.process_outcome_code = Process_Outcomes.process_outcome_code WHERE Process_Outcomes.process_outcome_description = 'Approved'
#
# Q: "Show the documents which are currently in review."
# Schema_links: [Documents.document_name, Process_Status.process_status_code, Process_Status.process_status_description, 'In Review']
# SQL: SELECT Documents.document_name FROM Documents INNER JOIN Documents_Processes ON Documents.document_id = Documents_Processes.document_id INNER JOIN Process_Status ON Documents_Processes.process_status_code = Process_Status.process_status_code WHERE Process_Status.process_status_description = 'In Review'
#
# Q: "List the staff who are currently involved in a business process and their roles."
# Schema_links: [Staff.staff_id, Staff.staff_details, Ref_Staff_Roles.staff_role_code, Ref_Staff_Roles.staff_role_description, Staff_in_Processes.staff_id, Staff_in_Processes.staff_role_code]
# SQL: SELECT Staff.staff_id, Staff.staff_details, Ref_Staff_Roles.staff_role_description FROM Staff INNER JOIN Staff_in_Processes ON Staff.staff_id = Staff_in_Processes.staff_id INNER JOIN Ref_Staff_Roles ON Staff_in_Processes.staff_role_code = Ref_Staff_Roles.staff_role_code
# SELECT The SQLite SQL QUERY provided for the question "Show the number of documents." is correct. It will return the count of all documents in the Documents table.  SELECT COUNT(document_id) FROM Documents
# Processing index 191
# SELECT DISTINCT painterID FROM paintings WHERE medium  =  "oil" AND LOCATION  =  "Gallery 240"
# Find the unique id of the painters who had medium oil paintings exhibited at gallery 240?
# NON-NESTED
# SELECT DISTINCT T1.artistID FROM Artists AS T1 JOIN Paintings AS T2 ON T1.artistID = T2.painterID WHERE T2.medium = 'oil' AND T2.location = 'gallery 240'
# SELECT The SQLite SQL QUERY you provided seems to be correct according to the instructions and the information given. It is properly selecting the distinct artistID from the Artists table and joining it with the Paintings table using the artistID and painterID foreign key. It also correctly filters the results using the WHERE clause for the medium and location. So, the SQLite FIXED SQL QUERY remains the same:  SELECT DISTINCT T1.artistID FROM Artists AS T1 JOIN Paintings AS T2 ON T1.artistID = T2.painterID WHERE T2.medium = 'oil' AND T2.location = 'gallery 240'
# Processing index 192
# SELECT name FROM countries ORDER BY politics_score DESC LIMIT 1
# What is the name of the country with the highest politics score?
# EASY
# SELECT name FROM countries ORDER BY politics_score DESC LIMIT 1
# SELECT The SQLite SQL QUERY you provided is correct for the question "What is the name of the country with the highest politics score?". It selects the name of the country from the countries table, orders the results by the politics_score in descending order, and limits the results to 1. So, the fixed SQL query is:  SELECT name FROM countries ORDER BY politics_score DESC LIMIT 1
# Processing index 193
# SELECT Title ,  Developers FROM game ORDER BY Units_sold_Millions DESC
# What are the titles and developers of all games, sorted by units sold descending?
# EASY
# SELECT Title, Developers FROM game ORDER BY Units_sold_Millions DESC
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question asked. It selects the Title and Developers from the game table and orders the results by Units_sold_Millions in descending order. However, I would recommend adding a comma between Title and Developers in the SELECT statement for clarity. Here is the corrected query:  ```sql SELECT Title, Developers FROM game ORDER BY Units_sold_Millions DESC; ```
# Processing index 194
# SELECT name FROM driver WHERE citizenship  =  'United States'
# What are the names of the drivers who are citizens of the 'United States'?
# EASY
# SELECT Name FROM driver WHERE Citizenship = 'United States'
# Q: "Which vehicles were built in the year 2000?"
# Schema_links: [vehicle.Vehicle_ID, vehicle.Build_Year, 2000]
# SQL: SELECT Vehicle_ID FROM vehicle WHERE Build_Year = 2000
# Q: "Find the drivers that drive vehicles with a top speed greater than 200 mph."
# Schema_links: [driver.Driver_ID, driver.Name, vehicle.Top_Speed, vehicle_driver.Driver_ID, vehicle_driver.Vehicle_ID, 200]
# SQL: SELECT driver.Name FROM driver INNER JOIN vehicle_driver ON driver.Driver_ID = vehicle_driver.Driver_ID INNER JOIN vehicle ON vehicle_driver.Vehicle_ID = vehicle.Vehicle_ID WHERE vehicle.Top_Speed > 200
# Q: "Which drivers are participating in the 'Formula One' racing series?"
# Schema_links: [driver.Name, driver.Racing_Series, 'Formula One']
# SQL: SELECT Name FROM driver WHERE Racing_Series = 'Formula One'
# Q: "Find the drivers and their vehicles that have a power greater than 500."
# Schema_links: [driver.Name, vehicle.Power, vehicle_driver.Driver_ID, vehicle_driver.Vehicle_ID, 500]
# SQL: SELECT driver.Name, vehicle.Power FROM driver INNER JOIN vehicle_driver ON driver.Driver_ID = vehicle_driver.Driver_ID INNER JOIN vehicle ON vehicle_driver.Vehicle_ID = vehicle.Vehicle_ID WHERE vehicle.Power > 500
# Q: "Find the vehicles with a total production of less than 100."
# Schema_links: [vehicle.Vehicle_ID, vehicle.Total_Production, 100]
# SQL: SELECT Vehicle_ID FROM vehicle WHERE Total_Production < 100
# Q: "Find the names of the builders who have built vehicles with a top speed of more than 250 mph."
# Schema_links: [vehicle.Builder, vehicle.Top_Speed, 250]
# SQL: SELECT Builder FROM vehicle WHERE Top_Speed > 250
# SELECT The SQLite SQL QUERY provided for the question "What are the names of the drivers who are citizens of the 'United States'?" is correct. There's no need for any fixes.  SQLite SQL QUERY: SELECT Name FROM driver WHERE Citizenship = 'United States'
# Processing index 195
# SELECT flavor FROM goods WHERE food  =  "Croissant"
# List all the flavors of Croissant available in this bakery.
# EASY
# SELECT Flavor FROM goods WHERE Food = 'Croissant'
# SELECT The SQLite SQL QUERY you provided seems to be correct for the question asked. It is selecting the Flavor column from the goods table where the Food column is 'Croissant'. Therefore, no changes are needed.  SELECT Flavor FROM goods WHERE Food = 'Croissant'
# Processing index 196
# SELECT id FROM goods WHERE food  =  "Cookie" OR food  =  "Cake" AND price BETWEEN 3 AND 7
# What are the ids of Cookie and Cake that cost between 3 and 7 dollars.
# EASY
# SELECT Id FROM goods WHERE (Flavor = 'Cookie' OR Food = 'Cake') AND Price BETWEEN 3 AND 7
#
# Q: "Who bought the most expensive item on the receipt number 123?"
# Schema_links: [receipts.ReceiptNumber, receipts.CustomerId, items.Receipt, items.Ordinal, items.Item, goods.Id, goods.Price]
# SQL:
# SELECT c.FirstName, c.LastName
# FROM receipts r
# JOIN items i ON r.ReceiptNumber = i.Receipt
# JOIN goods g ON i.Item = g.Id
# JOIN customers c ON r.CustomerId = c.Id
# WHERE r.ReceiptNumber = 123
# ORDER BY g.Price DESC
# LIMIT 1
#
# Q: "List all the receipt numbers where a customer bought more than one item."
# Schema_links: [receipts.ReceiptNumber, items.Receipt]
# SQL:
# SELECT i.Receipt
# FROM items i
# GROUP BY i.Receipt
# HAVING COUNT(i.Item) > 1
#
# Q: "How many customers bought items that cost more than 10 dollars?"
# Schema_links: [receipts.CustomerId, items.Item, goods.Id, goods.Price, 10]
# SQL:
# SELECT COUNT(DISTINCT r.CustomerId)
# FROM receipts r
# JOIN items i ON r.ReceiptNumber = i.Receipt
# JOIN goods g ON i.Item = g.Id
# WHERE g.Price > 10
# SELECT The SQLite SQL QUERY provided for the question "What are the ids of Cookie and Cake that cost between 3 and 7 dollars." seems to be correct. It is appropriately selecting the Id from the goods table where the Flavor is 'Cookie' or the Food is 'Cake' and the Price is between 3 and 7. Therefore, no fix is needed.  Here is the SQLite SQL QUERY as is:  ```sql SELECT Id FROM goods WHERE (Flavor = 'Cookie' OR Food = 'Cake') AND Price BETWEEN 3 AND 7 ```
# Processing index 197
# SELECT count(*) FROM Paper
# How many papers do we have?
# EASY
# SELECT COUNT(*) FROM Paper
#
# Q: "List all the authors who published a paper in 2018."
# Schema_links: [Author.name, Author_list.author_id, Paper.year, 2018]
# SQL: SELECT Author.name FROM Author JOIN Author_list ON Author.author_id = Author_list.author_id JOIN Paper ON Author_list.paper_id = Paper.paper_id WHERE Paper.year = 2018
#
# Q: "What are the titles of the papers that have been cited more than 100 times?"
# Schema_links: [Paper.title, Citation.paper_id, Citation.cited_paper_id, 100]
# SQL: SELECT Paper.title FROM Paper JOIN (SELECT Citation.cited_paper_id, COUNT(*) AS citation_count FROM Citation GROUP BY Citation.cited_paper_id HAVING citation_count > 100) AS highly_cited ON Paper.paper_id = highly_cited.cited_paper_id
#
# Q: "Which affiliations have published more than 50 papers?"
# Schema_links: [Affiliation.name, Author_list.affiliation_id, Paper.paper_id, 50]
# SQL: SELECT Affiliation.name FROM Affiliation JOIN (SELECT Author_list.affiliation_id, COUNT(*) AS paper_count FROM Author_list GROUP BY Author_list.affiliation_id HAVING paper_count > 50) AS productive_affiliations ON Affiliation.affiliation_id = productive_affiliations.affiliation_id
#
# Q: "Who are the authors of the most cited paper?"
# Schema_links: [Author.name, Author_list.author_id, Citation.cited_paper_id, Paper.paper_id]
# SQL: SELECT Author.name FROM Author JOIN Author_list ON Author.author_id = Author_list.author_id JOIN (SELECT Citation.cited_paper_id, COUNT(*) AS citation_count FROM Citation GROUP BY Citation.cited_paper_id ORDER BY citation_count DESC LIMIT 1) AS most_cited ON Author_list.paper_id = most_cited.cited_paper_id
# SELECT The SQLite SQL QUERY provided for the question "How many papers do we have?" is correct and does not need any fixes.  The query "SELECT COUNT(*) FROM Paper" will return the total number of rows in the Paper table, which corresponds to the total number of papers.  So, the SQLite FIXED SQL QUERY is:  SELECT COUNT(*) FROM Paper
# Processing index 198
# SELECT count(*) FROM Addresses
# How many addresses do we have?
# EASY
# SELECT COUNT(address_id) FROM Addresses
#
# Q: "Who are the customers that made orders on '2022-01-01'?"
# Schema_links: [Customers.customer_name, Customer_Orders.customer_id, Customer_Orders.order_date, '2022-01-01']
# SQL: SELECT Customers.customer_name FROM Customers JOIN Customer_Orders ON Customers.customer_id = Customer_Orders.customer_id WHERE Customer_Orders.order_date = '2022-01-01'
#
# Q: "What are the details of the products that were ordered more than 10 times?"
# Schema_links: [Products.product_name, Products.product_price, Order_Items.product_id, Order_Items.order_quantity, 10]
# SQL: SELECT Products.product_name, Products.product_price FROM Products JOIN Order_Items ON Products.product_id = Order_Items.product_id GROUP BY Products.product_id HAVING SUM(Order_Items.order_quantity) > 10
#
# Q: "What is the total revenue from orders made by the customer with id '123'?"
# Schema_links: [Customer_Orders.customer_id, Customer_Orders.order_id, Order_Items.order_id, Order_Items.product_id, Products.product_price, '123']
# SQL: SELECT SUM(Products.product_price * Order_Items.order_quantity) FROM Customer_Orders JOIN Order_Items ON Customer_Orders.order_id = Order_Items.order_id JOIN Products ON Order_Items.product_id = Products.product_id WHERE Customer_Orders.customer_id = '123'
#
# Q: "Which customers have not made any orders yet?"
# Schema_links: [Customers.customer_name, Customers.customer_id, Customer_Orders.customer_id]
# SQL: SELECT Customers.customer_name FROM Customers LEFT JOIN Customer_Orders ON Customers.customer_id = Customer_Orders.customer_id WHERE Customer_Orders.customer_id IS NULL
#
# Q: "What are the addresses of the customers who used the payment method 'Credit Card'?"
# Schema_links: [Customers.customer_id, Customers.address_id, Customers.payment_method_code, Addresses.address_id, Addresses.address_details, 'Credit Card']
# SQL: SELECT Addresses.address_details FROM Customers JOIN Addresses ON Customers.address_id = Addresses.address_id WHERE Customers.payment_method_code = 'Credit Card'
# SELECT The SQLite SQL QUERY provided for the question "How many addresses do we have?" is correct. It is properly selecting and counting the address_id from the Addresses table. Therefore, no changes are needed.  Correct SQLite SQL QUERY: SELECT COUNT(address_id) FROM Addresses
# Processing index 199
# SELECT pilot_name FROM pilotskills WHERE age BETWEEN 30 AND 40 ORDER BY age
# What are the names of pilots between the ages of 30 and 40, ordered by age ascending?
# EASY
# SELECT pilot_name FROM PilotSkills WHERE age BETWEEN 30 AND 40 ORDER BY age ASC;
# SELECT The SQLite SQL QUERY provided is already correct according to the instructions given. It is selecting the pilot_name from the PilotSkills table where the age is between 30 and 40 and ordering the results by age in ascending order. So, the SQLite FIXED SQL QUERY is:  SELECT pilot_name FROM PilotSkills WHERE age BETWEEN 30 AND 40 ORDER BY age ASC;

# %%
df.to_csv("mistral.csv")
